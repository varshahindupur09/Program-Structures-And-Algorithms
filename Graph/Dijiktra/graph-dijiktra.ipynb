# %% [markdown]
# ## Graph data structure
# ## Copyright: Jagadeesh Vasudevamurthy
# ## filename:graph.ipynb¶

# %% [markdown]
# # All import here

# %%
import sys # For getting Python Version
import os
import enum # For enum
import math  # for infinity
from graphviz import Source
print("Version of Python I am using is", sys.version)
# Out:
# Version of Python I am using is 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 10:07:17) [Clang 14.0.6 ]

# %% [markdown]
# # Graph input and output directory setup
# # YOU MUST CHANGE 2 lines below

# %%
inputFileBase = "/Users/varshahindupur/Desktop/Graph/graphdata/"
outputFileBase = "/Users/varshahindupur/Desktop/Graph/Dijiktra/"

# %%
def read_dot_file(f: str): #def read_dot_file(f: string)->'dot_graph':
    filename = outputFileBase + f + ".dot"
    print(filename)
    with open(filename) as f1:
        dot_graph = f1.read()
    print(dot_graph)
    return(dot_graph)

# %% [markdown]
# # YOU WRITE CODE HERE

# %% [markdown]
# # Graph buider from file

# %%
############################################################
# GraphBuilder.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
# YOU WRITE CODE IN THIS FILE
###########################################################

class GraphBuilder:
    def __init__(self, g, f: str): #def __init__(self, g: graph, f: str):
        self._g = g
        # graph object
        self._f = f  # File from which you are building graph
        self._g._g = self._build_graph()

    ############################################################
    # Write code: build_graph
    # Use as many private functions and prvate data you want
    ###########################################################
    def _build_graph(self) -> "None":
        with open(self._f, "r") as file:
            data = file.readlines()
            for aline in data:
                token = aline.split()
                size = len(token)
                if (size < 2) or (size > 3):
                    continue
                tf = token[0]
                tt = token[1]
                if (tf == tt):
                    continue
                w=0
                if size == 3: # weights are given for graph
                    tw = token[2]
                    w = float(tw)
                
                # Ensure both nodes are added to the graph
                f_node = self._g.build_node_and_to_graph(tf)
                t_node = self._g.build_node_and_to_graph(tt)
                
                # self._g._add_edge(tf,tt,w)
                self._g._add_edge(f_node,t_node,w)

# %% [markdown]
# # Write Graph as a dot file

# %%
############################################################
# GraphDot.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2020
###########################################################

############################################################
# YOU WRITE CODE IN THIS FILE
###########################################################

class GraphDot:
    def __init__(self, g, f):
        self._g = g  # Handle to graph
        self._f = f  # File where you write graph in dot format
        self._of = open(self._f, "w")
        self._write_dot()
        self._of.close()

    ############################################################
    # Write code: _write_dot
    # Use as many private functions and prvate data you want
    ###########################################################
    def _write_dot(self):
        self._of.write("## Jagadeesh Vasudevamurthy ####\n")
        self._of.write("digraph g {\n")
        t = self._g.get_graph_type()
       
        for node in self._g.list_of_nodes():
            node_name = node.get_name()
            # writing each nodename
            self._of.write(f'    "{node_name}";\n')
            print("This is a node: ", node_name, " ", node)
            
            for edge in node.fanout_of_a_node_edges():
                node2_name = edge.get_name()
                w = edge.get_weight()
                # include weights in graph if the graph is weighted
                if self._g.is_weighted_graph():
                    self._of.write(f'    "{node_name}" -> "{node2_name}" [label="{w}"];\n')
                else:
                    self._of.write(f'    "{node_name}" -> "{node2_name}";\n')
        
        self._of.write("}\n")

# %% [markdown]
# # DFS USING TIME STAMP

# %%
############################################################
# GraphDfs.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
# Depth First serach using TimeStamp
###########################################################
############################################################
# GraphDfs.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
# Depth First serach using TimeStamp
###########################################################
class Timestamp:
    def __init__(self):
        self.inn = 0
        self.out = 0
        
class GraphDfsUsingTimeStamp:
    def __init__(
        self,
        g: "graph",
        graph_name: "string",
        dfs_order: "list of Nodes",
        has_loop: "list of size 1",
        work: "list of size 1",
        dfs_traversal_output_file,
    ):
        ##NOTHING CAN BE CHANGED HERE
        self._g = g
        self._graph_name = graph_name
        self._dfs_order = dfs_order
        self._has_loop = has_loop
        self._has_loop[0] = False
        self._work = work
        self._work[0] = 0
        self._dfs_traversal_output_file = dfs_traversal_output_file

        ##YOU CAN has any number of private varibles and funcions
        self._counter = 0 
        self._a = {}
        self._unvisited_nodes = (set())

        self._dfs()
        self._write_dot()

    ##########################################################
    # Write dot file of DFS traversal
    ##########################################################
    def _write_dot(self):
        output_file = open(self._dfs_traversal_output_file, "w")
        output_file.write("## Jagadeesh Vasudevamurthy ####\n")
        output_file.write("digraph g {\n")
        output_file.write('\tlabel = "[') 
        for current_node in self._dfs_order:
            node_name = current_node.get_name()
            output_file.write(node_name)
            output_file.write(" ")
        if self._has_loop[0]:
            output_file.write('] LOOP"\n')
        else:
            output_file.write('] NOLOOP"\n')
        for current_node in self._dfs_order:
            node_name = current_node.get_name()
            output_file.write("\t")
            output_file.write(node_name)
            output_file.write(" [label= ")
            output_file.write("<")
            output_file.write(node_name)
            output_file.write('<BR /><FONT POINT-SIZE="10">')
            timestamp = self._a[current_node]
            output_file.write(str(timestamp.inn))
            output_file.write("/")
            output_file.write(str(timestamp.out))
            output_file.write("</FONT>>]\n")
    
        graph_type = self._g.get_graph_type()
        if graph_type == GraphType.UNDIRECTED or graph_type == GraphType.WEIGHTED_UNDIRECTED:
            output_file.write("\tedge [dir=none, color = blue]\n")
        else:
            output_file.write("\tedge [color=green]\n")
    
        all_nodes = self._g.list_of_nodes()
        for node in all_nodes:
            node_name_1 = node.get_name()
            fanout_edges = node.fanout_of_a_node()
            for edge in fanout_edges:
                node_name_2 = edge.get_name()
                edge_weight = node.node_get_fanout_node_weight(edge)
                edge_str = "" 
                if graph_type == GraphType.WEIGHTED_UNDIRECTED or graph_type == GraphType.WEIGHTED_DIRECTED:
                    if graph_type == GraphType.WEIGHTED_DIRECTED or (node_name_1 < node_name_2):
                        edge_str = f" {node_name_1} -> {node_name_2} [label = {edge_weight}]"
                elif graph_type == GraphType.DIRECTED or (node_name_1 < node_name_2):
                    edge_str = f" {node_name_1} -> {node_name_2}"
                if edge_str:
                    output_file.write(f"\t{edge_str}\n")
        output_file.write("}\n")
        output_file.close()


    ##########################################################
    # TIME: THETA(V + E)
    # SPACE: O(Largest path) = O(V)
    ##########################################################

    def _update_timestamp(self):
        listnodes = self._g.list_of_nodes()
        for n in listnodes:
            t = Timestamp()
            self._a[n] = t
            self._unvisited_nodes.add(n)

    def _is_visited_node(self, n: "Node"):
        return n not in self._unvisited_nodes

    def _mark_node_visited(self, n: "Node"):
        self._unvisited_nodes.remove(n)

    def _next_unvisited_node_from_set(self):
        return next(iter(self._unvisited_nodes), None)

    def _dfs_r(self, node: "Node", parentnode: "Node"):
        self._work[0] += 1
        if not self._is_visited_node(node):
            self._mark_node_visited(node)
            self._counter += 1
            t = self._a[node]
            t.inn = self._counter
            for fanoutnode in node.fanout_of_a_node():
                if fanoutnode != parentnode:
                    self._dfs_r(fanoutnode, node)
            self._counter += 1
            t.out = self._counter
            self._dfs_order.append(node)
        else:
            t = self._a[node]
            if t.out == 0:
                self._has_loop[0] = True
    def _dfs(self):
        self._update_timestamp()
        while True:
            nextnode = self._next_unvisited_node_from_set()
            if nextnode:
                self._dfs_r(nextnode, nextnode)
            else:
                break
        self._dfs_order.reverse()

# %% [markdown]
# # Dijkstra Algorithm

# %%
############################################################
# GraphDijkstra.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
# All imports
###########################################################
import heapq

############################################################
# self, gname, start_city, cost, work, dijkstra_traversal_dot_output_file
###########################################################
class GraphDijkstra:
    def __init__(
        self,
        g: "graph",
        graph_name: "string",
        start_city_name: "string",
        cost: "list of Nodes",  # FILL: cost from start city to all other city.If not reachable -1
        work: "list of size 1",  # FILL
        Dijkstra_traversal_output_file: "String",
        show: "bool",
    ):
        ##NOTHING CAN BE CHANGED HERE
        self._g = g
        self._gname = graph_name
        self._start_city_name = start_city_name
        self._cost = cost
        self._work = work
        self._work[0] = 0
        self._Dijkstra_traversal_output_file = Dijkstra_traversal_output_file
        self._show = show

        ##YOU CAN has any number of private varibles and funcions
        self._unvisited_nodes = set()
        self._visited_nodes = {} # visited, updated cost
        self._priority_queue = []
        self._distances = {}

        ###
        self._Dijkstra()
        self._write_dot()
        

    ##########################################################
    # All private function below
    ##########################################################
    def _increment_work(self, c):
        self._work[0] = self._work[0] + c

    def _write_dot(self):
        output = []
        graph_type = self._g.get_graph_type()
        
        # Add a comment about the graph type
        if graph_type == "WEIGHTED_DIRECTED":
            output.append('// This is a weighted directed graph\n')
            output.append('digraph G {\n')
        else:
            output.append('// This is a weighted undirected graph\n')
            output.append('graph G {\n')
        
        # Write nodes
        for node in self._g.list_of_nodes():
            node_name = node.get_name()
            if node in self._distances and self._distances[node] < float('infinity'):
                output.append(f'  "{node_name}" [label="{node_name} ({self._distances[node]})"];\n')
            else:
                output.append(f'  "{node_name}" [label="{node_name}"];\n')
        
        # Write edges
        for node in self._g.list_of_nodes():
            for neighbor in node.fanout_of_a_node():
                weight = node.node_get_fanout_node_weight(neighbor)
                if graph_type == "WEIGHTED_DIRECTED":
                    output.append(f'  "{node.get_name()}" -> "{neighbor.get_name()}" [label="{weight}"];\n')
                else:
                    output.append(f'  "{node.get_name()}" -- "{neighbor.get_name()}" [label="{weight}"];\n')
        
        output.append('}\n')
        
        with open(self._Dijkstra_traversal_output_file, 'w') as f:
            f.writelines(output)


    ##########################################################
    # Dijkstra algorithm
    ##########################################################

    def _get_unvisited_nodes_list(self):
        listnodes = self._g.list_of_nodes()
        self._distances = {node: float('infinity') for node in listnodes}
        for node, costing in self._distances.items():
            if node.get_name().__eq__(self._start_city_name):
                costing = 0.0
                heapq.heappush(self._priority_queue, (costing, node)) # start
                self._distances[node] = costing
            else:
                self._unvisited_nodes.add(node)

    def _Dijkstra(self):
        self._get_unvisited_nodes_list()
        
        while self._priority_queue: 
            current_cost, source_node = heapq.heappop(self._priority_queue)
            self._increment_work(1)

            for dest_node in source_node.fanout_of_a_node(): # 2, 4,
                w = source_node.node_get_fanout_node_weight(dest_node) 
                new_cost = current_cost + w

                if new_cost < self._distances[dest_node]:
                    heapq.heappush(self._priority_queue, (new_cost, dest_node))
                    self._distances[dest_node] = new_cost
                    self._increment_work(1)  

        # end
        for node, cost in self._distances.items():
            if cost == float('inf'):
                cost = -1.0
            self._cost.append(cost)

# %% [markdown]
# # BFS

# %%
############################################################
# GraphBfs.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

############################################################
# Breadth First search
###########################################################
class GraphBfs:
    def __init__(
        self,
        g: "graph",
        graph_name: "string",
        start_city_name: "string",
        end_city:"string",
        shortest_dist:'list of size 1',
        work: "list of size 1",
        bfs_traversal_output_file:"String",
        show: 'bool'
    ):
        ##NOTHING CAN BE CHANGED HERE
        self._g = g
        self._graph_name = graph_name
        self._start_city_name = start_city_name
        self._end_city = end_city
        self._shortest_dist = shortest_dist
        self._shortest_dist[0] = 0
        self._work = work
        self._work[0] = 0
        self._bfs_traversal_output_file = bfs_traversal_output_file
        self._show = show
        ## You can add any private data structures here
        self._a = {}  ## parallel dictionary. Key is node. Value is NodeData
        self._dq = Deque();
        self._bfsorder= []
        self._bfspath= {} #Dictionary. Key is node. Value is from(node)
        
        ## must write 3 routines
        self._bfs() 
        self._find_shortest_path()
        self._write_dot()
        
    ##########################################################
    # Write dot file of BFS traversal
    ##########################################################
    def _write_dot(self):
        print("Remove this line and WRITE CODE")


    ##########################################################
    # BFS
    #   TIME: THETA(V)
    #   SPACE:THETA(V)
    ##########################################################
    def _bfs(self):
           print("Remove this line and WRITE CODE")

  
    ##########################################################
    # Find shortest path from start city to every other city
    ##########################################################
    def _find_shortest_path(self)->'None':
        print("Remove this line and WRITE CODE")

# %% [markdown]
# ## NOTHING CAN BE CHANGED BELOW

# %% [markdown]
# # Graph Data

# %%
###########################################################
# Data.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
# All imports
###########################################################


class Data:
    def __init__(self, n: "string"):
        self._name = n  ### _name is used as key for this object
        self.age = 100  ## To show you can have anything,

    def __hash__(self):
        t = hash(self._name)
        return t

    def __eq__(self, other: "Node") -> "bool":
        if not isinstance(other, type(self)):
            assert False
        return self._name == other._name

    def __str__(self):
        return self._name

    def get_key(self) -> "string":
        return self._name

# %% [markdown]
# ## Graph Types

# %%
class GraphType(enum.Enum): 
    NONE = 0
    UNDIRECTED = 1
    DIRECTED = 2
    WEIGHTED_UNDIRECTED = 3
    WEIGHTED_DIRECTED  = 4

# %% [markdown]
# ## Graph class

# %%
############################################################
# Graph.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

############################################################
# NOTHING CAN BE CHANGED IN THIS FILE
###########################################################


############################################################
# Edge
# T can be number or name or user key
# Decision taken on other
# Must write __eq__ and __hash__
###########################################################
class Edge:
    def __init__(self, n: "Node", weight: float):
        # All keys below. 
        # Decision is taken based on key. Do not change key after inserted
        self._other = n  # _other is node
        # All values below
        # We can change these values
        self._weight = weight  # _weight is float

    ############################################################
    # All Public routines. YOU SHOULD ONLY CALL THESE ROUTINES
    ###########################################################
    def get_node(self) -> "Node":
        return self._other
    
    def get_name(self) -> "T":
        return self.get_node().get_name()

    def get_weight(self) -> float:
        return self._weight

    def change_weight(self, w: float) -> None:
        self._weight = w

    ############################################################
    # All Private routines. YOU SHOULD NOT CALL THESE ROUTINES
    ###########################################################

    #########  WRITE 5 below starts ################
    def _get_key(self)->'T':
        return self.get_name()

    def __hash__(self)->int:
        return (hash(self._get_key()))

    def __lt__(self, other:'Node')-> bool:
        if self._get_key() < other._get_key():
            return True
        else:
            return False

    def __eq__(self, other)-> bool:
        if (not(self < other) or (other < self)):
            return True
        return False

    def __ne__(self, other)-> bool:
        return (not(self == other))
        
    #########  WRITE 5 below ends ################


############################################################
# Node
# T can be number or name or user key
# Decision taken on T
# Must write __eq__ and __hash__
###########################################################
class Node:
    def __init__(self, T: "T"):
        # node data structures
        # All keys below. 
        # Decision is taken based on key. Do not change key after inserted
        self._item = T  # self._item is our key in hash/set
        # All values below
        # We can change these values
        self._fanins = {}  # dict of fanins of Node. Key is edge other node name, Value is Edge
        self._fanouts = {}  # dict of fanouts of Node. Key is edge other node name , Value is Edge

    ############################################################
    # All Public routines. YOU SHOULD ONLY CALL THESE ROUTINES
    ###########################################################
    def get_name(self) -> "T":
        return self._item

    def add_fan_out(self, e: "Edge") -> None:
        self._fanouts[e] = e

    def add_fan_in(self, e: "Edge") -> None:
        self._fanins[e] = e

    def num_fan_outs(self) -> "int":
        return len(self._fanouts)

    def num_fan_ins(self) -> "int":
        return len(self._fanins)

    def fanout_of_a_node_edges(self) -> "list of fanout edges":
        return list(self._fanouts.values())

    def fanout_of_a_node(self) -> "list of fanout Nodes":
        l = self.fanout_of_a_node_edges()
        n = []
        for edge in l:
            n.append(edge.get_node())
        return n

    def fanin_of_a_node_edges(self) -> "list of fanin edges":
        return list(self._fanins.values())

    def fanin_of_a_node(self) -> "list of fanin Nodes":
        l = self.fanin_of_a_node_edges()
        n = []
        for edge in l:
            n.append(edge.get_node())
        return n

    def node_has_fanout_edge(self, e: "Edge") -> "Edge or None":
        aedge = self._fanouts.get(e)
        if aedge:
            return aedge
        else:
            return None

    def node_has_fanout(self, e: "Edge") -> "Node or None":
        aedge = self.node_has_fanout_edge(e)
        return edge.get_node() if edge else None

    def node_has_fanin_edge(self, e: "Edge") -> "Edge or None":
        return self._fanins.get(e, None)

    def node_has_fanin(self, e: "Edge") -> "Node or None":
        aedge = self.node_has_fanin_edge(e)
        return aedge.get_node() if edge else None

    def node_get_fanout_node_weight(self, other_node: "Node") -> "float":
        nodename = self.get_name()
        aedge = self._fanouts.get(other_node)
        edgename = aedge.get_name()
        assert nodename != edgename
        return aedge.get_weight()

    def node_get_fanin_node_weight(self, other_node: "Node") -> "float":
        # edge = self._fanins.get(other_node.get_name(), None)
        # return edge.get_weight() if edge else -1
        nodename = self.get_name()
        aedge = self._fanins.get(other_node)
        edgename = aedge.get_name()
        assert nodename != edgename
        return aedge.get_weight()
        

    ############################################################
    # All Private routines. YOU SHOULD NOT CALL THESE ROUTINES
    ###########################################################

    #########  WRITE 5 below starts ################
    def _get_key(self) -> "T":
        return self.get_name()

    def __hash__(self) -> "int":
        return hash(self._get_key())

    def __lt__(self, other: 'Node') -> 'bool':
        return self._get_key() < other._get_key()

    def __eq__(self, other: 'Node') -> 'bool':
        # return self._get_key() == other._get_key()
        return (not(self < other)) and (not(other < self))

    def __ne__(self, other: 'Node') -> 'bool':
        return (not(self == other))

    #########  WRITE 5 below ends ################


class Graph:
    ##GRAPH DATA STRUCTURE
    def __init__(self,graphtype: "GraphType"):
        self._numE = 0  # Number of edges
        self._type = graphtype  # Graph type
        self._dict = {}  # Key is Node key, Value is Node


    ############################################################
    # All Public routines. YOU SHOULD ONLY CALL THESE ROUTINES
    ###########################################################
    
    def is_directed_graph(self) -> "bool":
        # return self._type in [GraphType.DIRECTED, GraphType.WEIGHTED_DIRECTED]
        if self._type == GraphType.DIRECTED:
            return True
        if self._type == GraphType.WEIGHTED_DIRECTED:
            return True
        return False

    def is_undirected_graph(self) -> "bool":
        # return self._type in [GraphType.UNDIRECTED, GraphType.WEIGHTED_UNDIRECTED]
        return not (self.is_directed_graph())

    def is_weighted_graph(self) -> "bool":
        # return self._type in [GraphType.WEIGHTED_DIRECTED, GraphType.WEIGHTED_UNDIRECTED]
        if self._type == GraphType.WEIGHTED_DIRECTED:
            return True
        if self._type == GraphType.WEIGHTED_UNDIRECTED:
            return True
        return False

    def get_graph_type(self) -> "GraphType":
        return self._type

    def get_graph_type_as_string(self) -> "string":
        t = self.get_graph_type()
        if t == GraphType.DIRECTED:
            return "DIRECTED GRAPH"
        if t == GraphType.UNDIRECTED:
            return "UNDIRECTED GRAPH"
        if t == GraphType.WEIGHTED_DIRECTED:
            return "WEIGHTED_DIRECTED GRAPH"
        if t == GraphType.WEIGHTED_UNDIRECTED:
            return "WEIGHTED_UNDIRECTED GRAPH"
        return "None"

    def get_numV(self) -> "int":
        return len(self._dict)

    def get_numE(self) -> "int":
        return self._numE  

    def list_of_nodes(self) -> "list of nodes":
        return list(self._dict.values())

    def build_node(self, name: 'T') -> "Node":
        return Node(name)

    def build_node_and_to_graph(self, name: 'T') -> "Node": #add to graph
        n = Node(name)
        self._add_node(n)
        return n

    def has_node(self, node: 'Node') -> "bool":
        return node.get_name() in self._dict

    def get_node(self, node: 'Node') -> 'Node':
        if self.has_node(node):
            n = self._dict[node.get_name()]  # correct key access
            assert n
            return n
        return None

    
    def add_edge(self,fname:'T', tname:'T', w:'float'):
        f = Node(fname)
        t = Node(tname)
        self._add_edge(f,t,w)
        
    ##########################################################
    # NOTHING CAN BE CHANGED IN THIS ROUTINE
    # if this passes means all your interface is right
    #  #Use this routine as a pattern for all other routine
    ##########################################################
    
    def dump(self, name):
        print("------------", name, "------------ ")
        print(self.get_graph_type())
        print("Num Vertices =", self.get_numV())
        print("Num Edges    =", self._numE)
        numedge = 0
        all_nodes = self.list_of_nodes()
        for node in all_nodes:
            n = node.get_name()
            print(n, "Fanouts: ", end="")
            f = node.num_fan_outs()
            if f == 0:
                print("NONE")
            else:
                fanout_nodes = node.fanout_of_a_node()
                j = 0
                for fnode in fanout_nodes:
                    numedge = numedge + 1
                    d = fnode.get_name()
                    if j < f - 1:
                        print(d, ",", sep="", end="")
                    else:
                        print(d)
                    j = j + 1
            print(n, "Fanins : ", end="")
            f = node.num_fan_ins()
            if f == 0:
                print("NONE")
            else:
                fanin_nodes = node.fanin_of_a_node()
                j = 0
                for fnode in fanin_nodes:
                    numedge = numedge + 1
                    d = fnode.get_name()
                    if j < f - 1:
                        print(d, ",", sep="", end="")
                    else:
                        print(d)
                    j = j + 1
        assert numedge/2 == self._numE

    ##########################################################
    # Nothing can be changed
    # TIME: THETA(V + E)
    # SPACE: THETA(V)
    ##########################################################
    def assert_dfs_passed(self, has_loop: "bool", dfs_order: "list of nodes"):
        t = self.get_graph_type()
        if (t == GraphType.UNDIRECTED) or (t == GraphType.WEIGHTED_UNDIRECTED):
            return
        if has_loop == False:
            set_of_visited_nodes = set()
            for n in dfs_order:
                ## Go on fanins of node
                fanins_of_n = n.fanin_of_a_node()
                for nf in fanins_of_n:
                    must_be_there = nf in set_of_visited_nodes  # find in THETA(1)
                    assert must_be_there
                set_of_visited_nodes.add(n)  # add in THETA(1)
            # All nodes must be visited
            assert len(set_of_visited_nodes) == self.get_numV()
            print("DFS ASSERT PASSED")

    ############################################################
    # All Private routines. YOU SHOULD NOT CALL THESE ROUTINES
    ###########################################################
    def _add_node(self, n:'Node')->"Node":
        storedn = self.get_node(n)
        if storedn:
            return storedn
        # self._dict[n] = n # because we have written what is key in node. Hash works.
        self._dict[n.get_name()] = n  # Store using node name as key
        storedn = self.get_node(n)
        assert storedn
        return storedn
        

    def _add_an_edge(self,f:'Node', t:'Node', fanout:'bool', w:'float'):
        # first discover whether its fanin or fanout
        # its with weight or without weight
        f = self._add_node(f)
        t = self._add_node(t)
        if fanout:
            e = f.node_has_fanout_edge(t)
            if e:
                ew = e.get_weight()
                if w < ew:
                    e.change_weight(w)
            else:
                # first time
                e = Edge(t, w)
                self._numE += 1
                f.add_fan_out(e)
        else:
            e = f.node_has_fanin_edge(t)
            if e:
                ew = e.get_weight()
                if w < ew:
                    e.change_weight(w)
            else:
                # first time
                e = Edge(t, w)
                # self._numE += 1
                f.add_fan_in(e)
        
    ##########################################################
    # Nothing can be changed in _add_edge
    # You must write _add_an_edge for this routine to work
    ##########################################################
    def _add_edge(self,f:'Node', t:'Node', w:'float'):
        self._add_an_edge(f,t,True,w) #fanout
        self._add_an_edge(t,f,False,w) #fanin
        # if (self._type == GraphType.UNDIRECTED) or (self._type == GraphType.WEIGHTED_UNDIRECTED):
        if self.is_undirected_graph():
            self._add_an_edge(t,f,True,w) #fanout
            self._add_an_edge(f,t,False,w) #fanin

    ############################################################
    ## All the routines written by students
    ##########################################################
    def build_graph(self, f: "file name"):
        b = GraphBuilder(self, f)  

    def write_dot(self, f):
        b = GraphDot(self, f)

    def show_dot_file(self, filename: "string"):
        with open(filename) as f:
            dot_graph = f.read()
        return dot_graph

    def dfs_using_time_stamp(
        self,
        gname: "string",
        dfs_order: "list of nodes",
        has_loop: "List of size 1 Boolean",
        work: "list of size 1",
        dfs_dot_output_file: "Traversal file name",
    ):

        b = GraphDfsUsingTimeStamp(
            self, gname, dfs_order, has_loop, work, dfs_dot_output_file
        )

    def bfs(
        self,
        gname: "graphname",
        start: "start city name",
        endt: "end city name",
        dist: "list of size 1",
        work: "list of size 1",
        ofile: "bfs_traversal_output_file",
        show: "bool",
    ):
        b = GraphBfs(self, gname, start, endt, dist, work, ofile, show)

    def Dijkstra(
        self,
        gname: "string",
        start_city: "String",
        cost: "list of cost",  # Caller will Fill. cost from start city to all other city.If not reachable -1
        work: "list of size 1",
        dijkstra_traversal_dot_output_file: "Traversal file name",
        show: "bool",
    ):
        b = GraphDijkstra(
            self,
            gname,
            start_city,
            cost,
            work,
            dijkstra_traversal_dot_output_file,
            show,
        )

# %% [markdown]
# # All testing routines here. Nothing can be changed
# # Use this routines to understand how to write testbench

# %% [markdown]
# # DFS TESTER

# %%
############################################################
# GraphDfsTest.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################
    
############################################################
# All imports
###########################################################
'''
from GraphType import *  ## #Otherwise, you cannot use GraphType
from Graph import *
from Data import *  ##User UDT
from GraphGlobal import *
'''


class GraphDfsTest:
    def __init__(self):
        self._show = True  # Change to True for debugging
        self._test_one()
        self._test()

    def _test1(self, gname: "graphname", graphtype: "GraphType", expected_has_loop: "Bool"):
        full_name = inputFileBase + gname + ".txt"

        print("Building graph", full_name)
        g = Graph(graphtype)
        g.build_graph(full_name)
        if self._show:
            g.dump(full_name)

        dot_output_file = outputFileBase + gname + ".dot"
        g.write_dot(dot_output_file)

        dfs_order = []  # Caller will Fill. List of Nodes
        has_loop = [False]  # List of size 1
        work = [0]  # List of size 1
        dfs_dot_output_file = outputFileBase + gname + "dfs.dot"
        g.dfs_using_time_stamp(gname, dfs_order, has_loop, work, dfs_dot_output_file)

        print("DFS traversal is in")
        print(dfs_dot_output_file)

        print("DFS ORDER: ", end=" ")
        for node in dfs_order:
            p1 = node.get_name()
            print(p1, end=" ")
        print()

        if has_loop[0]:
            print("LOOP")
        else:
            print("NOLOOP")
        print("Work Done", work[0])
        assert has_loop[0] == expected_has_loop
        g.assert_dfs_passed(has_loop[0],dfs_order)

    def _test_one(self):
        g = [
            ["1", GraphType.UNDIRECTED, False],
        ]

        for g1 in g:
            self._test1(g1[0], g1[1], g1[2])

    def _test(self):
        g = [
            ["u1", GraphType.UNDIRECTED, False],
            ["1", GraphType.UNDIRECTED, False],
            ["udf1", GraphType.DIRECTED, True],
            ["2", GraphType.DIRECTED, False],
            ["3", GraphType.DIRECTED, True],
            ["cat", GraphType.DIRECTED, False],
            ["7", GraphType.DIRECTED, False],
        ]

        for g1 in g:
            self._test1(g1[0], g1[1], g1[2])

# %% [markdown]
# # BFS Tester

# %%
############################################################
# GraphBfsTest.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################


class GraphBfsTest:
    def __init__(self):
        self._show = False  # Change to True for debugging
        self._test_one()
        #self._test()

    def _test1(self, gname: "graphname", graphtype: "GraphType", start: "start city name", endt: "end city name",edist:'int',show:'bool'):
        full_name = inputFileBase + gname + ".txt"
        print("Building graph", full_name)
        g = Graph(graphtype)
        g.build_graph(full_name)
        if self._show:
            g.dump(full_name)

        dot_output_file = outputFileBase + gname + ".dot"
        g.write_dot(dot_output_file)
        dist =[0] #Distance from start city to end city
        work = [0]  # List of size 1
        bfs_traversal_output_file = outputFileBase + gname + "bfs.dot"
        g.bfs(gname,start,endt, dist, work,bfs_traversal_output_file, show) ;
        assert(work[0] > 0)
        assert(dist[0] == edist)
        print("Work Done", work[0])
        print("Shortest Distance from",start, "to",endt, "is", dist[0])
        

    def _test_one(self):
        g = [
            ["5",GraphType.UNDIRECTED,"0","6",4,True] #name, directed/undirected, startcity, endcity,expected distance,show
        ]

        for g1 in g:
            self._test1(g1[0], g1[1], g1[2],g1[3],g1[4],g1[5])

    def _test(self):
        pass

# %% [markdown]
# # Dijkstra Tester

# %%
############################################################
# GraphDijkstraTest.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

class GraphGraphDijkstraTest:
    def __init__(self):
        self._show = False  # Change to True for debugging
        self._test()

    def _test(self):
        n = ["7", "loopparallel", "17", "hd1", "hd2", "hd3", "g1", "hd4", "hd5","hd6"]
        t = [
            GraphType.WEIGHTED_DIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
            GraphType.WEIGHTED_DIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
            GraphType.WEIGHTED_UNDIRECTED,
        ]
        s = ["0", "s", "A", "17", "60", "85", "P", "49","1","1"]  # starting city
        w0 = [0.0, 5.0, 3.0, 9.0, 13.0, 8.0, 7.0]
        w1 = [0.0, 1.0, 6.0, 7.0]  
        w2 = [2.0, 7.0, 5.0, 1.0, 3.0, 7.0, 0.0]
        w3 = [
            20.0,
            22.0,
            25.0,
            27.0,
            25.0,
            68.0,
            86.0,
            39.0,
            70.0,
            36.0,
            53.0,
            91.0,
            35.0,
            88.0,
            30.0,
            43.0,
            0.0,
            54.0,
            74.0,
            41.0,
        ]
        w4 = [
            9.0,
            13.0,
            8.0,
            10.0,
            8.0,
            5.0,
            8.0,
            5.0,
            12.0,
            1.0,
            7.0,
            15.0,
            4.0,
            8.0,
            9.0,
            4.0,
            11.0,
            1.0,
            4.0,
            12.0,
            9.0,
            11.0,
            7.0,
            9.0,
            10.0,
            9.0,
            7.0,
            10.0,
            5.0,
            10.0,
            11.0,
            9.0,
            1.0,
            7.0,
            12.0,
            6.0,
            12.0,
            15.0,
            10.0,
            11.0,
            15.0,
            6.0,
            10.0,
            7.0,
            9.0,
            7.0,
            7.0,
            14.0,
            5.0,
            13.0,
            8.0,
            8.0,
            10.0,
            7.0,
            4.0,
            6.0,
            3.0,
            8.0,
            11.0,
            11.0,
            12.0,
            4.0,
            9.0,
            9.0,
            7.0,
            7.0,
            7.0,
            0.0,
            13.0,
            6.0,
            7.0,
            8.0,
            8.0,
            3.0,
            5.0,
            6.0,
            11.0,
            5.0,
        ]
        w5 = [
            154.0,
            98.0,
            90.0,
            49.0,
            186.0,
            190.0,
            178.0,
            114.0,
            123.0,
            -1.0,
            -1.0,
            -1.0,
            123.0,
            -1.0,
            104.0,
            -1.0,
            -1.0,
            -1.0,
            207.0,
            134.0,
            123.0,
            75.0,
            155.0,
            -1.0,
            198.0,
            68.0,
            90.0,
            170.0,
            135.0,
            -1.0,
            103.0,
            145.0,
            -1.0,
            54.0,
            111.0,
            163.0,
            173.0,
            115.0,
            87.0,
            159.0,
            -1.0,
            94.0,
            102.0,
            -1.0,
            76.0,
            67.0,
            167.0,
            138.0,
            216.0,
            -1.0,
            172.0,
            102.0,
            212.0,
            163.0,
            103.0,
            112.0,
            -1.0,
            182.0,
            145.0,
            92.0,
            -1.0,
            -1.0,
            194.0,
            -1.0,
            182.0,
            -1.0,
            201.0,
            96.0,
            -1.0,
            85.0,
            121.0,
            108.0,
            161.0,
            130.0,
            100.0,
            120.0,
            -1.0,
            118.0,
            215.0,
            92.0,
            156.0,
            162.0,
            163.0,
            168.0,
            0.0,
            71.0,
            110.0,
            -1.0,
            -1.0,
            190.0,
            217.0,
            100.0,
            105.0,
            178.0,
        ]
        w6 = [0.0, 1.0, 4.0, 4.0, 2.0, 3.0]

        h4 = [13.0, 20.0, 30.0, 17.0, 17.0, 34.0, 33.0, 16.0, 16.0, 9.0, 11.0, 31.0, 21.0, 34.0, 19.0, 14.0, 23.0, 20.0, 42.0, 21.0, 15.0, 19.0, 24.0, 15.0, 34.0, 42.0, 27.0, 0, 10.0, 15.0, 16.0, 18.0, 19.0, 18.0, 14.0, 21.0, 21.0, 28.0, 21.0, 19.0, 45.0, 26.0, 27.0, 20.0, 16.0, 23.0, 28.0, 22.0, 27.0, 18.0, 22.0, 21.0, 11.0, 18.0, 22.0, 14.0, 26.0, 27.0, 27.0, 17.0, 24.0, 17.0, 17.0, 22.0, 12.0, 21.0, 10.0, 25.0]          
        h5 = [0, 8.0, 3.0, 11.0, 6.0, 8.0, 7.0, 6.0, 12.0, 12.0, 10.0, 9.0, 18.0, 12.0, 4.0, 8.0, 1.0, 3.0, 1.0, 2.0, 10.0, 8.0, 5.0, 6.0, 9.0, 17.0, 11.0, 8.0]
        h6 = [0, 6.0, 3.0, 3.0, 4.0, 3.0, 5.0, 3.0, 3.0, 4.0, 6.0, 5.0, 5.0, 4.0, 4.0, 1.0, 4.0, 5.0, 7.0, 6.0, 6.0, 4.0, 4.0, 4.0, 1.0, 4.0, 5.0, 7.0, 5.0, 2.0, 4.0, 5.0, 5.0, 3.0, 5.0, 6.0, 5.0, 4.0, 5.0, 3.0, 5.0, 5.0, 6.0, 4.0, 5.0, 5.0, 3.0, 6.0, 6.0, 5.0, 3.0, 6.0, 7.0, 5.0, 2.0, 6.0, 6.0, 4.0, 4.0, 3.0, 4.0, 5.0, 3.0, 6.0, 5.0, 3.0, 3.0, 4.0, 7.0, 2.0, 4.0, 6.0, 5.0, 2.0, 2.0, 6.0, 4.0, 6.0, 4.0, 5.0, 3.0, 4.0, 4.0, 4.0, 2.0, 1.0, 3.0, 3.0]
        
        w = [w0, w1, w2, w3, w4, w5, w6,h4,h5,h6]

        n1 = len(n)
        t1 = len(t)
        s1 = len(s)
        d1 = len(w)
        assert n1 == t1
        assert n1 == s1
        assert n1 == d1
        for i in range(n1):
            gname = n[i]
            start_city = s[i]
            expected_cost_array = w[i]
            print("------------- ", gname, " ------------")
            full_name = inputFileBase + gname + ".txt"
            g = Graph(t[i])
            g.build_graph(full_name)
            if self._show:
                g.dump(full_name)
                dot_output_file = outputFileBase + gname + ".dot"
                g.write_dot(dot_output_file)

            cost = (
                []
            )  # Caller will Fill. cost from start city to all other city.If not reachable -1
            work = [0]  # List of size 1
            dijkstra_traversal_dot_output_file = outputFileBase + gname + "dijkstra.dot"
            show = False
            if g.get_numV() < 21:
                show = True
            g.Dijkstra(
                gname, start_city, cost, work, dijkstra_traversal_dot_output_file, show
            )
            # assert answers
            print("Expected cost = ", expected_cost_array)
            print("Your answer    = ", cost)
            assert len(cost) == len(expected_cost_array)
            x = 0
            for j in range(len(cost)):
                if cost[j] != expected_cost_array[j]:
                    x = x + 1
            print("Failed ", x)
            assert x == 0  # NO failure can happen

# %%
# Graph Representation Tester
class GraphRepresentationTest:
    def __init__(self):
        self._test()

    def _u1(self):
        name = "13"
        f = inputFileBase + name + ".txt"
        g = Graph(GraphType.UNDIRECTED)
        g.build_graph(f)
        g.dump(name)
        file = outputFileBase + name + ".dot"
        g.write_dot(file)
        Source(read_dot_file(name))
        assert g.get_numV() == 7
        assert g.get_numE() == 24

    def _uw1(self):
        name = "14"
        f = inputFileBase + name + ".txt"
        g = Graph(GraphType.WEIGHTED_UNDIRECTED)
        g.build_graph(f)
        g.dump(name)
        file = outputFileBase + name + ".dot"
        g.write_dot(file)
        Source(read_dot_file(name))
        assert g.get_numV() == 6
        assert g.get_numE() == 20

    def _d1(self):
        name = "15"
        f = inputFileBase + name + ".txt"
        g = Graph(GraphType.DIRECTED)
        g.build_graph(f)
        g.dump(name)
        file = outputFileBase + name + ".dot"
        g.write_dot(file)
        Source(read_dot_file(name))
        assert g.get_numV() == 6
        assert g.get_numE() == 6

    def _dw1(self):
        name = "16"
        f = inputFileBase + name + ".txt"
        g = Graph(GraphType.WEIGHTED_DIRECTED)
        g.build_graph(f)
        g.dump(name)
        file = outputFileBase + name + ".dot"
        g.write_dot(file)
        Source(read_dot_file(name))
        assert g.get_numV() == 5
        assert g.get_numE() == 6

    def _DAG(self):
        name = "cat"
        f = inputFileBase + name + ".txt"
        g = Graph(GraphType.DIRECTED)
        g.build_graph(f)
        g.dump(name)
        # g.show_graph()
        file = outputFileBase + name + ".dot"
        g.write_dot(file)
        Source(read_dot_file(name))
        assert g.get_numV() == 6
        assert g.get_numE() == 7

    def _loop(self):
        name = "loopparallel"
        f = inputFileBase + name + ".txt"
        g = Graph(GraphType.WEIGHTED_DIRECTED)
        g.build_graph(f)
        g.dump(name)
        # g.show_graph()
        file = outputFileBase + name + ".dot"
        g.write_dot(file)
        Source(read_dot_file(name))
        assert g.get_numV() == 4
        assert g.get_numE() == 3

    def _test(self):
        self._u1()
        self._uw1()
        self._d1()
        self._dw1()
        self._DAG()
        self._loop()

# %% [markdown]
# # Graph tester

# %%
############################################################
# GraphTest.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

class GraphTest:
    def __init__(self):
        pass

    def RepresentationTest(self):
        t = GraphRepresentationTest()

    def DFS(self):
        t = GraphDfsTest()

    def BFS(self):
        t = GraphBfsTest()

    def Dijkstra(self):
        t = GraphGraphDijkstraTest()

# %% [markdown]
# # Main

# %%
############################################################
# main
# YOU CANNOT CHANGE ANYTHING BELOW
###########################################################
def main():
    print(sys.version)
    t = GraphTest()
    a = [0, 0, 0, 1]
    if a[0]:
        t.RepresentationTest()
        print("test_graph_representation Passed")
    if a[1]:
        t.DFS()
        print("DFS Passed")
    if a[2]:
        t.BFS() #must fix. Not  completely coded
        print("BFS Passed")
    if a[3]:
        t.Dijkstra()
        print("Dijkstra Passed. You are genius if all tests are passed")
        print("Can you rate me at: https://www.linkedin.com/in/jagadeesh-vasudevamurthy-6796591/")

# %% [markdown]
# # call Main

# %%
############################################################
# start up
###########################################################
if (__name__  == '__main__'):
    main()
# Out:
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 10:07:17) [Clang 14.0.6 ]
# -------------  7  ------------
# Expected cost =  [0.0, 5.0, 3.0, 9.0, 13.0, 8.0, 7.0]
# Your answer    =  [0.0, 5.0, 3.0, 9.0, 13.0, 8.0, 7.0]
# Failed  0
# -------------  loopparallel  ------------
# Expected cost =  [0.0, 1.0, 6.0, 7.0]
# Your answer    =  [0.0, 1.0, 6.0, 7.0]
# Failed  0
# -------------  17  ------------
# Expected cost =  [2.0, 7.0, 5.0, 1.0, 3.0, 7.0, 0.0]
# Your answer    =  [2.0, 7.0, 5.0, 1.0, 3.0, 7.0, 0.0]
# Failed  0
# -------------  hd1  ------------
# Expected cost =  [20.0, 22.0, 25.0, 27.0, 25.0, 68.0, 86.0, 39.0, 70.0, 36.0, 53.0, 91.0, 35.0, 88.0, 30.0, 43.0, 0.0, 54.0, 74.0, 41.0]
# Your answer    =  [20.0, 22.0, 25.0, 27.0, 25.0, 68.0, 86.0, 39.0, 70.0, 36.0, 53.0, 91.0, 35.0, 88.0, 30.0, 43.0, 0.0, 54.0, 74.0, 41.0]
# Failed  0
# -------------  hd2  ------------
# Expected cost =  [9.0, 13.0, 8.0, 10.0, 8.0, 5.0, 8.0, 5.0, 12.0, 1.0, 7.0, 15.0, 4.0, 8.0, 9.0, 4.0, 11.0, 1.0, 4.0, 12.0, 9.0, 11.0, 7.0, 9.0, 10.0, 9.0, 7.0, 10.0, 5.0, 10.0, 11.0, 9.0, 1.0, 7.0, 12.0, 6.0, 12.0, 15.0, 10.0, 11.0, 15.0, 6.0, 10.0, 7.0, 9.0, 7.0, 7.0, 14.0, 5.0, 13.0, 8.0, 8.0, 10.0, 7.0, 4.0, 6.0, 3.0, 8.0, 11.0, 11.0, 12.0, 4.0, 9.0, 9.0, 7.0, 7.0, 7.0, 0.0, 13.0, 6.0, 7.0, 8.0, 8.0, 3.0, 5.0, 6.0, 11.0, 5.0]
# Your answer    =  [9.0, 13.0, 8.0, 10.0, 8.0, 5.0, 8.0, 5.0, 12.0, 1.0, 7.0, 15.0, 4.0, 8.0, 9.0, 4.0, 11.0, 1.0, 4.0, 12.0, 9.0, 11.0, 7.0, 9.0, 10.0, 9.0, 7.0, 10.0, 5.0, 10.0, 11.0, 9.0, 1.0, 7.0, 12.0, 6.0, 12.0, 15.0, 10.0, 11.0, 15.0, 6.0, 10.0, 7.0, 9.0, 7.0, 7.0, 14.0, 5.0, 13.0, 8.0, 8.0, 10.0, 7.0, 4.0, 6.0, 3.0, 8.0, 11.0, 11.0, 12.0, 4.0, 9.0, 9.0, 7.0, 7.0, 7.0, 0.0, 13.0, 6.0, 7.0, 8.0, 8.0, 3.0, 5.0, 6.0, 11.0, 5.0]
# Failed  0
# -------------  hd3  ------------
# Expected cost =  [154.0, 98.0, 90.0, 49.0, 186.0, 190.0, 178.0, 114.0, 123.0, -1.0, -1.0, -1.0, 123.0, -1.0, 104.0, -1.0, -1.0, -1.0, 207.0, 134.0, 123.0, 75.0, 155.0, -1.0, 198.0, 68.0, 90.0, 170.0, 135.0, -1.0, 103.0, 145.0, -1.0, 54.0, 111.0, 163.0, 173.0, 115.0, 87.0, 159.0, -1.0, 94.0, 102.0, -1.0, 76.0, 67.0, 167.0, 138.0, 216.0, -1.0, 172.0, 102.0, 212.0, 163.0, 103.0, 112.0, -1.0, 182.0, 145.0, 92.0, -1.0, -1.0, 194.0, -1.0, 182.0, -1.0, 201.0, 96.0, -1.0, 85.0, 121.0, 108.0, 161.0, 130.0, 100.0, 120.0, -1.0, 118.0, 215.0, 92.0, 156.0, 162.0, 163.0, 168.0, 0.0, 71.0, 110.0, -1.0, -1.0, 190.0, 217.0, 100.0, 105.0, 178.0]
# Your answer    =  [154.0, 98.0, 90.0, 49.0, 186.0, 190.0, 178.0, 114.0, 123.0, -1.0, -1.0, -1.0, 123.0, -1.0, 104.0, -1.0, -1.0, -1.0, 207.0, 134.0, 123.0, 75.0, 155.0, -1.0, 198.0, 68.0, 90.0, 170.0, 135.0, -1.0, 103.0, 145.0, -1.0, 54.0, 111.0, 163.0, 173.0, 115.0, 87.0, 159.0, -1.0, 94.0, 102.0, -1.0, 76.0, 67.0, 167.0, 138.0, 216.0, -1.0, 172.0, 102.0, 212.0, 163.0, 103.0, 112.0, -1.0, 182.0, 145.0, 92.0, -1.0, -1.0, 194.0, -1.0, 182.0, -1.0, 201.0, 96.0, -1.0, 85.0, 121.0, 108.0, 161.0, 130.0, 100.0, 120.0, -1.0, 118.0, 215.0, 92.0, 156.0, 162.0, 163.0, 168.0, 0.0, 71.0, 110.0, -1.0, -1.0, 190.0, 217.0, 100.0, 105.0, 178.0]
# Failed  0
# -------------  g1  ------------
# Expected cost =  [0.0, 1.0, 4.0, 4.0, 2.0, 3.0]
# Your answer    =  [0.0, 1.0, 4.0, 4.0, 2.0, 3.0]
# Failed  0
# -------------  hd4  ------------
# Expected cost =  [13.0, 20.0, 30.0, 17.0, 17.0, 34.0, 33.0, 16.0, 16.0, 9.0, 11.0, 31.0, 21.0, 34.0, 19.0, 14.0, 23.0, 20.0, 42.0, 21.0, 15.0, 19.0, 24.0, 15.0, 34.0, 42.0, 27.0, 0, 10.0, 15.0, 16.0, 18.0, 19.0, 18.0, 14.0, 21.0, 21.0, 28.0, 21.0, 19.0, 45.0, 26.0, 27.0, 20.0, 16.0, 23.0, 28.0, 22.0, 27.0, 18.0, 22.0, 21.0, 11.0, 18.0, 22.0, 14.0, 26.0, 27.0, 27.0, 17.0, 24.0, 17.0, 17.0, 22.0, 12.0, 21.0, 10.0, 25.0]
# Your answer    =  [13.0, 20.0, 30.0, 17.0, 17.0, 34.0, 33.0, 16.0, 16.0, 9.0, 11.0, 31.0, 21.0, 34.0, 19.0, 14.0, 23.0, 20.0, 42.0, 21.0, 15.0, 19.0, 24.0, 15.0, 34.0, 42.0, 27.0, 0.0, 10.0, 15.0, 16.0, 18.0, 19.0, 18.0, 14.0, 21.0, 21.0, 28.0, 21.0, 19.0, 45.0, 26.0, 27.0, 20.0, 16.0, 23.0, 28.0, 22.0, 27.0, 18.0, 22.0, 21.0, 11.0, 18.0, 22.0, 14.0, 26.0, 27.0, 27.0, 17.0, 24.0, 17.0, 17.0, 22.0, 12.0, 21.0, 10.0, 25.0]
# Failed  0
# -------------  hd5  ------------
# Expected cost =  [0, 8.0, 3.0, 11.0, 6.0, 8.0, 7.0, 6.0, 12.0, 12.0, 10.0, 9.0, 18.0, 12.0, 4.0, 8.0, 1.0, 3.0, 1.0, 2.0, 10.0, 8.0, 5.0, 6.0, 9.0, 17.0, 11.0, 8.0]
# Your answer    =  [0.0, 8.0, 3.0, 11.0, 6.0, 8.0, 7.0, 6.0, 12.0, 12.0, 10.0, 9.0, 18.0, 12.0, 4.0, 8.0, 1.0, 3.0, 1.0, 2.0, 10.0, 8.0, 5.0, 6.0, 9.0, 17.0, 11.0, 8.0]
# Failed  0
# -------------  hd6  ------------
# Expected cost =  [0, 6.0, 3.0, 3.0, 4.0, 3.0, 5.0, 3.0, 3.0, 4.0, 6.0, 5.0, 5.0, 4.0, 4.0, 1.0, 4.0, 5.0, 7.0, 6.0, 6.0, 4.0, 4.0, 4.0, 1.0, 4.0, 5.0, 7.0, 5.0, 2.0, 4.0, 5.0, 5.0, 3.0, 5.0, 6.0, 5.0, 4.0, 5.0, 3.0, 5.0, 5.0, 6.0, 4.0, 5.0, 5.0, 3.0, 6.0, 6.0, 5.0, 3.0, 6.0, 7.0, 5.0, 2.0, 6.0, 6.0, 4.0, 4.0, 3.0, 4.0, 5.0, 3.0, 6.0, 5.0, 3.0, 3.0, 4.0, 7.0, 2.0, 4.0, 6.0, 5.0, 2.0, 2.0, 6.0, 4.0, 6.0, 4.0, 5.0, 3.0, 4.0, 4.0, 4.0, 2.0, 1.0, 3.0, 3.0]
# Your answer    =  [0.0, 6.0, 3.0, 3.0, 4.0, 3.0, 5.0, 3.0, 3.0, 4.0, 6.0, 5.0, 5.0, 4.0, 4.0, 1.0, 4.0, 5.0, 7.0, 6.0, 6.0, 4.0, 4.0, 4.0, 1.0, 4.0, 5.0, 7.0, 5.0, 2.0, 4.0, 5.0, 5.0, 3.0, 5.0, 6.0, 5.0, 4.0, 5.0, 3.0, 5.0, 5.0, 6.0, 4.0, 5.0, 5.0, 3.0, 6.0, 6.0, 5.0, 3.0, 6.0, 7.0, 5.0, 2.0, 6.0, 6.0, 4.0, 4.0, 3.0, 4.0, 5.0, 3.0, 6.0, 5.0, 3.0, 3.0, 4.0, 7.0, 2.0, 4.0, 6.0, 5.0, 2.0, 2.0, 6.0, 4.0, 6.0, 4.0, 5.0, 3.0, 4.0, 4.0, 4.0, 2.0, 1.0, 3.0, 3.0]
# Failed  0
# Dijkstra Passed. You are genius if all tests are passed
# Can you rate me at: https://www.linkedin.com/in/jagadeesh-vasudevamurthy-6796591/

# %% [markdown]
# # Uncomment Only Lines

# %%
# Source(read_dot_file("1"))

# %%
# Source(read_dot_file("14"))

# %%
# Source(read_dot_file("15"))

# %%
# Source(read_dot_file("16"))

# %%
# Source(read_dot_file("cat"))

# %%
# Source(read_dot_file("loopparallel"))

# %% [markdown]
# # DFS TRAVERSAL

# %%
# Source(read_dot_file("u1dfs"))

# %%
# Source(read_dot_file("1dfs"))

# %%
# Source(read_dot_file("udf1dfs"))

# %%
# Source(read_dot_file("2dfs"))

# %%
# Source(read_dot_file("3dfs"))

# %%
# Source(read_dot_file("catdfs"))

# %%
# Source(read_dot_file("7dfs"))

# %% [markdown]
# # Dijiktra

# %%
#         n = ["7", "loopparallel", "17", "hd1", "hd2", "hd3", "g1", "hd4", "hd5","hd6"]
Source(read_dot_file("7dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/7dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "0" [label="0 (0.0)"];
#   "2" [label="2 (5.0)"];
#   "3" [label="3 (3.0)"];
#   "1" [label="1 (9.0)"];
#   "6" [label="6 (13.0)"];
#   "4" [label="4 (8.0)"];
#   "5" [label="5 (7.0)"];
#   "0" -- "2" [label="5.0"];
#   "0" -- "3" [label="3.0"];
#   "0" -- "1" [label="14.0"];
#   "2" -- "5" [label="2.0"];
#   "2" -- "4" [label="3.0"];
#   "3" -- "2" [label="11.0"];
#   "3" -- "4" [label="7.0"];
#   "3" -- "1" [label="6.0"];
#   "1" -- "6" [label="6.0"];
#   "1" -- "4" [label="7.0"];
#   "4" -- "6" [label="5.0"];
#   "5" -- "6" [label="7.0"];
# }

# %%
Source(read_dot_file("loopparalleldijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/loopparalleldijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "s" [label="s (0.0)"];
#   "0" [label="0 (1.0)"];
#   "1" [label="1 (6.0)"];
#   "t" [label="t (7.0)"];
#   "s" -- "0" [label="1.0"];
#   "0" -- "s" [label="1.0"];
#   "0" -- "1" [label="5.0"];
#   "1" -- "0" [label="5.0"];
#   "1" -- "t" [label="1.0"];
#   "t" -- "1" [label="1.0"];
# }

# %%
Source(read_dot_file("17dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/17dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "C" [label="C (2.0)"];
#   "D" [label="D (7.0)"];
#   "E" [label="E (5.0)"];
#   "B" [label="B (1.0)"];
#   "G" [label="G (3.0)"];
#   "F" [label="F (7.0)"];
#   "A" [label="A (0.0)"];
#   "C" -- "D" [label="9.0"];
#   "C" -- "E" [label="3.0"];
#   "C" -- "B" [label="1.0"];
#   "C" -- "A" [label="3.0"];
#   "D" -- "C" [label="9.0"];
#   "D" -- "E" [label="2.0"];
#   "D" -- "G" [label="12.0"];
#   "D" -- "F" [label="1.0"];
#   "E" -- "C" [label="3.0"];
#   "E" -- "D" [label="2.0"];
#   "E" -- "B" [label="5.0"];
#   "E" -- "F" [label="2.0"];
#   "B" -- "C" [label="1.0"];
#   "B" -- "E" [label="5.0"];
#   "B" -- "G" [label="2.0"];
#   "B" -- "A" [label="1.0"];
#   "G" -- "D" [label="12.0"];
#   "G" -- "B" [label="2.0"];
#   "F" -- "D" [label="1.0"];
#   "F" -- "E" [label="2.0"];
#   "F" -- "A" [label="10.0"];
#   "A" -- "B" [label="1.0"];
#   "A" -- "C" [label="3.0"];
#   "A" -- "F" [label="10.0"];
# }

# %%
Source(read_dot_file("hd1dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/hd1dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "1" [label="1 (20.0)"];
#   "7" [label="7 (22.0)"];
#   "2" [label="2 (25.0)"];
#   "14" [label="14 (27.0)"];
#   "3" [label="3 (25.0)"];
#   "4" [label="4 (68.0)"];
#   "5" [label="5 (86.0)"];
#   "6" [label="6 (39.0)"];
#   "8" [label="8 (70.0)"];
#   "9" [label="9 (36.0)"];
#   "10" [label="10 (53.0)"];
#   "11" [label="11 (91.0)"];
#   "12" [label="12 (35.0)"];
#   "13" [label="13 (88.0)"];
#   "15" [label="15 (30.0)"];
#   "16" [label="16 (43.0)"];
#   "17" [label="17 (0.0)"];
#   "18" [label="18 (54.0)"];
#   "19" [label="19 (74.0)"];
#   "20" [label="20 (41.0)"];
#   "1" -- "7" [label="2.0"];
#   "1" -- "4" [label="48.0"];
#   "1" -- "5" [label="66.0"];
#   "1" -- "9" [label="16.0"];
#   "1" -- "10" [label="33.0"];
#   "1" -- "17" [label="20.0"];
#   "1" -- "18" [label="34.0"];
#   "1" -- "15" [label="34.0"];
#   "1" -- "12" [label="24.0"];
#   "1" -- "2" [label="5.0"];
#   "1" -- "3" [label="5.0"];
#   "7" -- "1" [label="2.0"];
#   "7" -- "3" [label="10.0"];
#   "7" -- "6" [label="17.0"];
#   "7" -- "14" [label="15.0"];
#   "7" -- "13" [label="66.0"];
#   "7" -- "16" [label="21.0"];
#   "7" -- "19" [label="52.0"];
#   "7" -- "9" [label="16.0"];
#   "7" -- "12" [label="13.0"];
#   "2" -- "14" [label="15.0"];
#   "2" -- "1" [label="5.0"];
#   "14" -- "2" [label="15.0"];
#   "14" -- "7" [label="15.0"];
#   "14" -- "8" [label="43.0"];
#   "14" -- "11" [label="64.0"];
#   "14" -- "12" [label="19.0"];
#   "14" -- "15" [label="3.0"];
#   "14" -- "20" [label="14.0"];
#   "14" -- "9" [label="9.0"];
#   "14" -- "3" [label="2.0"];
#   "14" -- "6" [label="26.0"];
#   "3" -- "7" [label="10.0"];
#   "3" -- "1" [label="5.0"];
#   "3" -- "14" [label="2.0"];
#   "4" -- "1" [label="48.0"];
#   "5" -- "1" [label="66.0"];
#   "6" -- "7" [label="17.0"];
#   "6" -- "14" [label="26.0"];
#   "8" -- "14" [label="43.0"];
#   "9" -- "1" [label="16.0"];
#   "9" -- "14" [label="9.0"];
#   "9" -- "7" [label="16.0"];
#   "10" -- "1" [label="33.0"];
#   "11" -- "14" [label="64.0"];
#   "12" -- "14" [label="19.0"];
#   "12" -- "1" [label="24.0"];
#   "12" -- "7" [label="13.0"];
#   "13" -- "7" [label="66.0"];
#   "15" -- "14" [label="3.0"];
#   "15" -- "1" [label="34.0"];
#   "16" -- "7" [label="21.0"];
#   "17" -- "1" [label="20.0"];
#   "18" -- "1" [label="34.0"];
#   "19" -- "7" [label="52.0"];
#   "20" -- "14" [label="14.0"];
# }

# %%
Source(read_dot_file("hd2dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/hd2dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "1" [label="1 (9.0)"];
#   "49" [label="49 (13.0)"];
#   "2" [label="2 (8.0)"];
#   "75" [label="75 (10.0)"];
#   "3" [label="3 (8.0)"];
#   "47" [label="47 (5.0)"];
#   "4" [label="4 (8.0)"];
#   "46" [label="46 (5.0)"];
#   "5" [label="5 (12.0)"];
#   "50" [label="50 (1.0)"];
#   "6" [label="6 (7.0)"];
#   "7" [label="7 (15.0)"];
#   "18" [label="18 (4.0)"];
#   "8" [label="8 (8.0)"];
#   "31" [label="31 (9.0)"];
#   "9" [label="9 (4.0)"];
#   "78" [label="78 (11.0)"];
#   "10" [label="10 (1.0)"];
#   "15" [label="15 (4.0)"];
#   "11" [label="11 (12.0)"];
#   "12" [label="12 (9.0)"];
#   "23" [label="23 (11.0)"];
#   "13" [label="13 (7.0)"];
#   "48" [label="48 (9.0)"];
#   "14" [label="14 (10.0)"];
#   "33" [label="33 (9.0)"];
#   "22" [label="22 (7.0)"];
#   "16" [label="16 (10.0)"];
#   "27" [label="27 (5.0)"];
#   "17" [label="17 (10.0)"];
#   "32" [label="32 (11.0)"];
#   "65" [label="65 (9.0)"];
#   "19" [label="19 (1.0)"];
#   "20" [label="20 (7.0)"];
#   "21" [label="21 (12.0)"];
#   "39" [label="39 (6.0)"];
#   "24" [label="24 (12.0)"];
#   "25" [label="25 (15.0)"];
#   "26" [label="26 (10.0)"];
#   "28" [label="28 (11.0)"];
#   "73" [label="73 (15.0)"];
#   "29" [label="29 (6.0)"];
#   "62" [label="62 (10.0)"];
#   "30" [label="30 (7.0)"];
#   "44" [label="44 (9.0)"];
#   "34" [label="34 (7.0)"];
#   "35" [label="35 (7.0)"];
#   "36" [label="36 (14.0)"];
#   "37" [label="37 (5.0)"];
#   "38" [label="38 (13.0)"];
#   "51" [label="51 (8.0)"];
#   "40" [label="40 (8.0)"];
#   "41" [label="41 (10.0)"];
#   "42" [label="42 (7.0)"];
#   "43" [label="43 (4.0)"];
#   "55" [label="55 (6.0)"];
#   "45" [label="45 (3.0)"];
#   "58" [label="58 (8.0)"];
#   "59" [label="59 (11.0)"];
#   "52" [label="52 (11.0)"];
#   "68" [label="68 (12.0)"];
#   "53" [label="53 (4.0)"];
#   "54" [label="54 (9.0)"];
#   "67" [label="67 (9.0)"];
#   "72" [label="72 (7.0)"];
#   "56" [label="56 (7.0)"];
#   "57" [label="57 (7.0)"];
#   "60" [label="60 (0.0)"];
#   "66" [label="66 (13.0)"];
#   "61" [label="61 (6.0)"];
#   "63" [label="63 (7.0)"];
#   "64" [label="64 (8.0)"];
#   "69" [label="69 (8.0)"];
#   "70" [label="70 (3.0)"];
#   "71" [label="71 (5.0)"];
#   "74" [label="74 (6.0)"];
#   "76" [label="76 (11.0)"];
#   "77" [label="77 (5.0)"];
#   "1" -- "49" [label="8.0"];
#   "1" -- "75" [label="14.0"];
#   "1" -- "78" [label="5.0"];
#   "1" -- "20" [label="28.0"];
#   "1" -- "2" [label="35.0"];
#   "1" -- "12" [label="31.0"];
#   "1" -- "5" [label="3.0"];
#   "1" -- "40" [label="2.0"];
#   "1" -- "58" [label="12.0"];
#   "1" -- "44" [label="23.0"];
#   "1" -- "77" [label="19.0"];
#   "1" -- "62" [label="46.0"];
#   "1" -- "55" [label="45.0"];
#   "1" -- "60" [label="9.0"];
#   "1" -- "29" [label="9.0"];
#   "1" -- "71" [label="29.0"];
#   "1" -- "41" [label="14.0"];
#   "1" -- "4" [label="31.0"];
#   "1" -- "18" [label="21.0"];
#   "1" -- "51" [label="3.0"];
#   "1" -- "64" [label="13.0"];
#   "1" -- "73" [label="22.0"];
#   "1" -- "50" [label="8.0"];
#   "1" -- "27" [label="22.0"];
#   "1" -- "74" [label="46.0"];
#   "1" -- "53" [label="14.0"];
#   "1" -- "11" [label="44.0"];
#   "1" -- "67" [label="37.0"];
#   "1" -- "9" [label="20.0"];
#   "1" -- "26" [label="2.0"];
#   "1" -- "33" [label="24.0"];
#   "1" -- "10" [label="31.0"];
#   "1" -- "56" [label="14.0"];
#   "1" -- "31" [label="34.0"];
#   "1" -- "28" [label="2.0"];
#   "1" -- "63" [label="43.0"];
#   "1" -- "48" [label="21.0"];
#   "1" -- "30" [label="40.0"];
#   "1" -- "35" [label="4.0"];
#   "1" -- "7" [label="12.0"];
#   "1" -- "13" [label="5.0"];
#   "1" -- "24" [label="31.0"];
#   "1" -- "52" [label="42.0"];
#   "1" -- "57" [label="29.0"];
#   "1" -- "8" [label="34.0"];
#   "49" -- "1" [label="8.0"];
#   "49" -- "40" [label="16.0"];
#   "49" -- "50" [label="18.0"];
#   "49" -- "66" [label="17.0"];
#   "49" -- "69" [label="40.0"];
#   "49" -- "48" [label="9.0"];
#   "49" -- "26" [label="42.0"];
#   "49" -- "39" [label="22.0"];
#   "49" -- "73" [label="21.0"];
#   "49" -- "4" [label="39.0"];
#   "49" -- "31" [label="17.0"];
#   "49" -- "76" [label="8.0"];
#   "49" -- "62" [label="28.0"];
#   "49" -- "37" [label="8.0"];
#   "49" -- "68" [label="22.0"];
#   "2" -- "75" [label="36.0"];
#   "2" -- "14" [label="12.0"];
#   "2" -- "1" [label="35.0"];
#   "2" -- "61" [label="33.0"];
#   "2" -- "62" [label="44.0"];
#   "2" -- "50" [label="7.0"];
#   "2" -- "41" [label="32.0"];
#   "2" -- "35" [label="44.0"];
#   "2" -- "46" [label="17.0"];
#   "2" -- "6" [label="3.0"];
#   "2" -- "28" [label="36.0"];
#   "2" -- "38" [label="46.0"];
#   "2" -- "5" [label="7.0"];
#   "2" -- "52" [label="17.0"];
#   "2" -- "13" [label="35.0"];
#   "2" -- "45" [label="5.0"];
#   "2" -- "3" [label="18.0"];
#   "2" -- "7" [label="38.0"];
#   "2" -- "48" [label="42.0"];
#   "2" -- "44" [label="41.0"];
#   "2" -- "55" [label="44.0"];
#   "2" -- "58" [label="13.0"];
#   "2" -- "42" [label="33.0"];
#   "75" -- "2" [label="36.0"];
#   "75" -- "1" [label="14.0"];
#   "75" -- "36" [label="7.0"];
#   "75" -- "65" [label="42.0"];
#   "75" -- "44" [label="20.0"];
#   "75" -- "22" [label="30.0"];
#   "75" -- "71" [label="10.0"];
#   "75" -- "69" [label="3.0"];
#   "75" -- "76" [label="1.0"];
#   "75" -- "10" [label="9.0"];
#   "75" -- "3" [label="6.0"];
#   "75" -- "13" [label="34.0"];
#   "75" -- "40" [label="9.0"];
#   "75" -- "59" [label="1.0"];
#   "75" -- "39" [label="28.0"];
#   "75" -- "56" [label="35.0"];
#   "75" -- "72" [label="41.0"];
#   "75" -- "8" [label="28.0"];
#   "75" -- "28" [label="7.0"];
#   "75" -- "21" [label="45.0"];
#   "75" -- "14" [label="19.0"];
#   "75" -- "63" [label="43.0"];
#   "75" -- "15" [label="18.0"];
#   "3" -- "47" [label="38.0"];
#   "3" -- "25" [label="12.0"];
#   "3" -- "20" [label="5.0"];
#   "3" -- "41" [label="8.0"];
#   "3" -- "34" [label="3.0"];
#   "3" -- "76" [label="15.0"];
#   "3" -- "69" [label="21.0"];
#   "3" -- "72" [label="40.0"];
#   "3" -- "50" [label="29.0"];
#   "3" -- "22" [label="10.0"];
#   "3" -- "16" [label="42.0"];
#   "3" -- "44" [label="2.0"];
#   "3" -- "54" [label="8.0"];
#   "3" -- "6" [label="40.0"];
#   "3" -- "45" [label="5.0"];
#   "3" -- "19" [label="15.0"];
#   "3" -- "75" [label="6.0"];
#   "3" -- "21" [label="10.0"];
#   "3" -- "61" [label="31.0"];
#   "3" -- "64" [label="7.0"];
#   "3" -- "11" [label="18.0"];
#   "3" -- "2" [label="18.0"];
#   "3" -- "37" [label="26.0"];
#   "3" -- "68" [label="9.0"];
#   "3" -- "59" [label="23.0"];
#   "3" -- "46" [label="20.0"];
#   "3" -- "70" [label="28.0"];
#   "3" -- "77" [label="29.0"];
#   "3" -- "43" [label="36.0"];
#   "47" -- "3" [label="38.0"];
#   "47" -- "6" [label="32.0"];
#   "47" -- "48" [label="17.0"];
#   "47" -- "14" [label="9.0"];
#   "47" -- "4" [label="14.0"];
#   "47" -- "11" [label="37.0"];
#   "47" -- "13" [label="10.0"];
#   "47" -- "70" [label="2.0"];
#   "47" -- "76" [label="40.0"];
#   "47" -- "30" [label="3.0"];
#   "47" -- "9" [label="44.0"];
#   "47" -- "54" [label="25.0"];
#   "47" -- "67" [label="8.0"];
#   "47" -- "73" [label="11.0"];
#   "47" -- "39" [label="23.0"];
#   "47" -- "57" [label="12.0"];
#   "47" -- "42" [label="2.0"];
#   "47" -- "58" [label="4.0"];
#   "47" -- "66" [label="12.0"];
#   "47" -- "55" [label="8.0"];
#   "47" -- "50" [label="5.0"];
#   "47" -- "74" [label="1.0"];
#   "47" -- "8" [label="5.0"];
#   "4" -- "46" [label="11.0"];
#   "4" -- "24" [label="19.0"];
#   "4" -- "53" [label="4.0"];
#   "4" -- "44" [label="22.0"];
#   "4" -- "47" [label="14.0"];
#   "4" -- "34" [label="27.0"];
#   "4" -- "23" [label="22.0"];
#   "4" -- "51" [label="23.0"];
#   "4" -- "33" [label="30.0"];
#   "4" -- "49" [label="39.0"];
#   "4" -- "63" [label="44.0"];
#   "4" -- "58" [label="45.0"];
#   "4" -- "1" [label="31.0"];
#   "4" -- "48" [label="24.0"];
#   "4" -- "15" [label="5.0"];
#   "4" -- "31" [label="1.0"];
#   "4" -- "21" [label="30.0"];
#   "4" -- "18" [label="5.0"];
#   "4" -- "57" [label="31.0"];
#   "4" -- "72" [label="25.0"];
#   "4" -- "60" [label="22.0"];
#   "4" -- "35" [label="5.0"];
#   "4" -- "16" [label="32.0"];
#   "4" -- "6" [label="14.0"];
#   "46" -- "4" [label="11.0"];
#   "46" -- "38" [label="41.0"];
#   "46" -- "45" [label="7.0"];
#   "46" -- "22" [label="17.0"];
#   "46" -- "34" [label="8.0"];
#   "46" -- "44" [label="12.0"];
#   "46" -- "48" [label="24.0"];
#   "46" -- "2" [label="17.0"];
#   "46" -- "76" [label="8.0"];
#   "46" -- "42" [label="8.0"];
#   "46" -- "67" [label="20.0"];
#   "46" -- "31" [label="15.0"];
#   "46" -- "32" [label="42.0"];
#   "46" -- "14" [label="9.0"];
#   "46" -- "9" [label="32.0"];
#   "46" -- "33" [label="43.0"];
#   "46" -- "43" [label="14.0"];
#   "46" -- "24" [label="16.0"];
#   "46" -- "62" [label="28.0"];
#   "46" -- "40" [label="13.0"];
#   "46" -- "6" [label="27.0"];
#   "46" -- "69" [label="21.0"];
#   "46" -- "5" [label="44.0"];
#   "46" -- "10" [label="46.0"];
#   "46" -- "15" [label="34.0"];
#   "46" -- "3" [label="20.0"];
#   "46" -- "7" [label="18.0"];
#   "46" -- "60" [label="5.0"];
#   "5" -- "50" [label="13.0"];
#   "5" -- "11" [label="1.0"];
#   "5" -- "1" [label="3.0"];
#   "5" -- "41" [label="6.0"];
#   "5" -- "68" [label="8.0"];
#   "5" -- "57" [label="31.0"];
#   "5" -- "22" [label="20.0"];
#   "5" -- "48" [label="19.0"];
#   "5" -- "15" [label="20.0"];
#   "5" -- "61" [label="29.0"];
#   "5" -- "35" [label="44.0"];
#   "5" -- "60" [label="37.0"];
#   "5" -- "18" [label="16.0"];
#   "5" -- "2" [label="7.0"];
#   "5" -- "9" [label="20.0"];
#   "5" -- "59" [label="29.0"];
#   "5" -- "21" [label="44.0"];
#   "5" -- "62" [label="20.0"];
#   "5" -- "40" [label="10.0"];
#   "5" -- "38" [label="9.0"];
#   "5" -- "46" [label="44.0"];
#   "5" -- "54" [label="33.0"];
#   "5" -- "66" [label="20.0"];
#   "5" -- "52" [label="36.0"];
#   "5" -- "28" [label="22.0"];
#   "5" -- "25" [label="22.0"];
#   "50" -- "5" [label="13.0"];
#   "50" -- "49" [label="18.0"];
#   "50" -- "27" [label="17.0"];
#   "50" -- "72" [label="19.0"];
#   "50" -- "22" [label="23.0"];
#   "50" -- "66" [label="17.0"];
#   "50" -- "77" [label="22.0"];
#   "50" -- "61" [label="16.0"];
#   "50" -- "32" [label="37.0"];
#   "50" -- "2" [label="7.0"];
#   "50" -- "3" [label="29.0"];
#   "50" -- "60" [label="1.0"];
#   "50" -- "51" [label="9.0"];
#   "50" -- "43" [label="3.0"];
#   "50" -- "53" [label="3.0"];
#   "50" -- "41" [label="21.0"];
#   "50" -- "1" [label="8.0"];
#   "50" -- "42" [label="16.0"];
#   "50" -- "23" [label="14.0"];
#   "50" -- "70" [label="9.0"];
#   "50" -- "39" [label="27.0"];
#   "50" -- "71" [label="17.0"];
#   "50" -- "25" [label="15.0"];
#   "50" -- "28" [label="21.0"];
#   "50" -- "73" [label="41.0"];
#   "50" -- "12" [label="22.0"];
#   "50" -- "20" [label="32.0"];
#   "50" -- "56" [label="31.0"];
#   "50" -- "47" [label="5.0"];
#   "50" -- "29" [label="35.0"];
#   "6" -- "47" [label="32.0"];
#   "6" -- "42" [label="44.0"];
#   "6" -- "45" [label="63.0"];
#   "6" -- "70" [label="37.0"];
#   "6" -- "55" [label="43.0"];
#   "6" -- "23" [label="9.0"];
#   "6" -- "63" [label="37.0"];
#   "6" -- "43" [label="3.0"];
#   "6" -- "71" [label="22.0"];
#   "6" -- "39" [label="45.0"];
#   "6" -- "11" [label="39.0"];
#   "6" -- "72" [label="10.0"];
#   "6" -- "2" [label="3.0"];
#   "6" -- "31" [label="31.0"];
#   "6" -- "3" [label="40.0"];
#   "6" -- "59" [label="18.0"];
#   "6" -- "9" [label="34.0"];
#   "6" -- "24" [label="33.0"];
#   "6" -- "67" [label="22.0"];
#   "6" -- "51" [label="11.0"];
#   "6" -- "48" [label="14.0"];
#   "6" -- "46" [label="27.0"];
#   "6" -- "15" [label="29.0"];
#   "6" -- "7" [label="24.0"];
#   "6" -- "4" [label="14.0"];
#   "6" -- "28" [label="45.0"];
#   "7" -- "18" [label="38.0"];
#   "7" -- "33" [label="32.0"];
#   "7" -- "72" [label="45.0"];
#   "7" -- "28" [label="26.0"];
#   "7" -- "11" [label="46.0"];
#   "7" -- "16" [label="5.0"];
#   "7" -- "25" [label="3.0"];
#   "7" -- "41" [label="11.0"];
#   "7" -- "29" [label="21.0"];
#   "7" -- "2" [label="38.0"];
#   "7" -- "59" [label="17.0"];
#   "7" -- "6" [label="24.0"];
#   "7" -- "8" [label="12.0"];
#   "7" -- "1" [label="12.0"];
#   "7" -- "46" [label="18.0"];
#   "7" -- "23" [label="23.0"];
#   "7" -- "52" [label="17.0"];
#   "7" -- "36" [label="16.0"];
#   "7" -- "40" [label="43.0"];
#   "7" -- "13" [label="45.0"];
#   "18" -- "7" [label="38.0"];
#   "18" -- "65" [label="22.0"];
#   "18" -- "31" [label="44.0"];
#   "18" -- "36" [label="36.0"];
#   "18" -- "62" [label="31.0"];
#   "18" -- "21" [label="32.0"];
#   "18" -- "57" [label="35.0"];
#   "18" -- "68" [label="15.0"];
#   "18" -- "61" [label="5.0"];
#   "18" -- "74" [label="25.0"];
#   "18" -- "38" [label="9.0"];
#   "18" -- "1" [label="21.0"];
#   "18" -- "5" [label="16.0"];
#   "18" -- "45" [label="1.0"];
#   "18" -- "27" [label="1.0"];
#   "18" -- "8" [label="28.0"];
#   "18" -- "41" [label="18.0"];
#   "18" -- "28" [label="45.0"];
#   "18" -- "34" [label="3.0"];
#   "18" -- "12" [label="10.0"];
#   "18" -- "42" [label="21.0"];
#   "18" -- "4" [label="5.0"];
#   "18" -- "66" [label="18.0"];
#   "18" -- "48" [label="43.0"];
#   "18" -- "11" [label="15.0"];
#   "18" -- "40" [label="17.0"];
#   "18" -- "32" [label="31.0"];
#   "18" -- "15" [label="1.0"];
#   "18" -- "71" [label="32.0"];
#   "8" -- "31" [label="39.0"];
#   "8" -- "70" [label="40.0"];
#   "8" -- "64" [label="24.0"];
#   "8" -- "37" [label="40.0"];
#   "8" -- "20" [label="11.0"];
#   "8" -- "9" [label="17.0"];
#   "8" -- "45" [label="5.0"];
#   "8" -- "30" [label="34.0"];
#   "8" -- "12" [label="15.0"];
#   "8" -- "40" [label="15.0"];
#   "8" -- "19" [label="36.0"];
#   "8" -- "54" [label="41.0"];
#   "8" -- "18" [label="28.0"];
#   "8" -- "36" [label="11.0"];
#   "8" -- "14" [label="29.0"];
#   "8" -- "15" [label="18.0"];
#   "8" -- "59" [label="44.0"];
#   "8" -- "22" [label="10.0"];
#   "8" -- "75" [label="28.0"];
#   "8" -- "7" [label="12.0"];
#   "8" -- "52" [label="31.0"];
#   "8" -- "57" [label="33.0"];
#   "8" -- "58" [label="43.0"];
#   "8" -- "35" [label="22.0"];
#   "8" -- "47" [label="5.0"];
#   "8" -- "1" [label="34.0"];
#   "31" -- "8" [label="39.0"];
#   "31" -- "18" [label="44.0"];
#   "31" -- "77" [label="4.0"];
#   "31" -- "20" [label="2.0"];
#   "31" -- "56" [label="36.0"];
#   "31" -- "42" [label="9.0"];
#   "31" -- "71" [label="31.0"];
#   "31" -- "39" [label="5.0"];
#   "31" -- "63" [label="34.0"];
#   "31" -- "49" [label="17.0"];
#   "31" -- "36" [label="27.0"];
#   "31" -- "6" [label="31.0"];
#   "31" -- "54" [label="39.0"];
#   "31" -- "46" [label="15.0"];
#   "31" -- "34" [label="18.0"];
#   "31" -- "61" [label="40.0"];
#   "31" -- "4" [label="1.0"];
#   "31" -- "45" [label="40.0"];
#   "31" -- "59" [label="34.0"];
#   "31" -- "43" [label="29.0"];
#   "31" -- "51" [label="31.0"];
#   "31" -- "1" [label="34.0"];
#   "31" -- "35" [label="22.0"];
#   "31" -- "53" [label="35.0"];
#   "31" -- "58" [label="31.0"];
#   "31" -- "10" [label="14.0"];
#   "9" -- "78" [label="18.0"];
#   "9" -- "16" [label="29.0"];
#   "9" -- "13" [label="3.0"];
#   "9" -- "21" [label="26.0"];
#   "9" -- "42" [label="44.0"];
#   "9" -- "67" [label="14.0"];
#   "9" -- "40" [label="18.0"];
#   "9" -- "8" [label="17.0"];
#   "9" -- "64" [label="19.0"];
#   "9" -- "15" [label="20.0"];
#   "9" -- "23" [label="42.0"];
#   "9" -- "47" [label="44.0"];
#   "9" -- "53" [label="14.0"];
#   "9" -- "65" [label="20.0"];
#   "9" -- "5" [label="20.0"];
#   "9" -- "74" [label="37.0"];
#   "9" -- "6" [label="34.0"];
#   "9" -- "55" [label="33.0"];
#   "9" -- "46" [label="32.0"];
#   "9" -- "1" [label="20.0"];
#   "9" -- "37" [label="1.0"];
#   "9" -- "52" [label="7.0"];
#   "9" -- "10" [label="3.0"];
#   "9" -- "20" [label="8.0"];
#   "9" -- "39" [label="34.0"];
#   "9" -- "77" [label="1.0"];
#   "78" -- "9" [label="18.0"];
#   "78" -- "32" [label="3.0"];
#   "78" -- "1" [label="5.0"];
#   "78" -- "52" [label="26.0"];
#   "78" -- "54" [label="11.0"];
#   "78" -- "11" [label="13.0"];
#   "78" -- "22" [label="25.0"];
#   "78" -- "20" [label="15.0"];
#   "78" -- "56" [label="38.0"];
#   "78" -- "21" [label="3.0"];
#   "78" -- "17" [label="35.0"];
#   "78" -- "77" [label="34.0"];
#   "78" -- "43" [label="7.0"];
#   "78" -- "61" [label="15.0"];
#   "78" -- "24" [label="16.0"];
#   "78" -- "25" [label="35.0"];
#   "78" -- "27" [label="28.0"];
#   "78" -- "12" [label="32.0"];
#   "78" -- "51" [label="22.0"];
#   "10" -- "15" [label="3.0"];
#   "10" -- "70" [label="10.0"];
#   "10" -- "30" [label="26.0"];
#   "10" -- "77" [label="44.0"];
#   "10" -- "45" [label="2.0"];
#   "10" -- "60" [label="1.0"];
#   "10" -- "61" [label="44.0"];
#   "10" -- "66" [label="13.0"];
#   "10" -- "42" [label="18.0"];
#   "10" -- "75" [label="9.0"];
#   "10" -- "68" [label="11.0"];
#   "10" -- "12" [label="9.0"];
#   "10" -- "57" [label="6.0"];
#   "10" -- "25" [label="28.0"];
#   "10" -- "41" [label="16.0"];
#   "10" -- "27" [label="29.0"];
#   "10" -- "65" [label="39.0"];
#   "10" -- "9" [label="3.0"];
#   "10" -- "1" [label="31.0"];
#   "10" -- "20" [label="31.0"];
#   "10" -- "26" [label="29.0"];
#   "10" -- "53" [label="33.0"];
#   "10" -- "28" [label="23.0"];
#   "10" -- "39" [label="24.0"];
#   "10" -- "46" [label="46.0"];
#   "10" -- "69" [label="20.0"];
#   "10" -- "31" [label="14.0"];
#   "15" -- "10" [label="3.0"];
#   "15" -- "22" [label="3.0"];
#   "15" -- "55" [label="2.0"];
#   "15" -- "61" [label="32.0"];
#   "15" -- "35" [label="4.0"];
#   "15" -- "13" [label="13.0"];
#   "15" -- "9" [label="20.0"];
#   "15" -- "5" [label="20.0"];
#   "15" -- "48" [label="32.0"];
#   "15" -- "41" [label="13.0"];
#   "15" -- "42" [label="27.0"];
#   "15" -- "4" [label="5.0"];
#   "15" -- "25" [label="30.0"];
#   "15" -- "60" [label="18.0"];
#   "15" -- "14" [label="39.0"];
#   "15" -- "63" [label="33.0"];
#   "15" -- "32" [label="15.0"];
#   "15" -- "71" [label="1.0"];
#   "15" -- "8" [label="18.0"];
#   "15" -- "69" [label="23.0"];
#   "15" -- "68" [label="9.0"];
#   "15" -- "28" [label="36.0"];
#   "15" -- "6" [label="29.0"];
#   "15" -- "16" [label="38.0"];
#   "15" -- "36" [label="20.0"];
#   "15" -- "46" [label="34.0"];
#   "15" -- "44" [label="13.0"];
#   "15" -- "76" [label="33.0"];
#   "15" -- "18" [label="1.0"];
#   "15" -- "75" [label="18.0"];
#   "11" -- "5" [label="1.0"];
#   "11" -- "78" [label="13.0"];
#   "11" -- "72" [label="30.0"];
#   "11" -- "47" [label="37.0"];
#   "11" -- "73" [label="27.0"];
#   "11" -- "61" [label="20.0"];
#   "11" -- "57" [label="18.0"];
#   "11" -- "51" [label="18.0"];
#   "11" -- "6" [label="39.0"];
#   "11" -- "59" [label="37.0"];
#   "11" -- "40" [label="21.0"];
#   "11" -- "20" [label="15.0"];
#   "11" -- "52" [label="6.0"];
#   "11" -- "54" [label="18.0"];
#   "11" -- "56" [label="34.0"];
#   "11" -- "48" [label="13.0"];
#   "11" -- "1" [label="44.0"];
#   "11" -- "3" [label="18.0"];
#   "11" -- "32" [label="1.0"];
#   "11" -- "7" [label="46.0"];
#   "11" -- "34" [label="21.0"];
#   "11" -- "18" [label="15.0"];
#   "11" -- "76" [label="44.0"];
#   "12" -- "23" [label="26.0"];
#   "12" -- "20" [label="41.0"];
#   "12" -- "1" [label="31.0"];
#   "12" -- "30" [label="9.0"];
#   "12" -- "41" [label="15.0"];
#   "12" -- "8" [label="15.0"];
#   "12" -- "76" [label="15.0"];
#   "12" -- "10" [label="9.0"];
#   "12" -- "37" [label="18.0"];
#   "12" -- "64" [label="37.0"];
#   "12" -- "39" [label="20.0"];
#   "12" -- "50" [label="22.0"];
#   "12" -- "43" [label="29.0"];
#   "12" -- "18" [label="10.0"];
#   "12" -- "24" [label="5.0"];
#   "12" -- "22" [label="11.0"];
#   "12" -- "26" [label="33.0"];
#   "12" -- "68" [label="7.0"];
#   "12" -- "78" [label="32.0"];
#   "12" -- "52" [label="14.0"];
#   "12" -- "44" [label="4.0"];
#   "12" -- "34" [label="2.0"];
#   "12" -- "16" [label="36.0"];
#   "12" -- "40" [label="31.0"];
#   "12" -- "70" [label="9.0"];
#   "23" -- "12" [label="26.0"];
#   "23" -- "19" [label="55.0"];
#   "23" -- "20" [label="25.0"];
#   "23" -- "55" [label="9.0"];
#   "23" -- "53" [label="19.0"];
#   "23" -- "6" [label="9.0"];
#   "23" -- "4" [label="22.0"];
#   "23" -- "29" [label="33.0"];
#   "23" -- "68" [label="3.0"];
#   "23" -- "52" [label="19.0"];
#   "23" -- "74" [label="26.0"];
#   "23" -- "48" [label="42.0"];
#   "23" -- "77" [label="20.0"];
#   "23" -- "9" [label="42.0"];
#   "23" -- "30" [label="39.0"];
#   "23" -- "27" [label="23.0"];
#   "23" -- "50" [label="14.0"];
#   "23" -- "69" [label="3.0"];
#   "23" -- "14" [label="38.0"];
#   "23" -- "51" [label="46.0"];
#   "23" -- "62" [label="18.0"];
#   "23" -- "56" [label="14.0"];
#   "23" -- "25" [label="26.0"];
#   "23" -- "41" [label="33.0"];
#   "23" -- "13" [label="12.0"];
#   "23" -- "35" [label="12.0"];
#   "23" -- "60" [label="30.0"];
#   "23" -- "61" [label="30.0"];
#   "23" -- "28" [label="37.0"];
#   "23" -- "24" [label="5.0"];
#   "23" -- "7" [label="23.0"];
#   "13" -- "48" [label="58.0"];
#   "13" -- "27" [label="6.0"];
#   "13" -- "77" [label="36.0"];
#   "13" -- "9" [label="3.0"];
#   "13" -- "39" [label="21.0"];
#   "13" -- "47" [label="10.0"];
#   "13" -- "70" [label="12.0"];
#   "13" -- "15" [label="13.0"];
#   "13" -- "45" [label="40.0"];
#   "13" -- "20" [label="8.0"];
#   "13" -- "62" [label="9.0"];
#   "13" -- "14" [label="11.0"];
#   "13" -- "25" [label="41.0"];
#   "13" -- "75" [label="34.0"];
#   "13" -- "2" [label="35.0"];
#   "13" -- "40" [label="11.0"];
#   "13" -- "22" [label="43.0"];
#   "13" -- "64" [label="1.0"];
#   "13" -- "56" [label="14.0"];
#   "13" -- "23" [label="12.0"];
#   "13" -- "51" [label="2.0"];
#   "13" -- "60" [label="7.0"];
#   "13" -- "72" [label="6.0"];
#   "13" -- "24" [label="9.0"];
#   "13" -- "63" [label="30.0"];
#   "13" -- "1" [label="5.0"];
#   "13" -- "7" [label="45.0"];
#   "13" -- "36" [label="29.0"];
#   "48" -- "13" [label="58.0"];
#   "48" -- "47" [label="17.0"];
#   "48" -- "58" [label="21.0"];
#   "48" -- "68" [label="3.0"];
#   "48" -- "32" [label="24.0"];
#   "48" -- "49" [label="9.0"];
#   "48" -- "46" [label="24.0"];
#   "48" -- "51" [label="29.0"];
#   "48" -- "5" [label="19.0"];
#   "48" -- "23" [label="42.0"];
#   "48" -- "43" [label="27.0"];
#   "48" -- "15" [label="32.0"];
#   "48" -- "4" [label="24.0"];
#   "48" -- "53" [label="32.0"];
#   "48" -- "16" [label="1.0"];
#   "48" -- "11" [label="13.0"];
#   "48" -- "63" [label="5.0"];
#   "48" -- "76" [label="20.0"];
#   "48" -- "26" [label="26.0"];
#   "48" -- "70" [label="44.0"];
#   "48" -- "6" [label="14.0"];
#   "48" -- "59" [label="30.0"];
#   "48" -- "18" [label="43.0"];
#   "48" -- "2" [label="42.0"];
#   "48" -- "1" [label="21.0"];
#   "48" -- "56" [label="2.0"];
#   "14" -- "33" [label="12.0"];
#   "14" -- "22" [label="18.0"];
#   "14" -- "63" [label="5.0"];
#   "14" -- "2" [label="12.0"];
#   "14" -- "36" [label="14.0"];
#   "14" -- "47" [label="9.0"];
#   "14" -- "29" [label="4.0"];
#   "14" -- "32" [label="21.0"];
#   "14" -- "35" [label="38.0"];
#   "14" -- "71" [label="24.0"];
#   "14" -- "74" [label="45.0"];
#   "14" -- "52" [label="13.0"];
#   "14" -- "54" [label="41.0"];
#   "14" -- "23" [label="38.0"];
#   "14" -- "13" [label="11.0"];
#   "14" -- "15" [label="39.0"];
#   "14" -- "44" [label="2.0"];
#   "14" -- "46" [label="9.0"];
#   "14" -- "8" [label="29.0"];
#   "14" -- "61" [label="6.0"];
#   "14" -- "27" [label="6.0"];
#   "14" -- "38" [label="19.0"];
#   "14" -- "45" [label="20.0"];
#   "14" -- "37" [label="29.0"];
#   "14" -- "24" [label="17.0"];
#   "14" -- "75" [label="19.0"];
#   "14" -- "60" [label="37.0"];
#   "33" -- "14" [label="12.0"];
#   "33" -- "39" [label="29.0"];
#   "33" -- "61" [label="28.0"];
#   "33" -- "7" [label="32.0"];
#   "33" -- "17" [label="21.0"];
#   "33" -- "62" [label="6.0"];
#   "33" -- "55" [label="17.0"];
#   "33" -- "4" [label="30.0"];
#   "33" -- "16" [label="44.0"];
#   "33" -- "42" [label="9.0"];
#   "33" -- "46" [label="43.0"];
#   "33" -- "45" [label="6.0"];
#   "33" -- "1" [label="24.0"];
#   "33" -- "22" [label="43.0"];
#   "33" -- "30" [label="38.0"];
#   "33" -- "37" [label="17.0"];
#   "33" -- "35" [label="38.0"];
#   "33" -- "73" [label="18.0"];
#   "33" -- "72" [label="3.0"];
#   "22" -- "15" [label="3.0"];
#   "22" -- "14" [label="18.0"];
#   "22" -- "35" [label="24.0"];
#   "22" -- "50" [label="23.0"];
#   "22" -- "74" [label="13.0"];
#   "22" -- "56" [label="3.0"];
#   "22" -- "46" [label="17.0"];
#   "22" -- "78" [label="25.0"];
#   "22" -- "72" [label="28.0"];
#   "22" -- "71" [label="3.0"];
#   "22" -- "30" [label="27.0"];
#   "22" -- "5" [label="20.0"];
#   "22" -- "40" [label="14.0"];
#   "22" -- "77" [label="35.0"];
#   "22" -- "75" [label="30.0"];
#   "22" -- "3" [label="10.0"];
#   "22" -- "67" [label="2.0"];
#   "22" -- "44" [label="5.0"];
#   "22" -- "45" [label="25.0"];
#   "22" -- "28" [label="45.0"];
#   "22" -- "42" [label="9.0"];
#   "22" -- "36" [label="37.0"];
#   "22" -- "13" [label="43.0"];
#   "22" -- "37" [label="39.0"];
#   "22" -- "24" [label="10.0"];
#   "22" -- "12" [label="11.0"];
#   "22" -- "8" [label="10.0"];
#   "22" -- "52" [label="7.0"];
#   "22" -- "33" [label="43.0"];
#   "22" -- "20" [label="4.0"];
#   "22" -- "43" [label="43.0"];
#   "22" -- "21" [label="35.0"];
#   "16" -- "27" [label="27.0"];
#   "16" -- "37" [label="8.0"];
#   "16" -- "68" [label="46.0"];
#   "16" -- "9" [label="29.0"];
#   "16" -- "41" [label="15.0"];
#   "16" -- "60" [label="17.0"];
#   "16" -- "3" [label="42.0"];
#   "16" -- "33" [label="44.0"];
#   "16" -- "17" [label="41.0"];
#   "16" -- "62" [label="5.0"];
#   "16" -- "48" [label="1.0"];
#   "16" -- "51" [label="21.0"];
#   "16" -- "25" [label="44.0"];
#   "16" -- "34" [label="3.0"];
#   "16" -- "64" [label="23.0"];
#   "16" -- "77" [label="37.0"];
#   "16" -- "7" [label="5.0"];
#   "16" -- "15" [label="38.0"];
#   "16" -- "32" [label="20.0"];
#   "16" -- "4" [label="32.0"];
#   "16" -- "12" [label="36.0"];
#   "16" -- "19" [label="9.0"];
#   "27" -- "16" [label="27.0"];
#   "27" -- "13" [label="6.0"];
#   "27" -- "50" [label="17.0"];
#   "27" -- "44" [label="9.0"];
#   "27" -- "54" [label="10.0"];
#   "27" -- "51" [label="14.0"];
#   "27" -- "1" [label="22.0"];
#   "27" -- "23" [label="23.0"];
#   "27" -- "62" [label="5.0"];
#   "27" -- "18" [label="1.0"];
#   "27" -- "10" [label="29.0"];
#   "27" -- "14" [label="6.0"];
#   "27" -- "67" [label="15.0"];
#   "27" -- "53" [label="43.0"];
#   "27" -- "43" [label="23.0"];
#   "27" -- "73" [label="33.0"];
#   "27" -- "78" [label="28.0"];
#   "27" -- "25" [label="11.0"];
#   "27" -- "69" [label="19.0"];
#   "27" -- "64" [label="10.0"];
#   "27" -- "37" [label="35.0"];
#   "17" -- "32" [label="9.0"];
#   "17" -- "74" [label="35.0"];
#   "17" -- "67" [label="30.0"];
#   "17" -- "33" [label="21.0"];
#   "17" -- "42" [label="23.0"];
#   "17" -- "78" [label="35.0"];
#   "17" -- "24" [label="46.0"];
#   "17" -- "29" [label="8.0"];
#   "17" -- "62" [label="11.0"];
#   "17" -- "63" [label="41.0"];
#   "17" -- "16" [label="41.0"];
#   "17" -- "70" [label="7.0"];
#   "17" -- "59" [label="23.0"];
#   "17" -- "58" [label="13.0"];
#   "17" -- "20" [label="9.0"];
#   "17" -- "73" [label="13.0"];
#   "17" -- "19" [label="13.0"];
#   "17" -- "68" [label="9.0"];
#   "17" -- "66" [label="46.0"];
#   "17" -- "35" [label="9.0"];
#   "17" -- "37" [label="16.0"];
#   "32" -- "17" [label="9.0"];
#   "32" -- "78" [label="3.0"];
#   "32" -- "48" [label="24.0"];
#   "32" -- "71" [label="14.0"];
#   "32" -- "38" [label="9.0"];
#   "32" -- "50" [label="37.0"];
#   "32" -- "59" [label="15.0"];
#   "32" -- "26" [label="21.0"];
#   "32" -- "14" [label="21.0"];
#   "32" -- "61" [label="12.0"];
#   "32" -- "44" [label="7.0"];
#   "32" -- "67" [label="16.0"];
#   "32" -- "21" [label="12.0"];
#   "32" -- "73" [label="9.0"];
#   "32" -- "69" [label="23.0"];
#   "32" -- "19" [label="14.0"];
#   "32" -- "37" [label="11.0"];
#   "32" -- "64" [label="27.0"];
#   "32" -- "42" [label="12.0"];
#   "32" -- "46" [label="42.0"];
#   "32" -- "15" [label="15.0"];
#   "32" -- "56" [label="11.0"];
#   "32" -- "11" [label="1.0"];
#   "32" -- "36" [label="32.0"];
#   "32" -- "45" [label="42.0"];
#   "32" -- "68" [label="44.0"];
#   "32" -- "58" [label="3.0"];
#   "32" -- "40" [label="19.0"];
#   "32" -- "35" [label="30.0"];
#   "32" -- "16" [label="20.0"];
#   "32" -- "18" [label="31.0"];
#   "32" -- "53" [label="30.0"];
#   "32" -- "55" [label="6.0"];
#   "65" -- "18" [label="22.0"];
#   "65" -- "19" [label="60.0"];
#   "65" -- "24" [label="6.0"];
#   "65" -- "40" [label="1.0"];
#   "65" -- "61" [label="4.0"];
#   "65" -- "75" [label="42.0"];
#   "65" -- "59" [label="46.0"];
#   "65" -- "38" [label="29.0"];
#   "65" -- "20" [label="23.0"];
#   "65" -- "26" [label="25.0"];
#   "65" -- "53" [label="27.0"];
#   "65" -- "9" [label="20.0"];
#   "65" -- "41" [label="9.0"];
#   "65" -- "45" [label="7.0"];
#   "65" -- "10" [label="39.0"];
#   "65" -- "42" [label="40.0"];
#   "65" -- "44" [label="40.0"];
#   "65" -- "73" [label="33.0"];
#   "65" -- "68" [label="23.0"];
#   "65" -- "66" [label="13.0"];
#   "65" -- "67" [label="36.0"];
#   "65" -- "71" [label="20.0"];
#   "19" -- "23" [label="55.0"];
#   "19" -- "65" [label="60.0"];
#   "19" -- "64" [label="42.0"];
#   "19" -- "77" [label="31.0"];
#   "19" -- "69" [label="36.0"];
#   "19" -- "35" [label="40.0"];
#   "19" -- "72" [label="22.0"];
#   "19" -- "32" [label="14.0"];
#   "19" -- "8" [label="36.0"];
#   "19" -- "41" [label="36.0"];
#   "19" -- "3" [label="15.0"];
#   "19" -- "29" [label="9.0"];
#   "19" -- "58" [label="7.0"];
#   "19" -- "17" [label="13.0"];
#   "19" -- "54" [label="42.0"];
#   "19" -- "56" [label="9.0"];
#   "19" -- "40" [label="29.0"];
#   "19" -- "70" [label="2.0"];
#   "19" -- "63" [label="45.0"];
#   "19" -- "60" [label="1.0"];
#   "19" -- "36" [label="41.0"];
#   "19" -- "16" [label="9.0"];
#   "20" -- "12" [label="41.0"];
#   "20" -- "23" [label="25.0"];
#   "20" -- "31" [label="2.0"];
#   "20" -- "1" [label="28.0"];
#   "20" -- "58" [label="41.0"];
#   "20" -- "3" [label="5.0"];
#   "20" -- "78" [label="15.0"];
#   "20" -- "38" [label="11.0"];
#   "20" -- "8" [label="11.0"];
#   "20" -- "39" [label="14.0"];
#   "20" -- "57" [label="9.0"];
#   "20" -- "13" [label="8.0"];
#   "20" -- "65" [label="23.0"];
#   "20" -- "11" [label="15.0"];
#   "20" -- "17" [label="9.0"];
#   "20" -- "68" [label="12.0"];
#   "20" -- "35" [label="19.0"];
#   "20" -- "44" [label="30.0"];
#   "20" -- "70" [label="34.0"];
#   "20" -- "67" [label="9.0"];
#   "20" -- "9" [label="8.0"];
#   "20" -- "60" [label="7.0"];
#   "20" -- "50" [label="32.0"];
#   "20" -- "10" [label="31.0"];
#   "20" -- "34" [label="26.0"];
#   "20" -- "22" [label="4.0"];
#   "20" -- "25" [label="35.0"];
#   "20" -- "74" [label="4.0"];
#   "21" -- "39" [label="6.0"];
#   "21" -- "68" [label="19.0"];
#   "21" -- "18" [label="32.0"];
#   "21" -- "9" [label="26.0"];
#   "21" -- "52" [label="3.0"];
#   "21" -- "62" [label="9.0"];
#   "21" -- "78" [label="3.0"];
#   "21" -- "44" [label="36.0"];
#   "21" -- "40" [label="25.0"];
#   "21" -- "32" [label="12.0"];
#   "21" -- "37" [label="24.0"];
#   "21" -- "67" [label="5.0"];
#   "21" -- "35" [label="24.0"];
#   "21" -- "73" [label="4.0"];
#   "21" -- "3" [label="10.0"];
#   "21" -- "5" [label="44.0"];
#   "21" -- "4" [label="30.0"];
#   "21" -- "69" [label="10.0"];
#   "21" -- "76" [label="42.0"];
#   "21" -- "75" [label="45.0"];
#   "21" -- "51" [label="28.0"];
#   "21" -- "22" [label="35.0"];
#   "39" -- "21" [label="6.0"];
#   "39" -- "33" [label="29.0"];
#   "39" -- "51" [label="2.0"];
#   "39" -- "49" [label="22.0"];
#   "39" -- "43" [label="21.0"];
#   "39" -- "70" [label="3.0"];
#   "39" -- "13" [label="21.0"];
#   "39" -- "31" [label="5.0"];
#   "39" -- "20" [label="14.0"];
#   "39" -- "6" [label="45.0"];
#   "39" -- "47" [label="23.0"];
#   "39" -- "56" [label="35.0"];
#   "39" -- "35" [label="1.0"];
#   "39" -- "50" [label="27.0"];
#   "39" -- "53" [label="7.0"];
#   "39" -- "24" [label="21.0"];
#   "39" -- "12" [label="20.0"];
#   "39" -- "62" [label="9.0"];
#   "39" -- "59" [label="24.0"];
#   "39" -- "75" [label="28.0"];
#   "39" -- "9" [label="34.0"];
#   "39" -- "52" [label="20.0"];
#   "39" -- "10" [label="24.0"];
#   "39" -- "72" [label="20.0"];
#   "39" -- "45" [label="19.0"];
#   "24" -- "4" [label="19.0"];
#   "24" -- "43" [label="33.0"];
#   "24" -- "67" [label="50.0"];
#   "24" -- "65" [label="6.0"];
#   "24" -- "60" [label="19.0"];
#   "24" -- "17" [label="46.0"];
#   "24" -- "59" [label="20.0"];
#   "24" -- "28" [label="34.0"];
#   "24" -- "36" [label="8.0"];
#   "24" -- "51" [label="14.0"];
#   "24" -- "72" [label="40.0"];
#   "24" -- "6" [label="33.0"];
#   "24" -- "39" [label="21.0"];
#   "24" -- "78" [label="16.0"];
#   "24" -- "46" [label="16.0"];
#   "24" -- "29" [label="44.0"];
#   "24" -- "73" [label="16.0"];
#   "24" -- "22" [label="10.0"];
#   "24" -- "12" [label="5.0"];
#   "24" -- "38" [label="19.0"];
#   "24" -- "69" [label="4.0"];
#   "24" -- "13" [label="9.0"];
#   "24" -- "14" [label="17.0"];
#   "24" -- "23" [label="5.0"];
#   "24" -- "1" [label="31.0"];
#   "24" -- "57" [label="9.0"];
#   "25" -- "3" [label="12.0"];
#   "25" -- "26" [label="15.0"];
#   "25" -- "59" [label="9.0"];
#   "25" -- "74" [label="35.0"];
#   "25" -- "29" [label="26.0"];
#   "25" -- "38" [label="37.0"];
#   "25" -- "61" [label="9.0"];
#   "25" -- "36" [label="24.0"];
#   "25" -- "44" [label="9.0"];
#   "25" -- "28" [label="46.0"];
#   "25" -- "30" [label="13.0"];
#   "25" -- "15" [label="30.0"];
#   "25" -- "13" [label="41.0"];
#   "25" -- "16" [label="44.0"];
#   "25" -- "10" [label="28.0"];
#   "25" -- "50" [label="15.0"];
#   "25" -- "23" [label="26.0"];
#   "25" -- "77" [label="37.0"];
#   "25" -- "7" [label="3.0"];
#   "25" -- "40" [label="16.0"];
#   "25" -- "78" [label="35.0"];
#   "25" -- "27" [label="11.0"];
#   "25" -- "20" [label="35.0"];
#   "25" -- "5" [label="22.0"];
#   "26" -- "25" [label="15.0"];
#   "26" -- "34" [label="42.0"];
#   "26" -- "49" [label="42.0"];
#   "26" -- "42" [label="29.0"];
#   "26" -- "66" [label="3.0"];
#   "26" -- "32" [label="21.0"];
#   "26" -- "72" [label="10.0"];
#   "26" -- "77" [label="15.0"];
#   "26" -- "57" [label="32.0"];
#   "26" -- "65" [label="25.0"];
#   "26" -- "62" [label="5.0"];
#   "26" -- "53" [label="11.0"];
#   "26" -- "1" [label="2.0"];
#   "26" -- "48" [label="26.0"];
#   "26" -- "37" [label="5.0"];
#   "26" -- "12" [label="33.0"];
#   "26" -- "10" [label="29.0"];
#   "26" -- "68" [label="20.0"];
#   "26" -- "38" [label="34.0"];
#   "28" -- "73" [label="10.0"];
#   "28" -- "52" [label="24.0"];
#   "28" -- "38" [label="3.0"];
#   "28" -- "62" [label="12.0"];
#   "28" -- "24" [label="34.0"];
#   "28" -- "25" [label="46.0"];
#   "28" -- "2" [label="36.0"];
#   "28" -- "44" [label="31.0"];
#   "28" -- "58" [label="11.0"];
#   "28" -- "7" [label="26.0"];
#   "28" -- "22" [label="45.0"];
#   "28" -- "18" [label="45.0"];
#   "28" -- "35" [label="20.0"];
#   "28" -- "50" [label="21.0"];
#   "28" -- "45" [label="11.0"];
#   "28" -- "71" [label="28.0"];
#   "28" -- "63" [label="10.0"];
#   "28" -- "1" [label="2.0"];
#   "28" -- "15" [label="36.0"];
#   "28" -- "34" [label="25.0"];
#   "28" -- "51" [label="34.0"];
#   "28" -- "56" [label="34.0"];
#   "28" -- "23" [label="37.0"];
#   "28" -- "75" [label="7.0"];
#   "28" -- "10" [label="23.0"];
#   "28" -- "40" [label="19.0"];
#   "28" -- "5" [label="22.0"];
#   "28" -- "6" [label="45.0"];
#   "28" -- "54" [label="12.0"];
#   "73" -- "28" [label="10.0"];
#   "73" -- "54" [label="35.0"];
#   "73" -- "34" [label="35.0"];
#   "73" -- "49" [label="21.0"];
#   "73" -- "11" [label="27.0"];
#   "73" -- "32" [label="9.0"];
#   "73" -- "55" [label="39.0"];
#   "73" -- "1" [label="22.0"];
#   "73" -- "47" [label="11.0"];
#   "73" -- "21" [label="4.0"];
#   "73" -- "17" [label="13.0"];
#   "73" -- "74" [label="9.0"];
#   "73" -- "59" [label="12.0"];
#   "73" -- "50" [label="41.0"];
#   "73" -- "24" [label="16.0"];
#   "73" -- "65" [label="33.0"];
#   "73" -- "27" [label="33.0"];
#   "73" -- "41" [label="38.0"];
#   "73" -- "38" [label="40.0"];
#   "73" -- "36" [label="13.0"];
#   "73" -- "63" [label="9.0"];
#   "73" -- "33" [label="18.0"];
#   "29" -- "62" [label="35.0"];
#   "29" -- "71" [label="4.0"];
#   "29" -- "25" [label="26.0"];
#   "29" -- "70" [label="3.0"];
#   "29" -- "52" [label="25.0"];
#   "29" -- "14" [label="4.0"];
#   "29" -- "35" [label="33.0"];
#   "29" -- "23" [label="33.0"];
#   "29" -- "36" [label="19.0"];
#   "29" -- "17" [label="8.0"];
#   "29" -- "1" [label="9.0"];
#   "29" -- "67" [label="23.0"];
#   "29" -- "60" [label="29.0"];
#   "29" -- "53" [label="9.0"];
#   "29" -- "57" [label="18.0"];
#   "29" -- "19" [label="9.0"];
#   "29" -- "24" [label="44.0"];
#   "29" -- "58" [label="3.0"];
#   "29" -- "37" [label="22.0"];
#   "29" -- "40" [label="32.0"];
#   "29" -- "7" [label="21.0"];
#   "29" -- "43" [label="18.0"];
#   "29" -- "77" [label="5.0"];
#   "29" -- "51" [label="14.0"];
#   "29" -- "38" [label="44.0"];
#   "29" -- "50" [label="35.0"];
#   "29" -- "42" [label="39.0"];
#   "62" -- "29" [label="35.0"];
#   "62" -- "18" [label="31.0"];
#   "62" -- "33" [label="6.0"];
#   "62" -- "57" [label="46.0"];
#   "62" -- "2" [label="44.0"];
#   "62" -- "21" [label="9.0"];
#   "62" -- "28" [label="12.0"];
#   "62" -- "44" [label="11.0"];
#   "62" -- "1" [label="46.0"];
#   "62" -- "59" [label="36.0"];
#   "62" -- "49" [label="28.0"];
#   "62" -- "17" [label="11.0"];
#   "62" -- "45" [label="35.0"];
#   "62" -- "16" [label="5.0"];
#   "62" -- "40" [label="14.0"];
#   "62" -- "13" [label="9.0"];
#   "62" -- "26" [label="5.0"];
#   "62" -- "27" [label="5.0"];
#   "62" -- "23" [label="18.0"];
#   "62" -- "5" [label="20.0"];
#   "62" -- "46" [label="28.0"];
#   "62" -- "38" [label="13.0"];
#   "62" -- "76" [label="7.0"];
#   "62" -- "39" [label="9.0"];
#   "62" -- "69" [label="28.0"];
#   "62" -- "35" [label="42.0"];
#   "62" -- "43" [label="22.0"];
#   "30" -- "44" [label="2.0"];
#   "30" -- "59" [label="47.0"];
#   "30" -- "10" [label="26.0"];
#   "30" -- "35" [label="46.0"];
#   "30" -- "22" [label="27.0"];
#   "30" -- "12" [label="9.0"];
#   "30" -- "37" [label="31.0"];
#   "30" -- "72" [label="4.0"];
#   "30" -- "47" [label="3.0"];
#   "30" -- "8" [label="34.0"];
#   "30" -- "23" [label="39.0"];
#   "30" -- "77" [label="2.0"];
#   "30" -- "25" [label="13.0"];
#   "30" -- "41" [label="6.0"];
#   "30" -- "63" [label="36.0"];
#   "30" -- "40" [label="14.0"];
#   "30" -- "1" [label="40.0"];
#   "30" -- "60" [label="26.0"];
#   "30" -- "33" [label="38.0"];
#   "30" -- "64" [label="30.0"];
#   "30" -- "51" [label="35.0"];
#   "30" -- "38" [label="9.0"];
#   "30" -- "34" [label="30.0"];
#   "44" -- "30" [label="2.0"];
#   "44" -- "55" [label="36.0"];
#   "44" -- "57" [label="17.0"];
#   "44" -- "38" [label="4.0"];
#   "44" -- "46" [label="12.0"];
#   "44" -- "4" [label="22.0"];
#   "44" -- "27" [label="9.0"];
#   "44" -- "67" [label="20.0"];
#   "44" -- "43" [label="10.0"];
#   "44" -- "62" [label="11.0"];
#   "44" -- "1" [label="23.0"];
#   "44" -- "32" [label="7.0"];
#   "44" -- "25" [label="9.0"];
#   "44" -- "21" [label="36.0"];
#   "44" -- "75" [label="20.0"];
#   "44" -- "3" [label="2.0"];
#   "44" -- "61" [label="42.0"];
#   "44" -- "63" [label="22.0"];
#   "44" -- "28" [label="31.0"];
#   "44" -- "42" [label="9.0"];
#   "44" -- "22" [label="5.0"];
#   "44" -- "20" [label="30.0"];
#   "44" -- "34" [label="8.0"];
#   "44" -- "14" [label="2.0"];
#   "44" -- "41" [label="26.0"];
#   "44" -- "65" [label="40.0"];
#   "44" -- "64" [label="3.0"];
#   "44" -- "70" [label="23.0"];
#   "44" -- "12" [label="4.0"];
#   "44" -- "15" [label="13.0"];
#   "44" -- "2" [label="41.0"];
#   "34" -- "26" [label="42.0"];
#   "34" -- "46" [label="8.0"];
#   "34" -- "4" [label="27.0"];
#   "34" -- "73" [label="35.0"];
#   "34" -- "3" [label="3.0"];
#   "34" -- "37" [label="21.0"];
#   "34" -- "55" [label="28.0"];
#   "34" -- "69" [label="7.0"];
#   "34" -- "35" [label="2.0"];
#   "34" -- "64" [label="38.0"];
#   "34" -- "52" [label="26.0"];
#   "34" -- "31" [label="18.0"];
#   "34" -- "16" [label="3.0"];
#   "34" -- "44" [label="8.0"];
#   "34" -- "11" [label="21.0"];
#   "34" -- "18" [label="3.0"];
#   "34" -- "70" [label="28.0"];
#   "34" -- "56" [label="36.0"];
#   "34" -- "28" [label="25.0"];
#   "34" -- "77" [label="4.0"];
#   "34" -- "20" [label="26.0"];
#   "34" -- "36" [label="16.0"];
#   "34" -- "12" [label="2.0"];
#   "34" -- "30" [label="30.0"];
#   "35" -- "22" [label="24.0"];
#   "35" -- "41" [label="25.0"];
#   "35" -- "30" [label="46.0"];
#   "35" -- "29" [label="33.0"];
#   "35" -- "15" [label="4.0"];
#   "35" -- "53" [label="32.0"];
#   "35" -- "2" [label="44.0"];
#   "35" -- "14" [label="38.0"];
#   "35" -- "71" [label="10.0"];
#   "35" -- "19" [label="40.0"];
#   "35" -- "5" [label="44.0"];
#   "35" -- "34" [label="2.0"];
#   "35" -- "43" [label="29.0"];
#   "35" -- "21" [label="24.0"];
#   "35" -- "39" [label="1.0"];
#   "35" -- "20" [label="19.0"];
#   "35" -- "54" [label="35.0"];
#   "35" -- "28" [label="20.0"];
#   "35" -- "37" [label="16.0"];
#   "35" -- "23" [label="12.0"];
#   "35" -- "51" [label="28.0"];
#   "35" -- "31" [label="22.0"];
#   "35" -- "64" [label="28.0"];
#   "35" -- "17" [label="9.0"];
#   "35" -- "1" [label="4.0"];
#   "35" -- "32" [label="30.0"];
#   "35" -- "4" [label="5.0"];
#   "35" -- "62" [label="42.0"];
#   "35" -- "40" [label="17.0"];
#   "35" -- "8" [label="22.0"];
#   "35" -- "33" [label="38.0"];
#   "36" -- "18" [label="36.0"];
#   "36" -- "77" [label="12.0"];
#   "36" -- "14" [label="14.0"];
#   "36" -- "75" [label="7.0"];
#   "36" -- "25" [label="24.0"];
#   "36" -- "51" [label="31.0"];
#   "36" -- "43" [label="10.0"];
#   "36" -- "29" [label="19.0"];
#   "36" -- "31" [label="27.0"];
#   "36" -- "24" [label="8.0"];
#   "36" -- "37" [label="10.0"];
#   "36" -- "8" [label="11.0"];
#   "36" -- "22" [label="37.0"];
#   "36" -- "69" [label="6.0"];
#   "36" -- "32" [label="32.0"];
#   "36" -- "60" [label="29.0"];
#   "36" -- "38" [label="30.0"];
#   "36" -- "15" [label="20.0"];
#   "36" -- "34" [label="16.0"];
#   "36" -- "73" [label="13.0"];
#   "36" -- "19" [label="41.0"];
#   "36" -- "54" [label="41.0"];
#   "36" -- "66" [label="32.0"];
#   "36" -- "42" [label="15.0"];
#   "36" -- "7" [label="16.0"];
#   "36" -- "40" [label="22.0"];
#   "36" -- "13" [label="29.0"];
#   "37" -- "16" [label="8.0"];
#   "37" -- "52" [label="13.0"];
#   "37" -- "64" [label="5.0"];
#   "37" -- "30" [label="31.0"];
#   "37" -- "66" [label="42.0"];
#   "37" -- "8" [label="40.0"];
#   "37" -- "63" [label="2.0"];
#   "37" -- "41" [label="28.0"];
#   "37" -- "21" [label="24.0"];
#   "37" -- "34" [label="21.0"];
#   "37" -- "53" [label="21.0"];
#   "37" -- "32" [label="11.0"];
#   "37" -- "51" [label="9.0"];
#   "37" -- "12" [label="18.0"];
#   "37" -- "49" [label="8.0"];
#   "37" -- "72" [label="34.0"];
#   "37" -- "74" [label="14.0"];
#   "37" -- "36" [label="10.0"];
#   "37" -- "22" [label="39.0"];
#   "37" -- "35" [label="16.0"];
#   "37" -- "9" [label="1.0"];
#   "37" -- "29" [label="22.0"];
#   "37" -- "3" [label="26.0"];
#   "37" -- "26" [label="5.0"];
#   "37" -- "14" [label="29.0"];
#   "37" -- "40" [label="8.0"];
#   "37" -- "38" [label="10.0"];
#   "37" -- "33" [label="17.0"];
#   "37" -- "27" [label="35.0"];
#   "37" -- "17" [label="16.0"];
#   "38" -- "46" [label="41.0"];
#   "38" -- "41" [label="22.0"];
#   "38" -- "28" [label="3.0"];
#   "38" -- "52" [label="8.0"];
#   "38" -- "32" [label="9.0"];
#   "38" -- "25" [label="37.0"];
#   "38" -- "44" [label="4.0"];
#   "38" -- "20" [label="11.0"];
#   "38" -- "77" [label="9.0"];
#   "38" -- "54" [label="23.0"];
#   "38" -- "65" [label="29.0"];
#   "38" -- "18" [label="9.0"];
#   "38" -- "2" [label="46.0"];
#   "38" -- "42" [label="37.0"];
#   "38" -- "61" [label="19.0"];
#   "38" -- "62" [label="13.0"];
#   "38" -- "36" [label="30.0"];
#   "38" -- "5" [label="9.0"];
#   "38" -- "14" [label="19.0"];
#   "38" -- "40" [label="18.0"];
#   "38" -- "24" [label="19.0"];
#   "38" -- "37" [label="10.0"];
#   "38" -- "73" [label="40.0"];
#   "38" -- "29" [label="44.0"];
#   "38" -- "30" [label="9.0"];
#   "38" -- "26" [label="34.0"];
#   "38" -- "45" [label="26.0"];
#   "51" -- "39" [label="2.0"];
#   "51" -- "59" [label="38.0"];
#   "51" -- "68" [label="17.0"];
#   "51" -- "36" [label="31.0"];
#   "51" -- "60" [label="31.0"];
#   "51" -- "4" [label="23.0"];
#   "51" -- "48" [label="29.0"];
#   "51" -- "11" [label="18.0"];
#   "51" -- "27" [label="14.0"];
#   "51" -- "50" [label="9.0"];
#   "51" -- "1" [label="3.0"];
#   "51" -- "37" [label="9.0"];
#   "51" -- "16" [label="21.0"];
#   "51" -- "23" [label="46.0"];
#   "51" -- "24" [label="14.0"];
#   "51" -- "13" [label="2.0"];
#   "51" -- "35" [label="28.0"];
#   "51" -- "6" [label="11.0"];
#   "51" -- "31" [label="31.0"];
#   "51" -- "28" [label="34.0"];
#   "51" -- "45" [label="20.0"];
#   "51" -- "61" [label="40.0"];
#   "51" -- "29" [label="14.0"];
#   "51" -- "30" [label="35.0"];
#   "51" -- "21" [label="28.0"];
#   "51" -- "78" [label="22.0"];
#   "51" -- "52" [label="22.0"];
#   "40" -- "49" [label="16.0"];
#   "40" -- "65" [label="1.0"];
#   "40" -- "70" [label="46.0"];
#   "40" -- "1" [label="2.0"];
#   "40" -- "9" [label="18.0"];
#   "40" -- "42" [label="37.0"];
#   "40" -- "22" [label="14.0"];
#   "40" -- "21" [label="25.0"];
#   "40" -- "76" [label="26.0"];
#   "40" -- "11" [label="21.0"];
#   "40" -- "72" [label="1.0"];
#   "40" -- "67" [label="32.0"];
#   "40" -- "8" [label="15.0"];
#   "40" -- "62" [label="14.0"];
#   "40" -- "30" [label="14.0"];
#   "40" -- "71" [label="23.0"];
#   "40" -- "13" [label="11.0"];
#   "40" -- "75" [label="9.0"];
#   "40" -- "5" [label="10.0"];
#   "40" -- "19" [label="29.0"];
#   "40" -- "46" [label="13.0"];
#   "40" -- "29" [label="32.0"];
#   "40" -- "25" [label="16.0"];
#   "40" -- "63" [label="40.0"];
#   "40" -- "38" [label="18.0"];
#   "40" -- "32" [label="19.0"];
#   "40" -- "37" [label="8.0"];
#   "40" -- "74" [label="40.0"];
#   "40" -- "18" [label="17.0"];
#   "40" -- "28" [label="19.0"];
#   "40" -- "12" [label="31.0"];
#   "40" -- "35" [label="17.0"];
#   "40" -- "68" [label="22.0"];
#   "40" -- "36" [label="22.0"];
#   "40" -- "7" [label="43.0"];
#   "41" -- "38" [label="22.0"];
#   "41" -- "63" [label="3.0"];
#   "41" -- "35" [label="25.0"];
#   "41" -- "5" [label="6.0"];
#   "41" -- "3" [label="8.0"];
#   "41" -- "16" [label="15.0"];
#   "41" -- "2" [label="32.0"];
#   "41" -- "37" [label="28.0"];
#   "41" -- "12" [label="15.0"];
#   "41" -- "1" [label="14.0"];
#   "41" -- "15" [label="13.0"];
#   "41" -- "50" [label="21.0"];
#   "41" -- "61" [label="17.0"];
#   "41" -- "72" [label="44.0"];
#   "41" -- "19" [label="36.0"];
#   "41" -- "66" [label="4.0"];
#   "41" -- "30" [label="6.0"];
#   "41" -- "65" [label="9.0"];
#   "41" -- "42" [label="43.0"];
#   "41" -- "18" [label="18.0"];
#   "41" -- "44" [label="26.0"];
#   "41" -- "10" [label="16.0"];
#   "41" -- "68" [label="2.0"];
#   "41" -- "23" [label="33.0"];
#   "41" -- "7" [label="11.0"];
#   "41" -- "59" [label="20.0"];
#   "41" -- "74" [label="7.0"];
#   "41" -- "73" [label="38.0"];
#   "42" -- "6" [label="44.0"];
#   "42" -- "56" [label="7.0"];
#   "42" -- "26" [label="29.0"];
#   "42" -- "17" [label="23.0"];
#   "42" -- "31" [label="9.0"];
#   "42" -- "9" [label="44.0"];
#   "42" -- "40" [label="37.0"];
#   "42" -- "72" [label="17.0"];
#   "42" -- "46" [label="8.0"];
#   "42" -- "10" [label="18.0"];
#   "42" -- "50" [label="16.0"];
#   "42" -- "15" [label="27.0"];
#   "42" -- "55" [label="8.0"];
#   "42" -- "44" [label="9.0"];
#   "42" -- "71" [label="15.0"];
#   "42" -- "32" [label="12.0"];
#   "42" -- "22" [label="9.0"];
#   "42" -- "41" [label="43.0"];
#   "42" -- "38" [label="37.0"];
#   "42" -- "33" [label="9.0"];
#   "42" -- "65" [label="40.0"];
#   "42" -- "70" [label="8.0"];
#   "42" -- "47" [label="2.0"];
#   "42" -- "18" [label="21.0"];
#   "42" -- "54" [label="3.0"];
#   "42" -- "29" [label="39.0"];
#   "42" -- "36" [label="15.0"];
#   "42" -- "2" [label="33.0"];
#   "43" -- "24" [label="33.0"];
#   "43" -- "39" [label="21.0"];
#   "43" -- "60" [label="17.0"];
#   "43" -- "44" [label="10.0"];
#   "43" -- "36" [label="10.0"];
#   "43" -- "6" [label="3.0"];
#   "43" -- "59" [label="32.0"];
#   "43" -- "48" [label="27.0"];
#   "43" -- "50" [label="3.0"];
#   "43" -- "78" [label="7.0"];
#   "43" -- "35" [label="29.0"];
#   "43" -- "74" [label="37.0"];
#   "43" -- "46" [label="14.0"];
#   "43" -- "31" [label="29.0"];
#   "43" -- "12" [label="29.0"];
#   "43" -- "66" [label="44.0"];
#   "43" -- "27" [label="23.0"];
#   "43" -- "45" [label="21.0"];
#   "43" -- "63" [label="35.0"];
#   "43" -- "29" [label="18.0"];
#   "43" -- "22" [label="43.0"];
#   "43" -- "62" [label="22.0"];
#   "43" -- "3" [label="36.0"];
#   "55" -- "44" [label="36.0"];
#   "55" -- "72" [label="11.0"];
#   "55" -- "74" [label="61.0"];
#   "55" -- "67" [label="7.0"];
#   "55" -- "15" [label="2.0"];
#   "55" -- "23" [label="9.0"];
#   "55" -- "6" [label="43.0"];
#   "55" -- "71" [label="3.0"];
#   "55" -- "33" [label="17.0"];
#   "55" -- "1" [label="45.0"];
#   "55" -- "52" [label="8.0"];
#   "55" -- "73" [label="39.0"];
#   "55" -- "34" [label="28.0"];
#   "55" -- "42" [label="8.0"];
#   "55" -- "9" [label="33.0"];
#   "55" -- "53" [label="16.0"];
#   "55" -- "59" [label="26.0"];
#   "55" -- "56" [label="22.0"];
#   "55" -- "61" [label="22.0"];
#   "55" -- "47" [label="8.0"];
#   "55" -- "54" [label="44.0"];
#   "55" -- "77" [label="38.0"];
#   "55" -- "58" [label="41.0"];
#   "55" -- "2" [label="44.0"];
#   "55" -- "32" [label="6.0"];
#   "45" -- "6" [label="63.0"];
#   "45" -- "46" [label="7.0"];
#   "45" -- "64" [label="49.0"];
#   "45" -- "56" [label="14.0"];
#   "45" -- "67" [label="43.0"];
#   "45" -- "8" [label="5.0"];
#   "45" -- "52" [label="10.0"];
#   "45" -- "10" [label="2.0"];
#   "45" -- "13" [label="40.0"];
#   "45" -- "60" [label="31.0"];
#   "45" -- "62" [label="35.0"];
#   "45" -- "3" [label="5.0"];
#   "45" -- "18" [label="1.0"];
#   "45" -- "22" [label="25.0"];
#   "45" -- "77" [label="38.0"];
#   "45" -- "2" [label="5.0"];
#   "45" -- "65" [label="7.0"];
#   "45" -- "31" [label="40.0"];
#   "45" -- "33" [label="6.0"];
#   "45" -- "28" [label="11.0"];
#   "45" -- "32" [label="42.0"];
#   "45" -- "57" [label="10.0"];
#   "45" -- "43" [label="21.0"];
#   "45" -- "14" [label="20.0"];
#   "45" -- "63" [label="38.0"];
#   "45" -- "51" [label="20.0"];
#   "45" -- "74" [label="32.0"];
#   "45" -- "66" [label="39.0"];
#   "45" -- "38" [label="26.0"];
#   "45" -- "39" [label="19.0"];
#   "58" -- "48" [label="21.0"];
#   "58" -- "60" [label="11.0"];
#   "58" -- "70" [label="26.0"];
#   "58" -- "72" [label="31.0"];
#   "58" -- "20" [label="41.0"];
#   "58" -- "1" [label="12.0"];
#   "58" -- "76" [label="12.0"];
#   "58" -- "4" [label="45.0"];
#   "58" -- "54" [label="1.0"];
#   "58" -- "17" [label="13.0"];
#   "58" -- "28" [label="11.0"];
#   "58" -- "19" [label="7.0"];
#   "58" -- "29" [label="3.0"];
#   "58" -- "47" [label="4.0"];
#   "58" -- "32" [label="3.0"];
#   "58" -- "64" [label="25.0"];
#   "58" -- "74" [label="43.0"];
# ...
#   "66" -- "10" [label="13.0"];
#   "66" -- "64" [label="9.0"];
#   "66" -- "72" [label="29.0"];
#   "66" -- "41" [label="4.0"];
#   "66" -- "70" [label="24.0"];
#   "66" -- "17" [label="46.0"];
#   "66" -- "43" [label="44.0"];
#   "66" -- "18" [label="18.0"];
#   "66" -- "47" [label="12.0"];
#   "66" -- "65" [label="13.0"];
#   "66" -- "77" [label="8.0"];
#   "66" -- "5" [label="20.0"];
#   "66" -- "45" [label="39.0"];
#   "66" -- "76" [label="26.0"];
#   "66" -- "36" [label="32.0"];
#   "61" -- "33" [label="28.0"];
#   "61" -- "50" [label="16.0"];
#   "61" -- "15" [label="32.0"];
#   "61" -- "74" [label="5.0"];
#   "61" -- "25" [label="9.0"];
#   "61" -- "65" [label="4.0"];
#   "61" -- "2" [label="33.0"];
#   "61" -- "32" [label="12.0"];
#   "61" -- "72" [label="26.0"];
#   "61" -- "11" [label="20.0"];
#   "61" -- "18" [label="5.0"];
#   "61" -- "10" [label="44.0"];
#   "61" -- "44" [label="42.0"];
#   "61" -- "5" [label="29.0"];
#   "61" -- "41" [label="17.0"];
#   "61" -- "60" [label="6.0"];
#   "61" -- "54" [label="26.0"];
#   "61" -- "31" [label="40.0"];
#   "61" -- "3" [label="31.0"];
#   "61" -- "78" [label="15.0"];
#   "61" -- "38" [label="19.0"];
#   "61" -- "52" [label="5.0"];
#   "61" -- "14" [label="6.0"];
#   "61" -- "55" [label="22.0"];
#   "61" -- "69" [label="6.0"];
#   "61" -- "23" [label="30.0"];
#   "61" -- "51" [label="40.0"];
#   "61" -- "67" [label="9.0"];
#   "63" -- "14" [label="5.0"];
#   "63" -- "41" [label="3.0"];
#   "63" -- "72" [label="13.0"];
#   "63" -- "31" [label="34.0"];
#   "63" -- "6" [label="37.0"];
#   "63" -- "37" [label="2.0"];
#   "63" -- "4" [label="44.0"];
#   "63" -- "59" [label="7.0"];
#   "63" -- "52" [label="25.0"];
#   "63" -- "17" [label="41.0"];
#   "63" -- "54" [label="2.0"];
#   "63" -- "44" [label="22.0"];
#   "63" -- "30" [label="36.0"];
#   "63" -- "64" [label="16.0"];
#   "63" -- "15" [label="33.0"];
#   "63" -- "48" [label="5.0"];
#   "63" -- "28" [label="10.0"];
#   "63" -- "1" [label="43.0"];
#   "63" -- "19" [label="45.0"];
#   "63" -- "40" [label="40.0"];
#   "63" -- "43" [label="35.0"];
#   "63" -- "45" [label="38.0"];
#   "63" -- "67" [label="27.0"];
#   "63" -- "60" [label="43.0"];
#   "63" -- "13" [label="30.0"];
#   "63" -- "75" [label="43.0"];
#   "63" -- "73" [label="9.0"];
#   "64" -- "45" [label="49.0"];
#   "64" -- "19" [label="42.0"];
#   "64" -- "8" [label="24.0"];
#   "64" -- "37" [label="5.0"];
#   "64" -- "76" [label="36.0"];
#   "64" -- "9" [label="19.0"];
#   "64" -- "67" [label="10.0"];
#   "64" -- "1" [label="13.0"];
#   "64" -- "66" [label="9.0"];
#   "64" -- "34" [label="38.0"];
#   "64" -- "32" [label="27.0"];
#   "64" -- "12" [label="37.0"];
#   "64" -- "63" [label="16.0"];
#   "64" -- "60" [label="28.0"];
#   "64" -- "3" [label="7.0"];
#   "64" -- "13" [label="1.0"];
#   "64" -- "16" [label="23.0"];
#   "64" -- "44" [label="3.0"];
#   "64" -- "35" [label="28.0"];
#   "64" -- "30" [label="30.0"];
#   "64" -- "58" [label="25.0"];
#   "64" -- "69" [label="26.0"];
#   "64" -- "27" [label="10.0"];
#   "69" -- "49" [label="40.0"];
#   "69" -- "66" [label="16.0"];
#   "69" -- "19" [label="36.0"];
#   "69" -- "53" [label="4.0"];
#   "69" -- "3" [label="21.0"];
#   "69" -- "75" [label="3.0"];
#   "69" -- "77" [label="26.0"];
#   "69" -- "71" [label="45.0"];
#   "69" -- "32" [label="23.0"];
#   "69" -- "34" [label="7.0"];
#   "69" -- "23" [label="3.0"];
#   "69" -- "36" [label="6.0"];
#   "69" -- "15" [label="23.0"];
#   "69" -- "61" [label="6.0"];
#   "69" -- "21" [label="10.0"];
#   "69" -- "59" [label="35.0"];
#   "69" -- "46" [label="21.0"];
#   "69" -- "24" [label="4.0"];
#   "69" -- "62" [label="28.0"];
#   "69" -- "52" [label="17.0"];
#   "69" -- "27" [label="19.0"];
#   "69" -- "10" [label="20.0"];
#   "69" -- "64" [label="26.0"];
#   "70" -- "6" [label="37.0"];
#   "70" -- "58" [label="26.0"];
#   "70" -- "10" [label="10.0"];
#   "70" -- "29" [label="3.0"];
#   "70" -- "39" [label="3.0"];
#   "70" -- "40" [label="46.0"];
#   "70" -- "8" [label="40.0"];
#   "70" -- "47" [label="2.0"];
#   "70" -- "13" [label="12.0"];
#   "70" -- "52" [label="28.0"];
#   "70" -- "17" [label="7.0"];
#   "70" -- "50" [label="9.0"];
#   "70" -- "66" [label="24.0"];
#   "70" -- "20" [label="34.0"];
#   "70" -- "42" [label="8.0"];
#   "70" -- "34" [label="28.0"];
#   "70" -- "48" [label="44.0"];
#   "70" -- "19" [label="2.0"];
#   "70" -- "53" [label="42.0"];
#   "70" -- "44" [label="23.0"];
#   "70" -- "3" [label="28.0"];
#   "70" -- "12" [label="9.0"];
#   "71" -- "29" [label="4.0"];
#   "71" -- "32" [label="14.0"];
#   "71" -- "55" [label="3.0"];
#   "71" -- "22" [label="3.0"];
#   "71" -- "54" [label="36.0"];
#   "71" -- "31" [label="31.0"];
#   "71" -- "6" [label="22.0"];
#   "71" -- "35" [label="10.0"];
#   "71" -- "75" [label="10.0"];
#   "71" -- "1" [label="29.0"];
#   "71" -- "69" [label="45.0"];
#   "71" -- "14" [label="24.0"];
#   "71" -- "42" [label="15.0"];
#   "71" -- "50" [label="17.0"];
#   "71" -- "77" [label="19.0"];
#   "71" -- "40" [label="23.0"];
#   "71" -- "15" [label="1.0"];
#   "71" -- "28" [label="28.0"];
#   "71" -- "72" [label="2.0"];
#   "71" -- "18" [label="32.0"];
#   "71" -- "65" [label="20.0"];
#   "74" -- "55" [label="61.0"];
#   "74" -- "52" [label="46.0"];
#   "74" -- "60" [label="44.0"];
#   "74" -- "25" [label="35.0"];
#   "74" -- "17" [label="35.0"];
#   "74" -- "22" [label="13.0"];
#   "74" -- "61" [label="5.0"];
#   "74" -- "23" [label="26.0"];
#   "74" -- "18" [label="25.0"];
#   "74" -- "14" [label="45.0"];
#   "74" -- "1" [label="46.0"];
#   "74" -- "9" [label="37.0"];
#   "74" -- "37" [label="14.0"];
#   "74" -- "43" [label="37.0"];
#   "74" -- "53" [label="2.0"];
#   "74" -- "73" [label="9.0"];
#   "74" -- "56" [label="1.0"];
#   "74" -- "40" [label="40.0"];
#   "74" -- "41" [label="7.0"];
#   "74" -- "45" [label="32.0"];
#   "74" -- "58" [label="43.0"];
#   "74" -- "47" [label="1.0"];
#   "74" -- "20" [label="4.0"];
#   "74" -- "59" [label="30.0"];
#   "76" -- "72" [label="24.0"];
#   "76" -- "56" [label="11.0"];
#   "76" -- "53" [label="42.0"];
#   "76" -- "3" [label="15.0"];
#   "76" -- "47" [label="40.0"];
#   "76" -- "64" [label="36.0"];
#   "76" -- "46" [label="8.0"];
#   "76" -- "58" [label="12.0"];
#   "76" -- "49" [label="8.0"];
#   "76" -- "40" [label="26.0"];
#   "76" -- "12" [label="15.0"];
#   "76" -- "75" [label="1.0"];
#   "76" -- "62" [label="7.0"];
#   "76" -- "48" [label="20.0"];
#   "76" -- "21" [label="42.0"];
#   "76" -- "11" [label="44.0"];
#   "76" -- "15" [label="33.0"];
#   "76" -- "66" [label="26.0"];
#   "77" -- "31" [label="4.0"];
#   "77" -- "50" [label="22.0"];
#   "77" -- "36" [label="12.0"];
#   "77" -- "13" [label="36.0"];
#   "77" -- "72" [label="31.0"];
#   "77" -- "19" [label="31.0"];
#   "77" -- "38" [label="9.0"];
#   "77" -- "10" [label="44.0"];
#   "77" -- "78" [label="34.0"];
#   "77" -- "1" [label="19.0"];
#   "77" -- "22" [label="35.0"];
#   "77" -- "60" [label="43.0"];
#   "77" -- "26" [label="15.0"];
#   "77" -- "57" [label="9.0"];
#   "77" -- "23" [label="20.0"];
#   "77" -- "69" [label="26.0"];
#   "77" -- "52" [label="13.0"];
#   "77" -- "59" [label="13.0"];
#   "77" -- "30" [label="2.0"];
#   "77" -- "71" [label="19.0"];
#   "77" -- "45" [label="38.0"];
#   "77" -- "25" [label="37.0"];
#   "77" -- "16" [label="37.0"];
#   "77" -- "34" [label="4.0"];
#   "77" -- "9" [label="1.0"];
#   "77" -- "29" [label="5.0"];
#   "77" -- "55" [label="38.0"];
#   "77" -- "66" [label="8.0"];
#   "77" -- "3" [label="29.0"];
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 Source(read_dot_file("hd2dijkstra"))
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:152, in DisplayFormatter.format(self, obj, include, exclude)
#     148 if self.ipython_display_formatter(obj):
#     149     # object handled itself, don't proceed
#     150     return {}, {}
# --> 152 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#     154 if format_dict or md_dict:
#     155     if include:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/jupyter_integration.py:98, in JupyterIntegration._repr_mimebundle_(self, include, exclude, **_)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/jupyter_integration.py:112, in JupyterIntegration._repr_image_svg_xml(self)
#     110 def _repr_image_svg_xml(self) -> str:
#     111     """Return the rendered graph as SVG string."""
# --> 112     return self.pipe(format='svg', encoding=SVG_ENCODING)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:149, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     146 if encoding is not None:
#     147     if codecs.lookup(encoding) is codecs.lookup(self.encoding):
#     148         # common case: both stdin and stdout need the same encoding
# --> 149         return self._pipe_lines_string(*args, encoding=encoding, **kwargs)
#     150     try:
#     151         raw = self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/piping.py:212, in pipe_lines_string(engine, format, input_lines, encoding, renderer, formatter, neato_no_op, quiet)
#     206 cmd = dot_command.command(engine, format,
#     207                           renderer=renderer,
#     208                           formatter=formatter,
#     209                           neato_no_op=neato_no_op)
#     210 kwargs = {'input_lines': input_lines, 'encoding': encoding}
# --> 212 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     213 return proc.stdout
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/execute.py:76, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      74     if kwargs.pop('capture_output'):
#      75         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 76     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77 else:
#      78     proc = subprocess.run(cmd, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/execute.py:102, in _run_input_lines(cmd, input_lines, kwargs)
#      99 for line in input_lines:
#     100     stdin_write(line)
# --> 102 stdout, stderr = popen.communicate()
#     103 return subprocess.CompletedProcess(popen.args, popen.returncode,
#     104                                    stdout=stdout, stderr=stderr)
#
# File /opt/homebrew/anaconda3/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/homebrew/anaconda3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
Source(read_dot_file("hd3dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/hd3dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "1" [label="1 (154.0)"];
#   "19" [label="19 (98.0)"];
#   "2" [label="2 (90.0)"];
#   "57" [label="57 (49.0)"];
#   "3" [label="3 (186.0)"];
#   "4" [label="4 (190.0)"];
#   "5" [label="5 (178.0)"];
#   "6" [label="6 (114.0)"];
#   "7" [label="7 (123.0)"];
#   "8" [label="8"];
#   "76" [label="76"];
#   "9" [label="9"];
#   "10" [label="10 (123.0)"];
#   "11" [label="11"];
#   "12" [label="12 (104.0)"];
#   "13" [label="13"];
#   "14" [label="14"];
#   "15" [label="15"];
#   "16" [label="16 (207.0)"];
#   "17" [label="17 (134.0)"];
#   "18" [label="18 (123.0)"];
#   "38" [label="38 (75.0)"];
#   "20" [label="20 (155.0)"];
#   "21" [label="21"];
#   "22" [label="22 (198.0)"];
#   "23" [label="23 (68.0)"];
#   "24" [label="24 (90.0)"];
#   "25" [label="25 (170.0)"];
#   "26" [label="26 (135.0)"];
#   "27" [label="27"];
#   "28" [label="28 (103.0)"];
#   "29" [label="29 (145.0)"];
#   "30" [label="30"];
#   "31" [label="31 (54.0)"];
#   "32" [label="32 (111.0)"];
#   "33" [label="33 (163.0)"];
#   "34" [label="34 (173.0)"];
#   "35" [label="35 (115.0)"];
#   "36" [label="36 (87.0)"];
#   "37" [label="37 (159.0)"];
#   "39" [label="39"];
#   "40" [label="40 (94.0)"];
#   "41" [label="41 (102.0)"];
#   "42" [label="42"];
#   "43" [label="43 (76.0)"];
#   "44" [label="44 (67.0)"];
#   "45" [label="45 (167.0)"];
#   "46" [label="46 (138.0)"];
#   "47" [label="47 (216.0)"];
#   "48" [label="48"];
#   "49" [label="49 (172.0)"];
#   "50" [label="50 (102.0)"];
#   "51" [label="51 (212.0)"];
#   "52" [label="52 (163.0)"];
#   "53" [label="53 (103.0)"];
#   "54" [label="54 (112.0)"];
#   "55" [label="55"];
#   "56" [label="56 (182.0)"];
#   "58" [label="58 (145.0)"];
#   "59" [label="59 (92.0)"];
#   "60" [label="60"];
#   "61" [label="61"];
#   "62" [label="62 (194.0)"];
#   "63" [label="63"];
#   "64" [label="64 (182.0)"];
#   "65" [label="65"];
#   "66" [label="66 (201.0)"];
#   "67" [label="67 (96.0)"];
#   "68" [label="68"];
#   "69" [label="69 (85.0)"];
#   "70" [label="70 (121.0)"];
#   "71" [label="71 (108.0)"];
#   "72" [label="72 (161.0)"];
#   "73" [label="73 (130.0)"];
#   "74" [label="74 (100.0)"];
#   "75" [label="75 (120.0)"];
#   "77" [label="77"];
#   "78" [label="78 (118.0)"];
#   "79" [label="79 (215.0)"];
#   "80" [label="80 (92.0)"];
#   "81" [label="81 (156.0)"];
#   "82" [label="82 (162.0)"];
#   "83" [label="83 (163.0)"];
#   "84" [label="84 (168.0)"];
#   "85" [label="85 (0.0)"];
#   "86" [label="86 (71.0)"];
#   "87" [label="87 (110.0)"];
#   "88" [label="88"];
#   "89" [label="89"];
#   "90" [label="90 (190.0)"];
#   "91" [label="91 (217.0)"];
#   "92" [label="92 (100.0)"];
#   "93" [label="93 (105.0)"];
#   "94" [label="94 (178.0)"];
#   "1" -- "19" [label="56.0"];
#   "1" -- "3" [label="32.0"];
#   "1" -- "4" [label="36.0"];
#   "1" -- "5" [label="24.0"];
#   "1" -- "16" [label="53.0"];
#   "1" -- "20" [label="1.0"];
#   "1" -- "22" [label="44.0"];
#   "1" -- "25" [label="16.0"];
#   "1" -- "34" [label="19.0"];
#   "1" -- "37" [label="5.0"];
#   "1" -- "45" [label="13.0"];
#   "1" -- "47" [label="62.0"];
#   "1" -- "49" [label="18.0"];
#   "1" -- "51" [label="58.0"];
#   "1" -- "52" [label="9.0"];
#   "1" -- "56" [label="28.0"];
#   "1" -- "62" [label="40.0"];
#   "1" -- "64" [label="28.0"];
#   "1" -- "66" [label="47.0"];
#   "1" -- "72" [label="7.0"];
#   "1" -- "79" [label="61.0"];
#   "1" -- "81" [label="2.0"];
#   "1" -- "83" [label="9.0"];
#   "1" -- "84" [label="14.0"];
#   "1" -- "90" [label="36.0"];
#   "1" -- "91" [label="63.0"];
#   "1" -- "94" [label="24.0"];
#   "19" -- "1" [label="56.0"];
#   "19" -- "6" [label="16.0"];
#   "19" -- "7" [label="25.0"];
#   "19" -- "10" [label="25.0"];
#   "19" -- "12" [label="6.0"];
#   "19" -- "17" [label="36.0"];
#   "19" -- "18" [label="25.0"];
#   "19" -- "38" [label="23.0"];
#   "19" -- "26" [label="37.0"];
#   "19" -- "29" [label="47.0"];
#   "19" -- "32" [label="13.0"];
#   "19" -- "33" [label="65.0"];
#   "19" -- "35" [label="17.0"];
#   "19" -- "41" [label="4.0"];
#   "19" -- "46" [label="40.0"];
#   "19" -- "50" [label="4.0"];
#   "19" -- "53" [label="5.0"];
#   "19" -- "58" [label="47.0"];
#   "19" -- "82" [label="64.0"];
#   "19" -- "87" [label="12.0"];
#   "19" -- "93" [label="7.0"];
#   "2" -- "57" [label="41.0"];
#   "57" -- "2" [label="41.0"];
#   "57" -- "23" [label="19.0"];
#   "57" -- "28" [label="54.0"];
#   "57" -- "31" [label="5.0"];
#   "57" -- "43" [label="27.0"];
#   "57" -- "44" [label="18.0"];
#   "57" -- "54" [label="63.0"];
#   "57" -- "38" [label="26.0"];
#   "57" -- "59" [label="43.0"];
#   "57" -- "71" [label="59.0"];
#   "57" -- "74" [label="51.0"];
#   "57" -- "80" [label="43.0"];
#   "57" -- "85" [label="49.0"];
#   "57" -- "86" [label="22.0"];
#   "57" -- "92" [label="51.0"];
#   "3" -- "1" [label="32.0"];
#   "4" -- "1" [label="36.0"];
#   "5" -- "1" [label="24.0"];
#   "6" -- "19" [label="16.0"];
#   "7" -- "19" [label="25.0"];
#   "8" -- "76" [label="6.0"];
#   "76" -- "8" [label="6.0"];
#   "76" -- "9" [label="23.0"];
#   "76" -- "11" [label="64.0"];
#   "76" -- "13" [label="12.0"];
#   "76" -- "14" [label="18.0"];
#   "76" -- "15" [label="47.0"];
#   "76" -- "21" [label="57.0"];
#   "76" -- "27" [label="22.0"];
#   "76" -- "30" [label="15.0"];
#   "76" -- "39" [label="33.0"];
#   "76" -- "42" [label="32.0"];
#   "76" -- "48" [label="46.0"];
#   "76" -- "55" [label="9.0"];
#   "76" -- "60" [label="37.0"];
#   "76" -- "61" [label="14.0"];
#   "76" -- "63" [label="27.0"];
#   "76" -- "65" [label="32.0"];
#   "76" -- "68" [label="58.0"];
#   "76" -- "77" [label="9.0"];
#   "76" -- "88" [label="55.0"];
#   "76" -- "89" [label="26.0"];
#   "9" -- "76" [label="23.0"];
#   "10" -- "19" [label="25.0"];
#   "11" -- "76" [label="64.0"];
#   "12" -- "19" [label="6.0"];
#   "13" -- "76" [label="12.0"];
#   "14" -- "76" [label="18.0"];
#   "15" -- "76" [label="47.0"];
#   "16" -- "1" [label="53.0"];
#   "17" -- "19" [label="36.0"];
#   "18" -- "19" [label="25.0"];
#   "38" -- "19" [label="23.0"];
#   "38" -- "24" [label="15.0"];
#   "38" -- "36" [label="12.0"];
#   "38" -- "40" [label="19.0"];
#   "38" -- "57" [label="26.0"];
#   "38" -- "67" [label="21.0"];
#   "38" -- "69" [label="10.0"];
#   "38" -- "70" [label="46.0"];
#   "38" -- "73" [label="55.0"];
#   "38" -- "75" [label="45.0"];
#   "38" -- "78" [label="43.0"];
#   "20" -- "1" [label="1.0"];
#   "21" -- "76" [label="57.0"];
#   "22" -- "1" [label="44.0"];
#   "23" -- "57" [label="19.0"];
#   "24" -- "38" [label="15.0"];
#   "25" -- "1" [label="16.0"];
#   "26" -- "19" [label="37.0"];
#   "27" -- "76" [label="22.0"];
#   "28" -- "57" [label="54.0"];
#   "29" -- "19" [label="47.0"];
#   "30" -- "76" [label="15.0"];
#   "31" -- "57" [label="5.0"];
#   "32" -- "19" [label="13.0"];
#   "33" -- "19" [label="65.0"];
#   "34" -- "1" [label="19.0"];
#   "35" -- "19" [label="17.0"];
#   "36" -- "38" [label="12.0"];
#   "37" -- "1" [label="5.0"];
#   "39" -- "76" [label="33.0"];
#   "40" -- "38" [label="19.0"];
#   "41" -- "19" [label="4.0"];
#   "42" -- "76" [label="32.0"];
#   "43" -- "57" [label="27.0"];
#   "44" -- "57" [label="18.0"];
#   "45" -- "1" [label="13.0"];
#   "46" -- "19" [label="40.0"];
#   "47" -- "1" [label="62.0"];
#   "48" -- "76" [label="46.0"];
#   "49" -- "1" [label="18.0"];
#   "50" -- "19" [label="4.0"];
#   "51" -- "1" [label="58.0"];
#   "52" -- "1" [label="9.0"];
#   "53" -- "19" [label="5.0"];
#   "54" -- "57" [label="63.0"];
#   "55" -- "76" [label="9.0"];
#   "56" -- "1" [label="28.0"];
#   "58" -- "19" [label="47.0"];
#   "59" -- "57" [label="43.0"];
#   "60" -- "76" [label="37.0"];
#   "61" -- "76" [label="14.0"];
#   "62" -- "1" [label="40.0"];
#   "63" -- "76" [label="27.0"];
#   "64" -- "1" [label="28.0"];
#   "65" -- "76" [label="32.0"];
#   "66" -- "1" [label="47.0"];
#   "67" -- "38" [label="21.0"];
#   "68" -- "76" [label="58.0"];
#   "69" -- "38" [label="10.0"];
#   "70" -- "38" [label="46.0"];
#   "71" -- "57" [label="59.0"];
#   "72" -- "1" [label="7.0"];
#   "73" -- "38" [label="55.0"];
#   "74" -- "57" [label="51.0"];
#   "75" -- "38" [label="45.0"];
#   "77" -- "76" [label="9.0"];
#   "78" -- "38" [label="43.0"];
#   "79" -- "1" [label="61.0"];
#   "80" -- "57" [label="43.0"];
#   "81" -- "1" [label="2.0"];
#   "82" -- "19" [label="64.0"];
#   "83" -- "1" [label="9.0"];
#   "84" -- "1" [label="14.0"];
#   "85" -- "57" [label="49.0"];
#   "86" -- "57" [label="22.0"];
#   "87" -- "19" [label="12.0"];
#   "88" -- "76" [label="55.0"];
#   "89" -- "76" [label="26.0"];
#   "90" -- "1" [label="36.0"];
#   "91" -- "1" [label="63.0"];
#   "92" -- "57" [label="51.0"];
#   "93" -- "19" [label="7.0"];
#   "94" -- "1" [label="24.0"];
# }

# %%
Source(read_dot_file("g1dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/g1dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "P" [label="P (0.0)"];
#   "Q" [label="Q (1.0)"];
#   "S" [label="S (4.0)"];
#   "T" [label="T (4.0)"];
#   "R" [label="R (2.0)"];
#   "U" [label="U (3.0)"];
#   "P" -- "Q" [label="1.0"];
#   "P" -- "S" [label="6.0"];
#   "P" -- "T" [label="7.0"];
#   "Q" -- "R" [label="1.0"];
#   "Q" -- "S" [label="4.0"];
#   "S" -- "T" [label="0.0"];
#   "S" -- "U" [label="2.0"];
#   "T" -- "U" [label="2.0"];
#   "R" -- "U" [label="1.0"];
#   "R" -- "S" [label="2.0"];
# }

# %%
Source(read_dot_file("hd4dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/hd4dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "1" [label="1 (13.0)"];
#   "59" [label="59 (20.0)"];
#   "2" [label="2 (30.0)"];
#   "31" [label="31 (17.0)"];
#   "3" [label="3 (17.0)"];
#   "41" [label="41 (34.0)"];
#   "4" [label="4 (33.0)"];
#   "5" [label="5 (16.0)"];
#   "36" [label="36 (16.0)"];
#   "6" [label="6 (9.0)"];
#   "23" [label="23 (11.0)"];
#   "7" [label="7 (31.0)"];
#   "54" [label="54 (21.0)"];
#   "8" [label="8 (34.0)"];
#   "19" [label="19 (19.0)"];
#   "9" [label="9 (14.0)"];
#   "20" [label="20 (23.0)"];
#   "10" [label="10 (20.0)"];
#   "16" [label="16 (42.0)"];
#   "11" [label="11 (21.0)"];
#   "27" [label="27 (15.0)"];
#   "12" [label="12 (19.0)"];
#   "13" [label="13 (24.0)"];
#   "26" [label="26 (15.0)"];
#   "14" [label="14 (34.0)"];
#   "64" [label="64 (42.0)"];
#   "15" [label="15 (27.0)"];
#   "49" [label="49 (0.0)"];
#   "65" [label="65 (10.0)"];
#   "17" [label="17 (15.0)"];
#   "18" [label="18 (16.0)"];
#   "29" [label="29 (18.0)"];
#   "52" [label="52 (19.0)"];
#   "21" [label="21 (18.0)"];
#   "58" [label="58 (14.0)"];
#   "22" [label="22 (21.0)"];
#   "24" [label="24 (21.0)"];
#   "25" [label="25 (28.0)"];
#   "40" [label="40 (21.0)"];
#   "67" [label="67 (19.0)"];
#   "28" [label="28 (45.0)"];
#   "30" [label="30 (26.0)"];
#   "50" [label="50 (27.0)"];
#   "32" [label="32 (20.0)"];
#   "33" [label="33 (16.0)"];
#   "46" [label="46 (23.0)"];
#   "34" [label="34 (28.0)"];
#   "68" [label="68 (22.0)"];
#   "35" [label="35 (27.0)"];
#   "53" [label="53 (18.0)"];
#   "37" [label="37 (22.0)"];
#   "38" [label="38 (21.0)"];
#   "45" [label="45 (11.0)"];
#   "39" [label="39 (18.0)"];
#   "51" [label="51 (22.0)"];
#   "42" [label="42 (14.0)"];
#   "43" [label="43 (26.0)"];
#   "44" [label="44 (27.0)"];
#   "61" [label="61 (27.0)"];
#   "47" [label="47 (17.0)"];
#   "48" [label="48 (24.0)"];
#   "55" [label="55 (17.0)"];
#   "56" [label="56 (17.0)"];
#   "57" [label="57 (22.0)"];
#   "60" [label="60 (12.0)"];
#   "62" [label="62 (21.0)"];
#   "63" [label="63 (10.0)"];
#   "66" [label="66 (25.0)"];
#   "1" -- "59" [label="16.0"];
#   "1" -- "9" [label="44.0"];
#   "1" -- "39" [label="5.0"];
#   "1" -- "29" [label="28.0"];
#   "1" -- "6" [label="4.0"];
#   "1" -- "18" [label="3.0"];
#   "1" -- "2" [label="30.0"];
#   "1" -- "40" [label="8.0"];
#   "1" -- "38" [label="32.0"];
#   "1" -- "26" [label="2.0"];
#   "1" -- "11" [label="24.0"];
#   "1" -- "50" [label="36.0"];
#   "1" -- "27" [label="36.0"];
#   "1" -- "37" [label="9.0"];
#   "1" -- "19" [label="30.0"];
#   "1" -- "54" [label="11.0"];
#   "1" -- "45" [label="34.0"];
#   "1" -- "42" [label="1.0"];
#   "1" -- "57" [label="39.0"];
#   "1" -- "66" [label="23.0"];
#   "1" -- "51" [label="9.0"];
#   "1" -- "12" [label="44.0"];
#   "1" -- "30" [label="26.0"];
#   "1" -- "21" [label="9.0"];
#   "1" -- "64" [label="43.0"];
#   "59" -- "1" [label="16.0"];
#   "59" -- "23" [label="62.0"];
#   "59" -- "55" [label="45.0"];
#   "59" -- "21" [label="43.0"];
#   "59" -- "3" [label="3.0"];
#   "59" -- "12" [label="12.0"];
#   "59" -- "30" [label="43.0"];
#   "2" -- "31" [label="46.0"];
#   "2" -- "12" [label="11.0"];
#   "2" -- "1" [label="30.0"];
#   "2" -- "39" [label="17.0"];
#   "2" -- "54" [label="38.0"];
#   "2" -- "18" [label="38.0"];
#   "2" -- "3" [label="35.0"];
#   "31" -- "2" [label="46.0"];
#   "31" -- "50" [label="14.0"];
#   "31" -- "57" [label="25.0"];
#   "31" -- "33" [label="1.0"];
#   "3" -- "41" [label="63.0"];
#   "3" -- "59" [label="3.0"];
#   "3" -- "4" [label="18.0"];
#   "3" -- "14" [label="38.0"];
#   "3" -- "49" [label="23.0"];
#   "3" -- "65" [label="20.0"];
#   "3" -- "51" [label="46.0"];
#   "3" -- "27" [label="2.0"];
#   "3" -- "18" [label="18.0"];
#   "3" -- "23" [label="20.0"];
#   "3" -- "60" [label="6.0"];
#   "3" -- "47" [label="5.0"];
#   "3" -- "61" [label="45.0"];
#   "3" -- "32" [label="32.0"];
#   "3" -- "34" [label="44.0"];
#   "3" -- "21" [label="28.0"];
#   "3" -- "57" [label="5.0"];
#   "3" -- "42" [label="45.0"];
#   "3" -- "55" [label="46.0"];
#   "3" -- "15" [label="43.0"];
#   "3" -- "39" [label="25.0"];
#   "3" -- "44" [label="39.0"];
#   "3" -- "2" [label="35.0"];
#   "3" -- "19" [label="46.0"];
#   "3" -- "24" [label="10.0"];
#   "3" -- "63" [label="43.0"];
#   "3" -- "10" [label="33.0"];
#   "41" -- "3" [label="63.0"];
#   "41" -- "4" [label="33.0"];
#   "41" -- "67" [label="26.0"];
#   "41" -- "66" [label="19.0"];
#   "41" -- "15" [label="7.0"];
#   "41" -- "60" [label="22.0"];
#   "4" -- "41" [label="33.0"];
#   "4" -- "17" [label="18.0"];
#   "4" -- "3" [label="18.0"];
#   "4" -- "30" [label="39.0"];
#   "4" -- "60" [label="26.0"];
#   "4" -- "15" [label="13.0"];
#   "4" -- "12" [label="25.0"];
#   "5" -- "36" [label="35.0"];
#   "5" -- "12" [label="23.0"];
#   "5" -- "6" [label="7.0"];
#   "36" -- "5" [label="35.0"];
#   "36" -- "53" [label="54.0"];
#   "36" -- "44" [label="24.0"];
#   "36" -- "42" [label="2.0"];
#   "36" -- "40" [label="9.0"];
#   "36" -- "38" [label="5.0"];
#   "36" -- "24" [label="10.0"];
#   "36" -- "56" [label="4.0"];
#   "36" -- "10" [label="16.0"];
#   "36" -- "8" [label="18.0"];
#   "36" -- "55" [label="2.0"];
#   "36" -- "27" [label="32.0"];
#   "36" -- "57" [label="17.0"];
#   "36" -- "34" [label="39.0"];
#   "36" -- "19" [label="16.0"];
#   "36" -- "48" [label="44.0"];
#   "36" -- "29" [label="42.0"];
#   "36" -- "17" [label="35.0"];
#   "36" -- "66" [label="19.0"];
#   "36" -- "26" [label="29.0"];
#   "36" -- "62" [label="36.0"];
#   "6" -- "23" [label="2.0"];
#   "6" -- "53" [label="9.0"];
#   "6" -- "15" [label="33.0"];
#   "6" -- "55" [label="27.0"];
#   "6" -- "65" [label="1.0"];
#   "6" -- "1" [label="4.0"];
#   "6" -- "21" [label="16.0"];
#   "6" -- "12" [label="23.0"];
#   "6" -- "49" [label="9.0"];
#   "6" -- "54" [label="30.0"];
#   "6" -- "27" [label="17.0"];
#   "6" -- "37" [label="36.0"];
#   "6" -- "46" [label="18.0"];
#   "6" -- "17" [label="6.0"];
#   "6" -- "63" [label="1.0"];
#   "6" -- "7" [label="39.0"];
#   "6" -- "45" [label="7.0"];
#   "6" -- "5" [label="7.0"];
#   "23" -- "6" [label="2.0"];
#   "23" -- "22" [label="10.0"];
#   "23" -- "59" [label="62.0"];
#   "23" -- "37" [label="26.0"];
#   "23" -- "66" [label="45.0"];
#   "23" -- "21" [label="19.0"];
#   "23" -- "9" [label="3.0"];
#   "23" -- "3" [label="20.0"];
#   "23" -- "33" [label="5.0"];
#   "7" -- "54" [label="10.0"];
#   "7" -- "35" [label="42.0"];
#   "7" -- "6" [label="39.0"];
#   "54" -- "7" [label="10.0"];
#   "54" -- "12" [label="16.0"];
#   "54" -- "8" [label="46.0"];
#   "54" -- "15" [label="38.0"];
#   "54" -- "11" [label="22.0"];
#   "54" -- "60" [label="9.0"];
#   "54" -- "63" [label="27.0"];
#   "54" -- "66" [label="4.0"];
#   "54" -- "55" [label="27.0"];
#   "54" -- "42" [label="9.0"];
#   "54" -- "2" [label="38.0"];
#   "54" -- "37" [label="46.0"];
#   "54" -- "6" [label="30.0"];
#   "54" -- "24" [label="46.0"];
#   "54" -- "25" [label="26.0"];
#   "54" -- "29" [label="26.0"];
#   "54" -- "1" [label="11.0"];
#   "54" -- "62" [label="46.0"];
#   "54" -- "16" [label="46.0"];
#   "54" -- "51" [label="30.0"];
#   "54" -- "13" [label="18.0"];
#   "8" -- "19" [label="35.0"];
#   "8" -- "20" [label="32.0"];
#   "8" -- "30" [label="21.0"];
#   "8" -- "54" [label="46.0"];
#   "8" -- "24" [label="23.0"];
#   "8" -- "36" [label="18.0"];
#   "8" -- "15" [label="23.0"];
#   "8" -- "21" [label="41.0"];
#   "8" -- "45" [label="45.0"];
#   "19" -- "8" [label="35.0"];
#   "19" -- "52" [label="32.0"];
#   "19" -- "12" [label="25.0"];
#   "19" -- "51" [label="19.0"];
#   "19" -- "36" [label="16.0"];
#   "19" -- "1" [label="30.0"];
#   "19" -- "45" [label="8.0"];
#   "19" -- "3" [label="46.0"];
#   "9" -- "20" [label="14.0"];
#   "9" -- "49" [label="32.0"];
#   "9" -- "1" [label="44.0"];
#   "9" -- "33" [label="8.0"];
#   "9" -- "56" [label="24.0"];
#   "9" -- "35" [label="13.0"];
#   "9" -- "23" [label="3.0"];
#   "9" -- "43" [label="44.0"];
#   "9" -- "45" [label="21.0"];
#   "9" -- "38" [label="39.0"];
#   "9" -- "29" [label="8.0"];
#   "9" -- "48" [label="32.0"];
#   "9" -- "39" [label="21.0"];
#   "9" -- "27" [label="23.0"];
#   "9" -- "42" [label="9.0"];
#   "9" -- "58" [label="28.0"];
#   "9" -- "17" [label="31.0"];
#   "20" -- "9" [label="14.0"];
#   "20" -- "8" [label="32.0"];
#   "20" -- "62" [label="37.0"];
#   "20" -- "51" [label="1.0"];
#   "20" -- "27" [label="39.0"];
#   "20" -- "12" [label="30.0"];
#   "20" -- "24" [label="38.0"];
#   "20" -- "63" [label="31.0"];
#   "20" -- "42" [label="39.0"];
#   "20" -- "15" [label="29.0"];
#   "10" -- "16" [label="52.0"];
#   "10" -- "47" [label="40.0"];
#   "10" -- "50" [label="63.0"];
#   "10" -- "21" [label="18.0"];
#   "10" -- "36" [label="16.0"];
#   "10" -- "33" [label="41.0"];
#   "10" -- "63" [label="10.0"];
#   "10" -- "57" [label="17.0"];
#   "10" -- "3" [label="33.0"];
#   "16" -- "10" [label="52.0"];
#   "16" -- "65" [label="62.0"];
#   "16" -- "57" [label="28.0"];
#   "16" -- "30" [label="16.0"];
#   "16" -- "21" [label="27.0"];
#   "16" -- "54" [label="46.0"];
#   "11" -- "27" [label="63.0"];
#   "11" -- "54" [label="22.0"];
#   "11" -- "1" [label="24.0"];
#   "11" -- "15" [label="38.0"];
#   "11" -- "60" [label="9.0"];
#   "11" -- "30" [label="22.0"];
#   "11" -- "12" [label="42.0"];
#   "11" -- "66" [label="42.0"];
#   "11" -- "57" [label="14.0"];
#   "27" -- "11" [label="63.0"];
#   "27" -- "67" [label="4.0"];
#   "27" -- "29" [label="3.0"];
#   "27" -- "20" [label="39.0"];
#   "27" -- "51" [label="22.0"];
#   "27" -- "24" [label="41.0"];
#   "27" -- "58" [label="15.0"];
#   "27" -- "55" [label="2.0"];
#   "27" -- "3" [label="2.0"];
#   "27" -- "36" [label="32.0"];
#   "27" -- "1" [label="36.0"];
#   "27" -- "18" [label="4.0"];
#   "27" -- "49" [label="26.0"];
#   "27" -- "17" [label="30.0"];
#   "27" -- "47" [label="2.0"];
#   "27" -- "6" [label="17.0"];
#   "27" -- "9" [label="23.0"];
#   "27" -- "63" [label="5.0"];
#   "27" -- "39" [label="24.0"];
#   "27" -- "38" [label="36.0"];
#   "27" -- "65" [label="46.0"];
#   "12" -- "2" [label="11.0"];
#   "12" -- "54" [label="16.0"];
#   "12" -- "13" [label="40.0"];
#   "12" -- "45" [label="26.0"];
#   "12" -- "19" [label="25.0"];
#   "12" -- "20" [label="30.0"];
#   "12" -- "59" [label="12.0"];
#   "12" -- "64" [label="23.0"];
#   "12" -- "17" [label="32.0"];
#   "12" -- "48" [label="27.0"];
#   "12" -- "6" [label="23.0"];
#   "12" -- "18" [label="10.0"];
#   "12" -- "38" [label="29.0"];
#   "12" -- "4" [label="25.0"];
#   "12" -- "24" [label="37.0"];
#   "12" -- "63" [label="9.0"];
#   "12" -- "5" [label="23.0"];
#   "12" -- "11" [label="42.0"];
#   "12" -- "1" [label="44.0"];
#   "12" -- "32" [label="16.0"];
#   "13" -- "26" [label="34.0"];
#   "13" -- "24" [label="64.0"];
#   "13" -- "12" [label="40.0"];
#   "13" -- "57" [label="9.0"];
#   "13" -- "60" [label="34.0"];
#   "13" -- "66" [label="37.0"];
#   "13" -- "18" [label="41.0"];
#   "13" -- "42" [label="10.0"];
#   "13" -- "15" [label="37.0"];
#   "13" -- "54" [label="18.0"];
#   "13" -- "30" [label="40.0"];
#   "26" -- "13" [label="34.0"];
#   "26" -- "40" [label="62.0"];
#   "26" -- "18" [label="29.0"];
#   "26" -- "48" [label="12.0"];
#   "26" -- "1" [label="2.0"];
#   "26" -- "21" [label="43.0"];
#   "26" -- "33" [label="28.0"];
#   "26" -- "45" [label="39.0"];
#   "26" -- "36" [label="29.0"];
#   "14" -- "64" [label="30.0"];
#   "14" -- "48" [label="20.0"];
#   "14" -- "3" [label="38.0"];
#   "14" -- "51" [label="16.0"];
#   "14" -- "39" [label="23.0"];
#   "14" -- "18" [label="18.0"];
#   "64" -- "14" [label="30.0"];
#   "64" -- "58" [label="28.0"];
#   "64" -- "12" [label="23.0"];
#   "64" -- "30" [label="38.0"];
#   "64" -- "15" [label="18.0"];
#   "64" -- "24" [label="35.0"];
#   "64" -- "1" [label="43.0"];
#   "15" -- "49" [label="32.0"];
#   "15" -- "6" [label="33.0"];
#   "15" -- "54" [label="38.0"];
#   "15" -- "28" [label="18.0"];
#   "15" -- "32" [label="25.0"];
#   "15" -- "67" [label="17.0"];
#   "15" -- "33" [label="32.0"];
#   "15" -- "48" [label="39.0"];
#   "15" -- "57" [label="38.0"];
#   "15" -- "47" [label="38.0"];
#   "15" -- "34" [label="17.0"];
#   "15" -- "24" [label="9.0"];
#   "15" -- "22" [label="40.0"];
#   "15" -- "35" [label="29.0"];
#   "15" -- "4" [label="13.0"];
#   "15" -- "11" [label="38.0"];
#   "15" -- "64" [label="18.0"];
#   "15" -- "41" [label="7.0"];
#   "15" -- "8" [label="23.0"];
#   "15" -- "3" [label="43.0"];
#   "15" -- "56" [label="10.0"];
#   "15" -- "66" [label="14.0"];
#   "15" -- "20" [label="29.0"];
#   "15" -- "18" [label="16.0"];
#   "15" -- "13" [label="37.0"];
#   "49" -- "15" [label="32.0"];
#   "49" -- "9" [label="32.0"];
#   "49" -- "61" [label="47.0"];
#   "49" -- "3" [label="23.0"];
#   "49" -- "57" [label="43.0"];
#   "49" -- "6" [label="9.0"];
#   "49" -- "27" [label="26.0"];
#   "49" -- "48" [label="44.0"];
#   "49" -- "60" [label="21.0"];
#   "65" -- "16" [label="62.0"];
#   "65" -- "25" [label="42.0"];
#   "65" -- "60" [label="2.0"];
#   "65" -- "3" [label="20.0"];
#   "65" -- "6" [label="1.0"];
#   "65" -- "45" [label="1.0"];
#   "65" -- "27" [label="46.0"];
#   "17" -- "4" [label="18.0"];
#   "17" -- "51" [label="9.0"];
#   "17" -- "12" [label="32.0"];
#   "17" -- "27" [label="30.0"];
#   "17" -- "30" [label="11.0"];
#   "17" -- "18" [label="32.0"];
#   "17" -- "6" [label="6.0"];
#   "17" -- "21" [label="42.0"];
#   "17" -- "9" [label="31.0"];
#   "17" -- "36" [label="35.0"];
#   "17" -- "24" [label="9.0"];
#   "17" -- "45" [label="9.0"];
#   "18" -- "29" [label="18.0"];
#   "18" -- "26" [label="29.0"];
#   "18" -- "68" [label="28.0"];
#   "18" -- "1" [label="3.0"];
#   "18" -- "40" [label="30.0"];
#   "18" -- "45" [label="33.0"];
#   "18" -- "35" [label="29.0"];
#   "18" -- "3" [label="18.0"];
#   "18" -- "47" [label="20.0"];
#   "18" -- "13" [label="41.0"];
#   "18" -- "12" [label="10.0"];
#   "18" -- "27" [label="4.0"];
#   "18" -- "2" [label="38.0"];
#   "18" -- "63" [label="32.0"];
#   "18" -- "24" [label="38.0"];
#   "18" -- "17" [label="32.0"];
#   "18" -- "15" [label="16.0"];
#   "18" -- "60" [label="42.0"];
#   "18" -- "21" [label="38.0"];
#   "18" -- "14" [label="18.0"];
#   "18" -- "53" [label="43.0"];
#   "29" -- "18" [label="18.0"];
#   "29" -- "27" [label="3.0"];
#   "29" -- "32" [label="34.0"];
#   "29" -- "33" [label="12.0"];
#   "29" -- "48" [label="22.0"];
#   "29" -- "1" [label="28.0"];
#   "29" -- "39" [label="35.0"];
#   "29" -- "9" [label="8.0"];
#   "29" -- "60" [label="27.0"];
#   "29" -- "54" [label="26.0"];
#   "29" -- "63" [label="16.0"];
#   "29" -- "45" [label="17.0"];
#   "29" -- "36" [label="42.0"];
#   "52" -- "19" [label="32.0"];
#   "52" -- "42" [label="48.0"];
#   "52" -- "34" [label="15.0"];
#   "52" -- "53" [label="48.0"];
#   "52" -- "63" [label="45.0"];
#   "52" -- "45" [label="39.0"];
#   "52" -- "60" [label="7.0"];
#   "52" -- "33" [label="10.0"];
#   "52" -- "66" [label="27.0"];
#   "21" -- "58" [label="4.0"];
#   "21" -- "59" [label="43.0"];
#   "21" -- "32" [label="2.0"];
#   "21" -- "10" [label="18.0"];
#   "21" -- "33" [label="23.0"];
#   "21" -- "44" [label="46.0"];
#   "21" -- "50" [label="11.0"];
#   "21" -- "23" [label="19.0"];
#   "21" -- "6" [label="16.0"];
#   "21" -- "68" [label="4.0"];
#   "21" -- "51" [label="17.0"];
#   "21" -- "67" [label="10.0"];
#   "21" -- "26" [label="43.0"];
#   "21" -- "53" [label="9.0"];
#   "21" -- "16" [label="27.0"];
#   "21" -- "43" [label="30.0"];
#   "21" -- "3" [label="28.0"];
#   "21" -- "39" [label="2.0"];
#   "21" -- "8" [label="41.0"];
#   "21" -- "63" [label="17.0"];
#   "21" -- "18" [label="38.0"];
#   "21" -- "17" [label="42.0"];
#   "21" -- "1" [label="9.0"];
#   "21" -- "48" [label="6.0"];
#   "21" -- "28" [label="42.0"];
#   "58" -- "21" [label="4.0"];
#   "58" -- "33" [label="23.0"];
#   "58" -- "64" [label="28.0"];
#   "58" -- "51" [label="35.0"];
#   "58" -- "27" [label="15.0"];
#   "58" -- "45" [label="3.0"];
#   "58" -- "57" [label="19.0"];
#   "58" -- "9" [label="28.0"];
#   "22" -- "23" [label="10.0"];
#   "22" -- "46" [label="19.0"];
#   "22" -- "51" [label="51.0"];
#   "22" -- "33" [label="27.0"];
#   "22" -- "15" [label="40.0"];
#   "22" -- "57" [label="9.0"];
#   "22" -- "45" [label="10.0"];
#   "24" -- "13" [label="64.0"];
#   "24" -- "63" [label="36.0"];
#   "24" -- "8" [label="23.0"];
#   "24" -- "60" [label="41.0"];
#   "24" -- "36" [label="10.0"];
#   "24" -- "27" [label="41.0"];
#   "24" -- "35" [label="46.0"];
#   "24" -- "34" [label="14.0"];
#   "24" -- "39" [label="3.0"];
#   "24" -- "55" [label="40.0"];
#   "24" -- "20" [label="38.0"];
#   "24" -- "15" [label="9.0"];
#   "24" -- "42" [label="27.0"];
#   "24" -- "68" [label="27.0"];
#   "24" -- "57" [label="20.0"];
#   "24" -- "54" [label="46.0"];
#   "24" -- "18" [label="38.0"];
#   "24" -- "64" [label="35.0"];
#   "24" -- "44" [label="13.0"];
#   "24" -- "12" [label="37.0"];
#   "24" -- "40" [label="42.0"];
#   "24" -- "43" [label="37.0"];
#   "24" -- "3" [label="10.0"];
#   "24" -- "38" [label="14.0"];
#   "24" -- "17" [label="9.0"];
#   "24" -- "46" [label="19.0"];
#   "25" -- "65" [label="42.0"];
#   "25" -- "54" [label="26.0"];
#   "25" -- "42" [label="14.0"];
#   "40" -- "26" [label="62.0"];
#   "40" -- "45" [label="12.0"];
#   "40" -- "36" [label="9.0"];
#   "40" -- "18" [label="30.0"];
#   "40" -- "1" [label="8.0"];
#   "40" -- "24" [label="42.0"];
#   "67" -- "27" [label="4.0"];
#   "67" -- "41" [label="26.0"];
#   "67" -- "63" [label="65.0"];
#   "67" -- "44" [label="49.0"];
#   "67" -- "15" [label="17.0"];
#   "67" -- "21" [label="10.0"];
#   "67" -- "48" [label="34.0"];
#   "67" -- "60" [label="7.0"];
#   "67" -- "45" [label="26.0"];
#   "67" -- "42" [label="21.0"];
#   "28" -- "30" [label="28.0"];
#   "28" -- "39" [label="46.0"];
#   "28" -- "15" [label="18.0"];
#   "28" -- "21" [label="42.0"];
#   "30" -- "28" [label="28.0"];
#   "30" -- "8" [label="21.0"];
#   "30" -- "4" [label="39.0"];
#   "30" -- "39" [label="12.0"];
#   "30" -- "50" [label="16.0"];
#   "30" -- "63" [label="25.0"];
#   "30" -- "16" [label="16.0"];
#   "30" -- "64" [label="38.0"];
#   "30" -- "17" [label="11.0"];
#   "30" -- "57" [label="37.0"];
#   "30" -- "59" [label="43.0"];
#   "30" -- "11" [label="22.0"];
#   "30" -- "37" [label="10.0"];
#   "30" -- "1" [label="26.0"];
#   "30" -- "56" [label="20.0"];
#   "30" -- "13" [label="40.0"];
#   "50" -- "31" [label="14.0"];
#   "50" -- "10" [label="63.0"];
#   "50" -- "48" [label="18.0"];
#   "50" -- "21" [label="11.0"];
#   "50" -- "30" [label="16.0"];
#   "50" -- "66" [label="18.0"];
#   "50" -- "1" [label="36.0"];
#   "50" -- "45" [label="16.0"];
#   "32" -- "29" [label="34.0"];
#   "32" -- "21" [label="2.0"];
#   "32" -- "60" [label="42.0"];
#   "32" -- "15" [label="25.0"];
#   "32" -- "3" [label="32.0"];
#   "32" -- "12" [label="16.0"];
#   "33" -- "46" [label="7.0"];
#   "33" -- "58" [label="23.0"];
#   "33" -- "29" [label="12.0"];
#   "33" -- "31" [label="1.0"];
#   "33" -- "22" [label="27.0"];
#   "33" -- "9" [label="8.0"];
#   "33" -- "21" [label="23.0"];
#   "33" -- "15" [label="32.0"];
#   "33" -- "48" [label="29.0"];
#   "33" -- "10" [label="41.0"];
#   "33" -- "23" [label="5.0"];
#   "33" -- "26" [label="28.0"];
#   "33" -- "63" [label="29.0"];
#   "33" -- "52" [label="10.0"];
#   "33" -- "45" [label="33.0"];
#   "33" -- "35" [label="22.0"];
#   "33" -- "39" [label="14.0"];
#   "33" -- "62" [label="33.0"];
#   "46" -- "33" [label="7.0"];
#   "46" -- "22" [label="19.0"];
#   "46" -- "6" [label="18.0"];
#   "46" -- "24" [label="19.0"];
#   "34" -- "68" [label="6.0"];
#   "34" -- "52" [label="15.0"];
#   "34" -- "24" [label="14.0"];
#   "34" -- "15" [label="17.0"];
#   "34" -- "36" [label="39.0"];
#   "34" -- "3" [label="44.0"];
#   "68" -- "34" [label="6.0"];
#   "68" -- "48" [label="21.0"];
#   "68" -- "39" [label="16.0"];
#   "68" -- "18" [label="28.0"];
#   "68" -- "51" [label="4.0"];
#   "68" -- "21" [label="4.0"];
#   "68" -- "60" [label="25.0"];
#   "68" -- "24" [label="27.0"];
#   "35" -- "7" [label="42.0"];
#   "35" -- "9" [label="13.0"];
#   "35" -- "57" [label="22.0"];
#   "35" -- "24" [label="46.0"];
#   "35" -- "18" [label="29.0"];
#   "35" -- "15" [label="29.0"];
#   "35" -- "33" [label="22.0"];
#   "53" -- "36" [label="54.0"];
#   "53" -- "52" [label="48.0"];
#   "53" -- "6" [label="9.0"];
#   "53" -- "48" [label="45.0"];
#   "53" -- "21" [label="9.0"];
#   "53" -- "39" [label="37.0"];
#   "53" -- "18" [label="43.0"];
#   "53" -- "51" [label="41.0"];
#   "37" -- "23" [label="26.0"];
#   "37" -- "51" [label="19.0"];
#   "37" -- "1" [label="9.0"];
#   "37" -- "54" [label="46.0"];
#   "37" -- "6" [label="36.0"];
#   "37" -- "30" [label="10.0"];
#   "38" -- "45" [label="57.0"];
#   "38" -- "36" [label="5.0"];
#   "38" -- "9" [label="39.0"];
#   "38" -- "1" [label="32.0"];
#   "38" -- "57" [label="17.0"];
#   "38" -- "12" [label="29.0"];
#   "38" -- "51" [label="22.0"];
#   "38" -- "42" [label="32.0"];
#   "38" -- "24" [label="14.0"];
#   "38" -- "27" [label="36.0"];
#   "45" -- "38" [label="57.0"];
#   "45" -- "40" [label="12.0"];
#   "45" -- "61" [label="16.0"];
#   "45" -- "51" [label="17.0"];
#   "45" -- "12" [label="26.0"];
#   "45" -- "39" [label="30.0"];
#   "45" -- "18" [label="33.0"];
#   "45" -- "58" [label="3.0"];
#   "45" -- "9" [label="21.0"];
#   "45" -- "52" [label="39.0"];
#   "45" -- "44" [label="16.0"];
#   "45" -- "50" [label="16.0"];
#   "45" -- "65" [label="1.0"];
#   "45" -- "1" [label="34.0"];
#   "45" -- "67" [label="26.0"];
#   "45" -- "8" [label="45.0"];
#   "45" -- "19" [label="8.0"];
#   "45" -- "29" [label="17.0"];
#   "45" -- "33" [label="33.0"];
#   "45" -- "26" [label="39.0"];
#   "45" -- "22" [label="10.0"];
#   "45" -- "6" [label="7.0"];
#   "45" -- "17" [label="9.0"];
#   "39" -- "51" [label="25.0"];
#   "39" -- "68" [label="16.0"];
#   "39" -- "1" [label="5.0"];
#   "39" -- "60" [label="15.0"];
#   "39" -- "56" [label="34.0"];
#   "39" -- "28" [label="46.0"];
#   "39" -- "62" [label="3.0"];
#   "39" -- "30" [label="12.0"];
#   "39" -- "45" [label="30.0"];
#   "39" -- "24" [label="3.0"];
#   "39" -- "29" [label="35.0"];
#   "39" -- "2" [label="17.0"];
#   "39" -- "63" [label="38.0"];
#   "39" -- "14" [label="23.0"];
#   "39" -- "9" [label="21.0"];
#   "39" -- "66" [label="11.0"];
#   "39" -- "53" [label="37.0"];
#   "39" -- "21" [label="2.0"];
#   "39" -- "3" [label="25.0"];
#   "39" -- "33" [label="14.0"];
#   "39" -- "27" [label="24.0"];
#   "39" -- "43" [label="25.0"];
#   "51" -- "39" [label="25.0"];
#   "51" -- "22" [label="51.0"];
#   "51" -- "45" [label="17.0"];
#   "51" -- "20" [label="1.0"];
#   "51" -- "58" [label="35.0"];
#   "51" -- "57" [label="24.0"];
#   "51" -- "61" [label="27.0"];
#   "51" -- "27" [label="22.0"];
#   "51" -- "68" [label="4.0"];
#   "51" -- "17" [label="9.0"];
#   "51" -- "3" [label="46.0"];
#   "51" -- "14" [label="16.0"];
#   "51" -- "19" [label="19.0"];
#   "51" -- "21" [label="17.0"];
#   "51" -- "37" [label="19.0"];
#   "51" -- "38" [label="22.0"];
#   "51" -- "1" [label="9.0"];
#   "51" -- "54" [label="30.0"];
#   "51" -- "53" [label="41.0"];
#   "51" -- "55" [label="45.0"];
#   "42" -- "52" [label="48.0"];
#   "42" -- "43" [label="24.0"];
#   "42" -- "36" [label="2.0"];
#   "42" -- "56" [label="3.0"];
#   "42" -- "47" [label="41.0"];
#   "42" -- "54" [label="9.0"];
#   "42" -- "13" [label="10.0"];
#   "42" -- "24" [label="27.0"];
#   "42" -- "20" [label="39.0"];
#   "42" -- "3" [label="45.0"];
#   "42" -- "9" [label="9.0"];
#   "42" -- "1" [label="1.0"];
#   "42" -- "38" [label="32.0"];
#   "42" -- "25" [label="14.0"];
#   "42" -- "67" [label="21.0"];
#   "43" -- "42" [label="24.0"];
#   "43" -- "44" [label="22.0"];
#   "43" -- "60" [label="14.0"];
#   "43" -- "48" [label="46.0"];
#   "43" -- "9" [label="44.0"];
#   "43" -- "21" [label="30.0"];
#   "43" -- "57" [label="42.0"];
#   "43" -- "24" [label="37.0"];
#   "43" -- "39" [label="25.0"];
#   "44" -- "43" [label="22.0"];
#   "44" -- "67" [label="49.0"];
#   "44" -- "36" [label="24.0"];
#   "44" -- "21" [label="46.0"];
#   "44" -- "45" [label="16.0"];
#   "44" -- "24" [label="13.0"];
#   "44" -- "3" [label="39.0"];
#   "61" -- "45" [label="16.0"];
#   "61" -- "49" [label="47.0"];
#   "61" -- "51" [label="27.0"];
#   "61" -- "3" [label="45.0"];
#   "47" -- "10" [label="40.0"];
#   "47" -- "42" [label="41.0"];
#   "47" -- "18" [label="20.0"];
#   "47" -- "15" [label="38.0"];
#   "47" -- "3" [label="5.0"];
#   "47" -- "27" [label="2.0"];
#   "47" -- "57" [label="28.0"];
#   "48" -- "14" [label="20.0"];
#   "48" -- "56" [label="26.0"];
#   "48" -- "68" [label="21.0"];
#   "48" -- "29" [label="22.0"];
#   "48" -- "50" [label="18.0"];
#   "48" -- "53" [label="45.0"];
#   "48" -- "43" [label="46.0"];
#   "48" -- "26" [label="12.0"];
#   "48" -- "15" [label="39.0"];
#   "48" -- "67" [label="34.0"];
#   "48" -- "33" [label="29.0"];
#   "48" -- "12" [label="27.0"];
#   "48" -- "9" [label="32.0"];
#   "48" -- "49" [label="44.0"];
#   "48" -- "36" [label="44.0"];
#   "48" -- "21" [label="6.0"];
#   "55" -- "59" [label="45.0"];
#   "55" -- "6" [label="27.0"];
#   "55" -- "36" [label="2.0"];
#   "55" -- "27" [label="2.0"];
#   "55" -- "54" [label="27.0"];
#   "55" -- "24" [label="40.0"];
#   "55" -- "57" [label="43.0"];
#   "55" -- "3" [label="46.0"];
#   "55" -- "51" [label="45.0"];
#   "56" -- "48" [label="26.0"];
#   "56" -- "39" [label="34.0"];
#   "56" -- "9" [label="24.0"];
#   "56" -- "42" [label="3.0"];
#   "56" -- "36" [label="4.0"];
#   "56" -- "15" [label="10.0"];
#   "56" -- "30" [label="20.0"];
#   "57" -- "31" [label="25.0"];
#   "57" -- "13" [label="9.0"];
#   "57" -- "51" [label="24.0"];
#   "57" -- "16" [label="28.0"];
#   "57" -- "35" [label="22.0"];
#   "57" -- "49" [label="43.0"];
#   "57" -- "15" [label="38.0"];
#   "57" -- "38" [label="17.0"];
#   "57" -- "36" [label="17.0"];
#   "57" -- "22" [label="9.0"];
#   "57" -- "24" [label="20.0"];
#   "57" -- "43" [label="42.0"];
#   "57" -- "55" [label="43.0"];
#   "57" -- "3" [label="5.0"];
#   "57" -- "30" [label="37.0"];
#   "57" -- "1" [label="39.0"];
#   "57" -- "58" [label="19.0"];
#   "57" -- "47" [label="28.0"];
#   "57" -- "10" [label="17.0"];
#   "57" -- "11" [label="14.0"];
#   "60" -- "43" [label="14.0"];
#   "60" -- "65" [label="2.0"];
#   "60" -- "39" [label="15.0"];
#   "60" -- "32" [label="42.0"];
#   "60" -- "13" [label="34.0"];
#   "60" -- "24" [label="41.0"];
#   "60" -- "54" [label="9.0"];
#   "60" -- "68" [label="25.0"];
#   "60" -- "4" [label="26.0"];
#   "60" -- "3" [label="6.0"];
#   "60" -- "67" [label="7.0"];
#   "60" -- "29" [label="27.0"];
#   "60" -- "11" [label="9.0"];
#   "60" -- "52" [label="7.0"];
#   "60" -- "41" [label="22.0"];
#   "60" -- "18" [label="42.0"];
#   "60" -- "49" [label="21.0"];
#   "62" -- "20" [label="37.0"];
#   "62" -- "39" [label="3.0"];
#   "62" -- "54" [label="46.0"];
#   "62" -- "33" [label="33.0"];
#   "62" -- "36" [label="36.0"];
#   "63" -- "67" [label="65.0"];
#   "63" -- "24" [label="36.0"];
#   "63" -- "52" [label="45.0"];
#   "63" -- "66" [label="30.0"];
#   "63" -- "54" [label="27.0"];
#   "63" -- "30" [label="25.0"];
#   "63" -- "39" [label="38.0"];
#   "63" -- "20" [label="31.0"];
#   "63" -- "10" [label="10.0"];
#   "63" -- "18" [label="32.0"];
#   "63" -- "33" [label="29.0"];
#   "63" -- "27" [label="5.0"];
#   "63" -- "29" [label="16.0"];
#   "63" -- "6" [label="1.0"];
#   "63" -- "12" [label="9.0"];
#   "63" -- "21" [label="17.0"];
#   "63" -- "3" [label="43.0"];
#   "66" -- "23" [label="45.0"];
#   "66" -- "41" [label="19.0"];
#   "66" -- "63" [label="30.0"];
#   "66" -- "13" [label="37.0"];
#   "66" -- "54" [label="4.0"];
#   "66" -- "50" [label="18.0"];
#   "66" -- "39" [label="11.0"];
#   "66" -- "1" [label="23.0"];
#   "66" -- "15" [label="14.0"];
#   "66" -- "36" [label="19.0"];
#   "66" -- "52" [label="27.0"];
#   "66" -- "11" [label="42.0"];
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 Source(read_dot_file("hd4dijkstra"))
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:152, in DisplayFormatter.format(self, obj, include, exclude)
#     148 if self.ipython_display_formatter(obj):
#     149     # object handled itself, don't proceed
#     150     return {}, {}
# --> 152 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#     154 if format_dict or md_dict:
#     155     if include:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/jupyter_integration.py:98, in JupyterIntegration._repr_mimebundle_(self, include, exclude, **_)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/jupyter_integration.py:112, in JupyterIntegration._repr_image_svg_xml(self)
#     110 def _repr_image_svg_xml(self) -> str:
#     111     """Return the rendered graph as SVG string."""
# --> 112     return self.pipe(format='svg', encoding=SVG_ENCODING)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:149, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     146 if encoding is not None:
#     147     if codecs.lookup(encoding) is codecs.lookup(self.encoding):
#     148         # common case: both stdin and stdout need the same encoding
# --> 149         return self._pipe_lines_string(*args, encoding=encoding, **kwargs)
#     150     try:
#     151         raw = self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/piping.py:212, in pipe_lines_string(engine, format, input_lines, encoding, renderer, formatter, neato_no_op, quiet)
#     206 cmd = dot_command.command(engine, format,
#     207                           renderer=renderer,
#     208                           formatter=formatter,
#     209                           neato_no_op=neato_no_op)
#     210 kwargs = {'input_lines': input_lines, 'encoding': encoding}
# --> 212 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     213 return proc.stdout
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/execute.py:76, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      74     if kwargs.pop('capture_output'):
#      75         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 76     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77 else:
#      78     proc = subprocess.run(cmd, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/execute.py:102, in _run_input_lines(cmd, input_lines, kwargs)
#      99 for line in input_lines:
#     100     stdin_write(line)
# --> 102 stdout, stderr = popen.communicate()
#     103 return subprocess.CompletedProcess(popen.args, popen.returncode,
#     104                                    stdout=stdout, stderr=stderr)
#
# File /opt/homebrew/anaconda3/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/homebrew/anaconda3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
Source(read_dot_file("hd5dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/hd5dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "1" [label="1 (0.0)"];
#   "24" [label="24 (8.0)"];
#   "2" [label="2 (3.0)"];
#   "5" [label="5 (11.0)"];
#   "3" [label="3 (6.0)"];
#   "4" [label="4 (8.0)"];
#   "6" [label="6 (7.0)"];
#   "13" [label="13 (6.0)"];
#   "7" [label="7 (12.0)"];
#   "14" [label="14 (12.0)"];
#   "8" [label="8 (10.0)"];
#   "22" [label="22 (9.0)"];
#   "9" [label="9 (18.0)"];
#   "27" [label="27 (12.0)"];
#   "10" [label="10 (4.0)"];
#   "11" [label="11 (8.0)"];
#   "18" [label="18 (1.0)"];
#   "12" [label="12 (3.0)"];
#   "15" [label="15 (1.0)"];
#   "16" [label="16 (2.0)"];
#   "17" [label="17 (10.0)"];
#   "19" [label="19 (8.0)"];
#   "20" [label="20 (5.0)"];
#   "21" [label="21 (6.0)"];
#   "23" [label="23 (9.0)"];
#   "25" [label="25 (17.0)"];
#   "26" [label="26 (11.0)"];
#   "28" [label="28 (8.0)"];
#   "1" -- "24" [label="11.0"];
#   "1" -- "22" [label="15.0"];
#   "1" -- "20" [label="37.0"];
#   "1" -- "8" [label="28.0"];
#   "1" -- "12" [label="42.0"];
#   "1" -- "15" [label="1.0"];
#   "1" -- "6" [label="20.0"];
#   "1" -- "18" [label="1.0"];
#   "1" -- "27" [label="44.0"];
#   "1" -- "2" [label="3.0"];
#   "1" -- "21" [label="21.0"];
#   "1" -- "14" [label="12.0"];
#   "1" -- "10" [label="35.0"];
#   "1" -- "16" [label="17.0"];
#   "1" -- "25" [label="42.0"];
#   "1" -- "23" [label="9.0"];
#   "1" -- "11" [label="14.0"];
#   "1" -- "17" [label="40.0"];
#   "24" -- "1" [label="11.0"];
#   "24" -- "3" [label="23.0"];
#   "24" -- "5" [label="19.0"];
#   "24" -- "13" [label="9.0"];
#   "24" -- "12" [label="5.0"];
#   "24" -- "21" [label="21.0"];
#   "24" -- "14" [label="18.0"];
#   "24" -- "27" [label="7.0"];
#   "24" -- "16" [label="9.0"];
#   "24" -- "26" [label="15.0"];
#   "24" -- "28" [label="1.0"];
#   "24" -- "11" [label="44.0"];
#   "2" -- "5" [label="42.0"];
#   "2" -- "23" [label="16.0"];
#   "2" -- "3" [label="3.0"];
#   "2" -- "6" [label="27.0"];
#   "2" -- "11" [label="37.0"];
#   "2" -- "8" [label="13.0"];
#   "2" -- "14" [label="11.0"];
#   "2" -- "1" [label="3.0"];
#   "2" -- "21" [label="21.0"];
#   "5" -- "2" [label="42.0"];
#   "5" -- "4" [label="45.0"];
#   "5" -- "24" [label="19.0"];
#   "5" -- "8" [label="27.0"];
#   "5" -- "18" [label="36.0"];
#   "5" -- "21" [label="10.0"];
#   "5" -- "10" [label="40.0"];
#   "5" -- "19" [label="27.0"];
#   "5" -- "3" [label="5.0"];
#   "5" -- "12" [label="27.0"];
#   "3" -- "24" [label="23.0"];
#   "3" -- "19" [label="29.0"];
#   "3" -- "12" [label="20.0"];
#   "3" -- "20" [label="7.0"];
#   "3" -- "2" [label="3.0"];
#   "3" -- "26" [label="7.0"];
#   "3" -- "7" [label="40.0"];
#   "3" -- "16" [label="7.0"];
#   "3" -- "4" [label="11.0"];
#   "3" -- "28" [label="44.0"];
#   "3" -- "5" [label="5.0"];
#   "3" -- "18" [label="19.0"];
#   "3" -- "13" [label="34.0"];
#   "4" -- "5" [label="45.0"];
#   "4" -- "22" [label="32.0"];
#   "4" -- "27" [label="12.0"];
#   "4" -- "15" [label="7.0"];
#   "4" -- "3" [label="11.0"];
#   "4" -- "11" [label="13.0"];
#   "4" -- "14" [label="9.0"];
#   "4" -- "12" [label="43.0"];
#   "4" -- "16" [label="34.0"];
#   "4" -- "23" [label="21.0"];
#   "4" -- "28" [label="45.0"];
#   "6" -- "13" [label="38.0"];
#   "6" -- "25" [label="47.0"];
#   "6" -- "17" [label="3.0"];
#   "6" -- "2" [label="27.0"];
#   "6" -- "1" [label="20.0"];
#   "6" -- "16" [label="5.0"];
#   "6" -- "11" [label="9.0"];
#   "6" -- "10" [label="40.0"];
#   "6" -- "28" [label="9.0"];
#   "6" -- "21" [label="35.0"];
#   "6" -- "23" [label="27.0"];
#   "13" -- "6" [label="38.0"];
#   "13" -- "24" [label="9.0"];
#   "13" -- "18" [label="10.0"];
#   "13" -- "16" [label="4.0"];
#   "13" -- "27" [label="6.0"];
#   "13" -- "26" [label="42.0"];
#   "13" -- "21" [label="9.0"];
#   "13" -- "12" [label="22.0"];
#   "13" -- "14" [label="37.0"];
#   "13" -- "9" [label="12.0"];
#   "13" -- "28" [label="23.0"];
#   "13" -- "25" [label="31.0"];
#   "13" -- "15" [label="43.0"];
#   "13" -- "3" [label="34.0"];
#   "7" -- "14" [label="44.0"];
#   "7" -- "10" [label="24.0"];
#   "7" -- "21" [label="21.0"];
#   "7" -- "26" [label="18.0"];
#   "7" -- "25" [label="39.0"];
#   "7" -- "23" [label="14.0"];
#   "7" -- "3" [label="40.0"];
#   "7" -- "17" [label="2.0"];
#   "7" -- "15" [label="41.0"];
#   "7" -- "9" [label="28.0"];
#   "7" -- "27" [label="1.0"];
#   "7" -- "19" [label="22.0"];
#   "14" -- "7" [label="44.0"];
#   "14" -- "8" [label="18.0"];
#   "14" -- "16" [label="51.0"];
#   "14" -- "20" [label="45.0"];
#   "14" -- "26" [label="21.0"];
#   "14" -- "9" [label="26.0"];
#   "14" -- "24" [label="18.0"];
#   "14" -- "15" [label="15.0"];
#   "14" -- "25" [label="5.0"];
#   "14" -- "2" [label="11.0"];
#   "14" -- "13" [label="37.0"];
#   "14" -- "22" [label="17.0"];
#   "14" -- "19" [label="19.0"];
#   "14" -- "1" [label="12.0"];
#   "14" -- "4" [label="9.0"];
#   "14" -- "10" [label="8.0"];
#   "14" -- "12" [label="40.0"];
#   "8" -- "22" [label="2.0"];
#   "8" -- "14" [label="18.0"];
#   "8" -- "16" [label="17.0"];
#   "8" -- "1" [label="28.0"];
#   "8" -- "5" [label="27.0"];
#   "8" -- "2" [label="13.0"];
#   "8" -- "15" [label="9.0"];
#   "8" -- "26" [label="28.0"];
#   "8" -- "12" [label="44.0"];
#   "8" -- "18" [label="12.0"];
#   "8" -- "23" [label="8.0"];
#   "8" -- "9" [label="23.0"];
#   "22" -- "8" [label="2.0"];
#   "22" -- "21" [label="4.0"];
#   "22" -- "4" [label="32.0"];
#   "22" -- "1" [label="15.0"];
#   "22" -- "18" [label="8.0"];
#   "22" -- "17" [label="12.0"];
#   "22" -- "14" [label="17.0"];
#   "22" -- "12" [label="13.0"];
#   "22" -- "16" [label="18.0"];
#   "9" -- "27" [label="47.0"];
#   "9" -- "14" [label="26.0"];
#   "9" -- "12" [label="26.0"];
#   "9" -- "21" [label="16.0"];
#   "9" -- "20" [label="43.0"];
#   "9" -- "13" [label="12.0"];
#   "9" -- "7" [label="28.0"];
#   "9" -- "8" [label="23.0"];
#   "27" -- "9" [label="47.0"];
#   "27" -- "15" [label="24.0"];
#   "27" -- "12" [label="38.0"];
#   "27" -- "13" [label="6.0"];
#   "27" -- "24" [label="7.0"];
#   "27" -- "4" [label="12.0"];
#   "27" -- "28" [label="5.0"];
#   "27" -- "1" [label="44.0"];
#   "27" -- "26" [label="21.0"];
#   "27" -- "23" [label="27.0"];
#   "27" -- "20" [label="33.0"];
#   "27" -- "7" [label="1.0"];
#   "10" -- "7" [label="24.0"];
#   "10" -- "12" [label="5.0"];
#   "10" -- "28" [label="32.0"];
#   "10" -- "21" [label="16.0"];
#   "10" -- "17" [label="32.0"];
#   "10" -- "20" [label="9.0"];
#   "10" -- "6" [label="40.0"];
#   "10" -- "1" [label="35.0"];
#   "10" -- "5" [label="40.0"];
#   "10" -- "14" [label="8.0"];
#   "10" -- "18" [label="3.0"];
#   "10" -- "23" [label="35.0"];
#   "11" -- "18" [label="7.0"];
#   "11" -- "28" [label="37.0"];
#   "11" -- "2" [label="37.0"];
#   "11" -- "6" [label="9.0"];
#   "11" -- "24" [label="44.0"];
#   "11" -- "4" [label="13.0"];
#   "11" -- "16" [label="36.0"];
#   "11" -- "17" [label="34.0"];
#   "11" -- "1" [label="14.0"];
#   "11" -- "15" [label="9.0"];
#   "18" -- "11" [label="7.0"];
#   "18" -- "13" [label="10.0"];
#   "18" -- "21" [label="9.0"];
#   "18" -- "15" [label="19.0"];
#   "18" -- "22" [label="8.0"];
#   "18" -- "5" [label="36.0"];
#   "18" -- "12" [label="2.0"];
#   "18" -- "1" [label="1.0"];
#   "18" -- "8" [label="12.0"];
#   "18" -- "10" [label="3.0"];
#   "18" -- "3" [label="19.0"];
#   "12" -- "10" [label="5.0"];
#   "12" -- "17" [label="12.0"];
#   "12" -- "27" [label="38.0"];
#   "12" -- "24" [label="5.0"];
#   "12" -- "3" [label="20.0"];
#   "12" -- "9" [label="26.0"];
#   "12" -- "28" [label="5.0"];
#   "12" -- "1" [label="42.0"];
#   "12" -- "18" [label="2.0"];
#   "12" -- "13" [label="22.0"];
#   "12" -- "8" [label="44.0"];
#   "12" -- "19" [label="14.0"];
#   "12" -- "20" [label="2.0"];
#   "12" -- "22" [label="13.0"];
#   "12" -- "14" [label="40.0"];
#   "12" -- "4" [label="43.0"];
#   "12" -- "5" [label="27.0"];
#   "15" -- "27" [label="24.0"];
#   "15" -- "19" [label="11.0"];
#   "15" -- "14" [label="15.0"];
#   "15" -- "18" [label="19.0"];
#   "15" -- "1" [label="1.0"];
#   "15" -- "16" [label="1.0"];
#   "15" -- "8" [label="9.0"];
#   "15" -- "17" [label="15.0"];
#   "15" -- "7" [label="41.0"];
#   "15" -- "4" [label="7.0"];
#   "15" -- "13" [label="43.0"];
#   "15" -- "11" [label="9.0"];
#   "16" -- "14" [label="51.0"];
#   "16" -- "13" [label="4.0"];
#   "16" -- "8" [label="17.0"];
#   "16" -- "21" [label="4.0"];
#   "16" -- "6" [label="5.0"];
#   "16" -- "15" [label="1.0"];
#   "16" -- "28" [label="35.0"];
#   "16" -- "24" [label="9.0"];
#   "16" -- "25" [label="41.0"];
#   "16" -- "3" [label="7.0"];
#   "16" -- "1" [label="17.0"];
#   "16" -- "22" [label="18.0"];
#   "16" -- "11" [label="36.0"];
#   "16" -- "4" [label="34.0"];
#   "16" -- "26" [label="35.0"];
#   "17" -- "12" [label="12.0"];
#   "17" -- "26" [label="43.0"];
#   "17" -- "6" [label="3.0"];
#   "17" -- "22" [label="12.0"];
#   "17" -- "15" [label="15.0"];
#   "17" -- "10" [label="32.0"];
#   "17" -- "7" [label="2.0"];
#   "17" -- "11" [label="34.0"];
#   "17" -- "20" [label="41.0"];
#   "17" -- "1" [label="40.0"];
#   "17" -- "21" [label="37.0"];
#   "19" -- "15" [label="11.0"];
#   "19" -- "3" [label="29.0"];
#   "19" -- "25" [label="27.0"];
#   "19" -- "23" [label="4.0"];
#   "19" -- "20" [label="3.0"];
#   "19" -- "12" [label="14.0"];
#   "19" -- "14" [label="19.0"];
#   "19" -- "21" [label="34.0"];
#   "19" -- "5" [label="27.0"];
#   "19" -- "7" [label="22.0"];
#   "20" -- "14" [label="45.0"];
#   "20" -- "1" [label="37.0"];
#   "20" -- "3" [label="7.0"];
#   "20" -- "9" [label="43.0"];
#   "20" -- "19" [label="3.0"];
#   "20" -- "10" [label="9.0"];
#   "20" -- "12" [label="2.0"];
#   "20" -- "27" [label="33.0"];
#   "20" -- "28" [label="11.0"];
#   "20" -- "17" [label="41.0"];
#   "20" -- "26" [label="36.0"];
#   "21" -- "7" [label="21.0"];
#   "21" -- "22" [label="4.0"];
#   "21" -- "18" [label="9.0"];
#   "21" -- "24" [label="21.0"];
#   "21" -- "10" [label="16.0"];
#   "21" -- "25" [label="39.0"];
#   "21" -- "16" [label="4.0"];
#   "21" -- "13" [label="9.0"];
#   "21" -- "9" [label="16.0"];
#   "21" -- "5" [label="10.0"];
#   "21" -- "1" [label="21.0"];
#   "21" -- "19" [label="34.0"];
#   "21" -- "6" [label="35.0"];
#   "21" -- "2" [label="21.0"];
#   "21" -- "17" [label="37.0"];
#   "23" -- "2" [label="16.0"];
#   "23" -- "25" [label="22.0"];
#   "23" -- "7" [label="14.0"];
#   "23" -- "19" [label="4.0"];
#   "23" -- "26" [label="2.0"];
#   "23" -- "8" [label="8.0"];
#   "23" -- "27" [label="27.0"];
#   "23" -- "1" [label="9.0"];
#   "23" -- "6" [label="27.0"];
#   "23" -- "4" [label="21.0"];
#   "23" -- "10" [label="35.0"];
#   "25" -- "6" [label="47.0"];
#   "25" -- "7" [label="39.0"];
#   "25" -- "19" [label="27.0"];
#   "25" -- "21" [label="39.0"];
#   "25" -- "23" [label="22.0"];
#   "25" -- "14" [label="5.0"];
#   "25" -- "26" [label="15.0"];
#   "25" -- "16" [label="41.0"];
#   "25" -- "13" [label="31.0"];
#   "25" -- "1" [label="42.0"];
#   "26" -- "7" [label="18.0"];
#   "26" -- "17" [label="43.0"];
#   "26" -- "14" [label="21.0"];
#   "26" -- "13" [label="42.0"];
#   "26" -- "3" [label="7.0"];
#   "26" -- "25" [label="15.0"];
#   "26" -- "23" [label="2.0"];
#   "26" -- "24" [label="15.0"];
#   "26" -- "8" [label="28.0"];
#   "26" -- "27" [label="21.0"];
#   "26" -- "20" [label="36.0"];
#   "26" -- "16" [label="35.0"];
#   "28" -- "10" [label="32.0"];
#   "28" -- "12" [label="5.0"];
#   "28" -- "11" [label="37.0"];
#   "28" -- "27" [label="5.0"];
#   "28" -- "16" [label="35.0"];
#   "28" -- "13" [label="23.0"];
#   "28" -- "24" [label="1.0"];
#   "28" -- "6" [label="9.0"];
#   "28" -- "20" [label="11.0"];
#   "28" -- "3" [label="44.0"];
#   "28" -- "4" [label="45.0"];
# }

# %%
Source(read_dot_file("hd6dijkstra"))
# Out:
# /Users/varshahindupur/Desktop/Graph/Dijiktra/hd6dijkstra.dot
# // This is a weighted undirected graph
# graph G {
#   "1" [label="1 (0.0)"];
#   "31" [label="31 (6.0)"];
#   "2" [label="2 (3.0)"];
#   "85" [label="85 (3.0)"];
#   "3" [label="3 (4.0)"];
#   "32" [label="32 (3.0)"];
#   "4" [label="4 (5.0)"];
#   "5" [label="5 (3.0)"];
#   "54" [label="54 (3.0)"];
#   "6" [label="6 (4.0)"];
#   "21" [label="21 (6.0)"];
#   "7" [label="7 (5.0)"];
#   "8" [label="8 (5.0)"];
#   "58" [label="58 (4.0)"];
#   "9" [label="9 (4.0)"];
#   "42" [label="42 (1.0)"];
#   "10" [label="10 (4.0)"];
#   "18" [label="18 (5.0)"];
#   "11" [label="11 (7.0)"];
#   "29" [label="29 (6.0)"];
#   "12" [label="12 (6.0)"];
#   "61" [label="61 (4.0)"];
#   "13" [label="13 (4.0)"];
#   "73" [label="73 (4.0)"];
#   "14" [label="14 (1.0)"];
#   "15" [label="15 (4.0)"];
#   "16" [label="16 (5.0)"];
#   "49" [label="49 (7.0)"];
#   "17" [label="17 (5.0)"];
#   "30" [label="30 (2.0)"];
#   "19" [label="19 (4.0)"];
#   "22" [label="22 (5.0)"];
#   "20" [label="20 (5.0)"];
#   "38" [label="38 (3.0)"];
#   "55" [label="55 (5.0)"];
#   "23" [label="23 (6.0)"];
#   "78" [label="78 (5.0)"];
#   "24" [label="24 (4.0)"];
#   "25" [label="25 (5.0)"];
#   "26" [label="26 (3.0)"];
#   "27" [label="27 (5.0)"];
#   "28" [label="28 (5.0)"];
#   "47" [label="47 (6.0)"];
#   "65" [label="65 (4.0)"];
#   "79" [label="79 (5.0)"];
#   "62" [label="62 (5.0)"];
#   "33" [label="33 (3.0)"];
#   "34" [label="34 (6.0)"];
#   "43" [label="43 (6.0)"];
#   "35" [label="35 (5.0)"];
#   "36" [label="36 (3.0)"];
#   "37" [label="37 (6.0)"];
#   "48" [label="48 (7.0)"];
#   "53" [label="53 (5.0)"];
#   "39" [label="39 (2.0)"];
#   "76" [label="76 (6.0)"];
#   "40" [label="40 (6.0)"];
#   "41" [label="41 (4.0)"];
#   "75" [label="75 (4.0)"];
#   "44" [label="44 (3.0)"];
#   "45" [label="45 (4.0)"];
#   "46" [label="46 (5.0)"];
#   "50" [label="50 (3.0)"];
#   "51" [label="51 (6.0)"];
#   "64" [label="64 (5.0)"];
#   "52" [label="52 (3.0)"];
#   "68" [label="68 (3.0)"];
#   "56" [label="56 (4.0)"];
#   "57" [label="57 (7.0)"];
#   "88" [label="88 (2.0)"];
#   "59" [label="59 (4.0)"];
#   "60" [label="60 (6.0)"];
#   "63" [label="63 (5.0)"];
#   "66" [label="66 (2.0)"];
#   "67" [label="67 (2.0)"];
#   "69" [label="69 (6.0)"];
#   "70" [label="70 (4.0)"];
#   "71" [label="71 (6.0)"];
#   "72" [label="72 (4.0)"];
#   "74" [label="74 (5.0)"];
#   "77" [label="77 (3.0)"];
#   "80" [label="80 (4.0)"];
#   "81" [label="81 (4.0)"];
#   "82" [label="82 (4.0)"];
#   "83" [label="83 (2.0)"];
#   "84" [label="84 (1.0)"];
#   "86" [label="86 (3.0)"];
#   "87" [label="87 (3.0)"];
#   "1" -- "31" [label="8.0"];
#   "1" -- "4" [label="6.0"];
#   "1" -- "74" [label="9.0"];
#   "1" -- "68" [label="3.0"];
#   "1" -- "33" [label="6.0"];
#   "1" -- "80" [label="24.0"];
#   "1" -- "7" [label="5.0"];
#   "1" -- "25" [label="39.0"];
#   "1" -- "44" [label="3.0"];
#   "1" -- "13" [label="32.0"];
#   "1" -- "76" [label="37.0"];
#   "1" -- "30" [label="2.0"];
#   "1" -- "39" [label="2.0"];
#   "1" -- "35" [label="25.0"];
#   "1" -- "9" [label="21.0"];
#   "1" -- "84" [label="1.0"];
#   "1" -- "42" [label="1.0"];
#   "1" -- "16" [label="5.0"];
#   "1" -- "2" [label="3.0"];
#   "1" -- "72" [label="37.0"];
#   "1" -- "46" [label="40.0"];
#   "1" -- "57" [label="8.0"];
#   "1" -- "6" [label="11.0"];
#   "1" -- "17" [label="8.0"];
#   "1" -- "47" [label="22.0"];
#   "1" -- "83" [label="17.0"];
#   "1" -- "12" [label="27.0"];
#   "1" -- "18" [label="15.0"];
#   "1" -- "66" [label="38.0"];
#   "1" -- "67" [label="2.0"];
#   "1" -- "26" [label="7.0"];
#   "1" -- "87" [label="3.0"];
#   "1" -- "65" [label="4.0"];
#   "1" -- "78" [label="14.0"];
#   "1" -- "14" [label="1.0"];
#   "1" -- "27" [label="45.0"];
#   "1" -- "34" [label="35.0"];
#   "1" -- "10" [label="20.0"];
#   "1" -- "69" [label="18.0"];
#   "1" -- "62" [label="7.0"];
#   "1" -- "41" [label="36.0"];
#   "1" -- "63" [label="9.0"];
#   "1" -- "82" [label="6.0"];
#   "1" -- "88" [label="34.0"];
#   "1" -- "85" [label="10.0"];
#   "1" -- "19" [label="6.0"];
#   "1" -- "8" [label="9.0"];
#   "1" -- "21" [label="36.0"];
#   "1" -- "64" [label="8.0"];
#   "1" -- "79" [label="26.0"];
#   "1" -- "77" [label="22.0"];
#   "1" -- "3" [label="6.0"];
#   "1" -- "28" [label="19.0"];
#   "1" -- "11" [label="19.0"];
#   "1" -- "23" [label="41.0"];
#   "1" -- "61" [label="8.0"];
#   "1" -- "52" [label="8.0"];
#   "1" -- "53" [label="25.0"];
#   "1" -- "22" [label="39.0"];
#   "1" -- "43" [label="19.0"];
#   "1" -- "75" [label="4.0"];
#   "1" -- "70" [label="32.0"];
#   "1" -- "86" [label="10.0"];
#   "1" -- "15" [label="30.0"];
#   "1" -- "58" [label="19.0"];
#   "1" -- "37" [label="16.0"];
#   "1" -- "59" [label="9.0"];
#   "31" -- "1" [label="8.0"];
#   "31" -- "79" [label="57.0"];
#   "31" -- "28" [label="25.0"];
#   "31" -- "75" [label="25.0"];
#   "31" -- "25" [label="20.0"];
#   "31" -- "45" [label="19.0"];
#   "31" -- "82" [label="5.0"];
#   "31" -- "37" [label="28.0"];
#   "31" -- "78" [label="1.0"];
#   "31" -- "6" [label="5.0"];
#   "31" -- "46" [label="35.0"];
#   "31" -- "81" [label="46.0"];
#   "31" -- "5" [label="17.0"];
#   "31" -- "3" [label="19.0"];
#   "31" -- "4" [label="28.0"];
#   "31" -- "77" [label="41.0"];
#   "31" -- "22" [label="8.0"];
#   "31" -- "51" [label="39.0"];
#   "31" -- "16" [label="7.0"];
#   "31" -- "66" [label="16.0"];
#   "31" -- "55" [label="26.0"];
#   "31" -- "11" [label="6.0"];
#   "31" -- "65" [label="33.0"];
#   "31" -- "69" [label="24.0"];
#   "31" -- "86" [label="13.0"];
#   "31" -- "36" [label="10.0"];
#   "31" -- "67" [label="10.0"];
#   "31" -- "74" [label="45.0"];
#   "31" -- "23" [label="37.0"];
#   "31" -- "2" [label="3.0"];
#   "31" -- "50" [label="38.0"];
#   "31" -- "62" [label="12.0"];
#   "31" -- "52" [label="38.0"];
#   "31" -- "41" [label="21.0"];
#   "31" -- "43" [label="45.0"];
#   "31" -- "49" [label="10.0"];
#   "31" -- "30" [label="31.0"];
#   "31" -- "34" [label="21.0"];
#   "31" -- "39" [label="16.0"];
#   "31" -- "12" [label="1.0"];
#   "31" -- "35" [label="9.0"];
#   "31" -- "54" [label="44.0"];
#   "31" -- "24" [label="21.0"];
#   "31" -- "80" [label="39.0"];
#   "31" -- "84" [label="16.0"];
#   "2" -- "85" [label="24.0"];
#   "2" -- "45" [label="1.0"];
#   "2" -- "38" [label="22.0"];
#   "2" -- "34" [label="11.0"];
#   "2" -- "1" [label="3.0"];
#   "2" -- "27" [label="33.0"];
#   "2" -- "3" [label="1.0"];
#   "2" -- "12" [label="6.0"];
#   "2" -- "44" [label="1.0"];
#   "2" -- "57" [label="19.0"];
#   "2" -- "8" [label="9.0"];
#   "2" -- "20" [label="19.0"];
#   "2" -- "73" [label="9.0"];
#   "2" -- "28" [label="24.0"];
#   "2" -- "15" [label="26.0"];
#   "2" -- "48" [label="15.0"];
#   "2" -- "10" [label="12.0"];
#   "2" -- "42" [label="16.0"];
#   "2" -- "5" [label="11.0"];
#   "2" -- "13" [label="41.0"];
#   "2" -- "7" [label="30.0"];
#   "2" -- "37" [label="20.0"];
#   "2" -- "46" [label="19.0"];
#   "2" -- "25" [label="17.0"];
#   "2" -- "72" [label="42.0"];
#   "2" -- "68" [label="16.0"];
#   "2" -- "31" [label="3.0"];
#   "2" -- "69" [label="45.0"];
#   "2" -- "52" [label="19.0"];
#   "2" -- "60" [label="17.0"];
#   "2" -- "9" [label="13.0"];
#   "2" -- "61" [label="8.0"];
#   "2" -- "39" [label="19.0"];
#   "2" -- "78" [label="32.0"];
#   "2" -- "76" [label="34.0"];
#   "2" -- "21" [label="23.0"];
#   "2" -- "55" [label="46.0"];
#   "2" -- "54" [label="45.0"];
#   "2" -- "84" [label="11.0"];
#   "85" -- "2" [label="24.0"];
#   "85" -- "34" [label="54.0"];
#   "85" -- "58" [label="1.0"];
#   "85" -- "62" [label="9.0"];
#   "85" -- "88" [label="28.0"];
#   "85" -- "5" [label="15.0"];
#   "85" -- "22" [label="4.0"];
#   "85" -- "69" [label="20.0"];
#   "85" -- "86" [label="22.0"];
#   "85" -- "15" [label="23.0"];
#   "85" -- "78" [label="10.0"];
#   "85" -- "64" [label="21.0"];
#   "85" -- "38" [label="44.0"];
#   "85" -- "46" [label="27.0"];
#   "85" -- "7" [label="38.0"];
#   "85" -- "4" [label="13.0"];
#   "85" -- "67" [label="4.0"];
#   "85" -- "84" [label="28.0"];
#   "85" -- "10" [label="3.0"];
#   "85" -- "6" [label="8.0"];
#   "85" -- "49" [label="40.0"];
#   "85" -- "74" [label="41.0"];
#   "85" -- "44" [label="18.0"];
#   "85" -- "3" [label="9.0"];
#   "85" -- "50" [label="7.0"];
#   "85" -- "18" [label="26.0"];
#   "85" -- "25" [label="24.0"];
#   "85" -- "1" [label="10.0"];
#   "85" -- "24" [label="3.0"];
#   "85" -- "56" [label="36.0"];
#   "85" -- "42" [label="4.0"];
#   "85" -- "45" [label="16.0"];
#   "85" -- "66" [label="15.0"];
#   "85" -- "52" [label="5.0"];
#   "85" -- "20" [label="33.0"];
#   "85" -- "83" [label="1.0"];
#   "85" -- "73" [label="39.0"];
#   "85" -- "26" [label="10.0"];
#   "85" -- "11" [label="33.0"];
#   "85" -- "33" [label="3.0"];
#   "85" -- "41" [label="34.0"];
#   "85" -- "53" [label="43.0"];
#   "85" -- "63" [label="17.0"];
#   "85" -- "8" [label="16.0"];
#   "3" -- "32" [label="50.0"];
#   "3" -- "14" [label="5.0"];
#   "3" -- "36" [label="54.0"];
#   "3" -- "49" [label="3.0"];
#   "3" -- "58" [label="34.0"];
#   "3" -- "46" [label="26.0"];
#   "3" -- "2" [label="1.0"];
#   "3" -- "41" [label="8.0"];
#   "3" -- "4" [label="16.0"];
#   "3" -- "30" [label="7.0"];
#   "3" -- "11" [label="6.0"];
#   "3" -- "31" [label="19.0"];
#   "3" -- "81" [label="16.0"];
#   "3" -- "24" [label="4.0"];
#   "3" -- "35" [label="34.0"];
#   "3" -- "69" [label="7.0"];
#   "3" -- "88" [label="15.0"];
#   "3" -- "25" [label="10.0"];
#   "3" -- "66" [label="27.0"];
#   "3" -- "85" [label="9.0"];
#   "3" -- "9" [label="26.0"];
#   "3" -- "26" [label="21.0"];
#   "3" -- "20" [label="7.0"];
#   "3" -- "72" [label="39.0"];
#   "3" -- "73" [label="30.0"];
#   "3" -- "75" [label="12.0"];
#   "3" -- "21" [label="7.0"];
#   "3" -- "45" [label="43.0"];
#   "3" -- "12" [label="34.0"];
#   "3" -- "48" [label="7.0"];
#   "3" -- "70" [label="18.0"];
#   "3" -- "39" [label="29.0"];
#   "3" -- "50" [label="19.0"];
#   "3" -- "16" [label="24.0"];
#   "3" -- "1" [label="6.0"];
#   "3" -- "79" [label="29.0"];
#   "3" -- "80" [label="23.0"];
#   "3" -- "62" [label="12.0"];
#   "3" -- "63" [label="12.0"];
#   "3" -- "34" [label="44.0"];
#   "3" -- "7" [label="1.0"];
#   "3" -- "10" [label="28.0"];
#   "3" -- "71" [label="8.0"];
#   "3" -- "42" [label="32.0"];
#   "3" -- "86" [label="36.0"];
#   "3" -- "78" [label="33.0"];
#   "32" -- "3" [label="50.0"];
#   "32" -- "7" [label="27.0"];
#   "32" -- "62" [label="55.0"];
#   "32" -- "75" [label="13.0"];
#   "32" -- "76" [label="9.0"];
#   "32" -- "9" [label="46.0"];
#   "32" -- "27" [label="44.0"];
#   "32" -- "87" [label="20.0"];
#   "32" -- "69" [label="32.0"];
#   "32" -- "44" [label="37.0"];
#   "32" -- "50" [label="18.0"];
#   "32" -- "52" [label="26.0"];
#   "32" -- "60" [label="35.0"];
#   "32" -- "17" [label="15.0"];
#   "32" -- "10" [label="1.0"];
#   "32" -- "15" [label="1.0"];
#   "32" -- "8" [label="4.0"];
#   "32" -- "6" [label="20.0"];
#   "32" -- "56" [label="2.0"];
#   "32" -- "5" [label="25.0"];
#   "32" -- "40" [label="44.0"];
#   "32" -- "14" [label="25.0"];
#   "32" -- "54" [label="34.0"];
#   "32" -- "39" [label="1.0"];
#   "32" -- "77" [label="9.0"];
#   "32" -- "80" [label="6.0"];
#   "32" -- "20" [label="33.0"];
#   "32" -- "22" [label="33.0"];
#   "32" -- "42" [label="14.0"];
#   "32" -- "55" [label="23.0"];
#   "32" -- "81" [label="27.0"];
#   "32" -- "49" [label="27.0"];
#   "32" -- "73" [label="8.0"];
#   "32" -- "46" [label="35.0"];
#   "32" -- "57" [label="22.0"];
#   "32" -- "63" [label="9.0"];
#   "4" -- "1" [label="6.0"];
#   "4" -- "66" [label="23.0"];
#   "4" -- "76" [label="9.0"];
#   "4" -- "77" [label="27.0"];
#   "4" -- "61" [label="9.0"];
#   "4" -- "10" [label="7.0"];
#   "4" -- "29" [label="24.0"];
#   "4" -- "52" [label="8.0"];
#   "4" -- "48" [label="25.0"];
#   "4" -- "40" [label="12.0"];
#   "4" -- "3" [label="16.0"];
#   "4" -- "85" [label="13.0"];
#   "4" -- "21" [label="15.0"];
#   "4" -- "13" [label="23.0"];
#   "4" -- "75" [label="9.0"];
#   "4" -- "79" [label="5.0"];
#   "4" -- "34" [label="40.0"];
#   "4" -- "9" [label="23.0"];
#   "4" -- "31" [label="28.0"];
#   "4" -- "80" [label="9.0"];
#   "4" -- "83" [label="8.0"];
#   "4" -- "43" [label="28.0"];
#   "4" -- "67" [label="21.0"];
#   "4" -- "25" [label="16.0"];
#   "4" -- "37" [label="4.0"];
#   "4" -- "63" [label="13.0"];
#   "4" -- "15" [label="1.0"];
#   "4" -- "49" [label="6.0"];
#   "4" -- "5" [label="9.0"];
#   "4" -- "60" [label="39.0"];
#   "4" -- "71" [label="1.0"];
#   "4" -- "47" [label="6.0"];
#   "4" -- "51" [label="5.0"];
#   "4" -- "59" [label="46.0"];
#   "4" -- "73" [label="5.0"];
#   "4" -- "50" [label="8.0"];
#   "4" -- "23" [label="15.0"];
#   "4" -- "84" [label="20.0"];
#   "4" -- "7" [label="9.0"];
#   "4" -- "30" [label="41.0"];
#   "4" -- "74" [label="42.0"];
#   "4" -- "65" [label="26.0"];
#   "4" -- "69" [label="17.0"];
#   "4" -- "22" [label="3.0"];
#   "4" -- "33" [label="35.0"];
#   "4" -- "81" [label="1.0"];
#   "4" -- "56" [label="32.0"];
#   "5" -- "54" [label="4.0"];
#   "5" -- "57" [label="9.0"];
#   "5" -- "26" [label="15.0"];
#   "5" -- "13" [label="18.0"];
#   "5" -- "23" [label="24.0"];
#   "5" -- "7" [label="9.0"];
#   "5" -- "85" [label="15.0"];
#   "5" -- "72" [label="30.0"];
#   "5" -- "29" [label="46.0"];
#   "5" -- "28" [label="11.0"];
#   "5" -- "42" [label="24.0"];
#   "5" -- "37" [label="9.0"];
#   "5" -- "35" [label="35.0"];
#   "5" -- "33" [label="2.0"];
#   "5" -- "12" [label="3.0"];
#   "5" -- "31" [label="17.0"];
#   "5" -- "17" [label="7.0"];
#   "5" -- "11" [label="8.0"];
#   "5" -- "32" [label="25.0"];
#   "5" -- "38" [label="2.0"];
#   "5" -- "24" [label="10.0"];
#   "5" -- "62" [label="8.0"];
#   "5" -- "55" [label="33.0"];
#   "5" -- "66" [label="14.0"];
#   "5" -- "78" [label="32.0"];
#   "5" -- "68" [label="43.0"];
#   "5" -- "2" [label="11.0"];
#   "5" -- "51" [label="34.0"];
#   "5" -- "77" [label="38.0"];
#   "5" -- "80" [label="44.0"];
#   "5" -- "4" [label="9.0"];
#   "5" -- "34" [label="42.0"];
#   "5" -- "9" [label="16.0"];
#   "5" -- "65" [label="24.0"];
#   "5" -- "15" [label="33.0"];
#   "5" -- "50" [label="8.0"];
#   "5" -- "8" [label="18.0"];
#   "5" -- "20" [label="29.0"];
#   "5" -- "84" [label="22.0"];
#   "5" -- "82" [label="30.0"];
#   "5" -- "73" [label="31.0"];
#   "5" -- "56" [label="39.0"];
#   "5" -- "43" [label="18.0"];
#   "5" -- "83" [label="1.0"];
#   "5" -- "27" [label="34.0"];
#   "54" -- "5" [label="4.0"];
#   "54" -- "36" [label="53.0"];
#   "54" -- "9" [label="6.0"];
#   "54" -- "21" [label="20.0"];
#   "54" -- "65" [label="42.0"];
#   "54" -- "20" [label="22.0"];
#   "54" -- "55" [label="5.0"];
#   "54" -- "27" [label="11.0"];
#   "54" -- "64" [label="43.0"];
#   "54" -- "74" [label="8.0"];
#   "54" -- "47" [label="39.0"];
#   "54" -- "12" [label="44.0"];
#   "54" -- "69" [label="17.0"];
#   "54" -- "48" [label="5.0"];
#   "54" -- "24" [label="6.0"];
#   "54" -- "66" [label="5.0"];
#   "54" -- "32" [label="34.0"];
#   "54" -- "44" [label="38.0"];
#   "54" -- "30" [label="34.0"];
#   "54" -- "60" [label="10.0"];
#   "54" -- "35" [label="18.0"];
#   "54" -- "68" [label="36.0"];
#   "54" -- "75" [label="17.0"];
#   "54" -- "38" [label="3.0"];
#   "54" -- "67" [label="31.0"];
#   "54" -- "33" [label="21.0"];
#   "54" -- "82" [label="1.0"];
#   "54" -- "15" [label="30.0"];
#   "54" -- "46" [label="2.0"];
#   "54" -- "72" [label="24.0"];
#   "54" -- "37" [label="41.0"];
#   "54" -- "13" [label="22.0"];
#   "54" -- "10" [label="43.0"];
#   "54" -- "11" [label="14.0"];
#   "54" -- "61" [label="23.0"];
#   "54" -- "31" [label="44.0"];
#   "54" -- "53" [label="22.0"];
#   "54" -- "52" [label="39.0"];
#   "54" -- "42" [label="2.0"];
#   "54" -- "28" [label="37.0"];
#   "54" -- "2" [label="45.0"];
#   "54" -- "77" [label="36.0"];
#   "54" -- "78" [label="7.0"];
#   "6" -- "21" [label="66.0"];
#   "6" -- "61" [label="24.0"];
#   "6" -- "66" [label="19.0"];
#   "6" -- "28" [label="4.0"];
#   "6" -- "27" [label="29.0"];
#   "6" -- "35" [label="36.0"];
#   "6" -- "30" [label="10.0"];
#   "6" -- "1" [label="11.0"];
#   "6" -- "15" [label="42.0"];
#   "6" -- "63" [label="11.0"];
#   "6" -- "74" [label="4.0"];
#   "6" -- "20" [label="1.0"];
#   "6" -- "77" [label="15.0"];
#   "6" -- "58" [label="9.0"];
#   "6" -- "31" [label="5.0"];
#   "6" -- "79" [label="32.0"];
#   "6" -- "47" [label="11.0"];
#   "6" -- "70" [label="30.0"];
#   "6" -- "22" [label="9.0"];
#   "6" -- "50" [label="14.0"];
#   "6" -- "76" [label="39.0"];
#   "6" -- "51" [label="4.0"];
#   "6" -- "11" [label="32.0"];
#   "6" -- "88" [label="2.0"];
#   "6" -- "60" [label="30.0"];
#   "6" -- "85" [label="8.0"];
#   "6" -- "32" [label="20.0"];
#   "6" -- "43" [label="30.0"];
#   "6" -- "59" [label="23.0"];
#   "6" -- "84" [label="6.0"];
#   "6" -- "73" [label="2.0"];
#   "6" -- "46" [label="43.0"];
#   "6" -- "16" [label="12.0"];
#   "6" -- "9" [label="16.0"];
#   "6" -- "67" [label="15.0"];
#   "6" -- "25" [label="1.0"];
#   "6" -- "33" [label="31.0"];
#   "6" -- "12" [label="31.0"];
#   "6" -- "55" [label="7.0"];
#   "6" -- "17" [label="31.0"];
#   "6" -- "49" [label="27.0"];
#   "6" -- "34" [label="17.0"];
#   "6" -- "68" [label="15.0"];
#   "6" -- "45" [label="6.0"];
#   "6" -- "71" [label="4.0"];
#   "21" -- "6" [label="66.0"];
#   "21" -- "55" [label="49.0"];
#   "21" -- "28" [label="19.0"];
#   "21" -- "76" [label="7.0"];
#   "21" -- "41" [label="13.0"];
#   "21" -- "80" [label="28.0"];
#   "21" -- "81" [label="22.0"];
#   "21" -- "54" [label="20.0"];
#   "21" -- "63" [label="1.0"];
#   "21" -- "44" [label="15.0"];
#   "21" -- "26" [label="10.0"];
#   "21" -- "20" [label="18.0"];
#   "21" -- "68" [label="22.0"];
#   "21" -- "4" [label="15.0"];
#   "21" -- "58" [label="9.0"];
#   "21" -- "34" [label="22.0"];
#   "21" -- "82" [label="30.0"];
#   "21" -- "49" [label="20.0"];
#   "21" -- "53" [label="20.0"];
#   "21" -- "88" [label="39.0"];
#   "21" -- "86" [label="3.0"];
#   "21" -- "45" [label="45.0"];
#   "21" -- "9" [label="10.0"];
#   "21" -- "67" [label="35.0"];
#   "21" -- "78" [label="43.0"];
#   "21" -- "27" [label="45.0"];
#   "21" -- "51" [label="28.0"];
#   "21" -- "22" [label="10.0"];
#   "21" -- "3" [label="7.0"];
#   "21" -- "66" [label="11.0"];
#   "21" -- "56" [label="15.0"];
#   "21" -- "1" [label="36.0"];
#   "21" -- "72" [label="31.0"];
#   "21" -- "69" [label="12.0"];
#   "21" -- "39" [label="10.0"];
#   "21" -- "36" [label="30.0"];
#   "21" -- "14" [label="31.0"];
#   "21" -- "16" [label="40.0"];
#   "21" -- "30" [label="23.0"];
#   "21" -- "2" [label="23.0"];
#   "21" -- "70" [label="22.0"];
#   "21" -- "65" [label="28.0"];
#   "21" -- "46" [label="27.0"];
#   "7" -- "32" [label="27.0"];
#   "7" -- "24" [label="6.0"];
#   "7" -- "84" [label="42.0"];
#   "7" -- "13" [label="31.0"];
#   "7" -- "1" [label="5.0"];
#   "7" -- "9" [label="17.0"];
#   "7" -- "35" [label="44.0"];
#   "7" -- "17" [label="9.0"];
#   "7" -- "59" [label="10.0"];
#   "7" -- "5" [label="9.0"];
#   "7" -- "29" [label="7.0"];
#   "7" -- "20" [label="29.0"];
#   "7" -- "23" [label="18.0"];
#   "7" -- "85" [label="38.0"];
#   "7" -- "64" [label="7.0"];
#   "7" -- "78" [label="16.0"];
#   "7" -- "79" [label="5.0"];
#   "7" -- "10" [label="29.0"];
#   "7" -- "50" [label="42.0"];
#   "7" -- "77" [label="9.0"];
#   "7" -- "53" [label="25.0"];
#   "7" -- "45" [label="42.0"];
#   "7" -- "14" [label="22.0"];
#   "7" -- "12" [label="28.0"];
#   "7" -- "56" [label="3.0"];
#   "7" -- "66" [label="31.0"];
#   "7" -- "65" [label="10.0"];
#   "7" -- "70" [label="13.0"];
#   "7" -- "41" [label="6.0"];
#   "7" -- "30" [label="4.0"];
#   "7" -- "48" [label="5.0"];
#   "7" -- "2" [label="30.0"];
#   "7" -- "83" [label="6.0"];
#   "7" -- "19" [label="43.0"];
#   "7" -- "27" [label="26.0"];
#   "7" -- "51" [label="5.0"];
#   "7" -- "86" [label="4.0"];
#   "7" -- "33" [label="38.0"];
#   "7" -- "4" [label="9.0"];
#   "7" -- "26" [label="9.0"];
#   "7" -- "69" [label="6.0"];
#   "7" -- "72" [label="16.0"];
#   "7" -- "81" [label="6.0"];
#   "7" -- "3" [label="1.0"];
#   "7" -- "43" [label="36.0"];
#   "7" -- "63" [label="31.0"];
#   "7" -- "73" [label="42.0"];
#   "8" -- "58" [label="8.0"];
#   "8" -- "78" [label="2.0"];
#   "8" -- "33" [label="7.0"];
#   "8" -- "11" [label="9.0"];
#   "8" -- "30" [label="12.0"];
#   "8" -- "61" [label="1.0"];
#   "8" -- "13" [label="33.0"];
#   "8" -- "81" [label="31.0"];
#   "8" -- "84" [label="16.0"];
#   "8" -- "57" [label="12.0"];
#   "8" -- "69" [label="27.0"];
#   "8" -- "36" [label="12.0"];
#   "8" -- "12" [label="16.0"];
#   "8" -- "25" [label="26.0"];
#   "8" -- "73" [label="23.0"];
#   "8" -- "2" [label="9.0"];
#   "8" -- "55" [label="22.0"];
#   "8" -- "32" [label="4.0"];
#   "8" -- "86" [label="6.0"];
#   "8" -- "56" [label="17.0"];
#   "8" -- "82" [label="34.0"];
#   "8" -- "38" [label="31.0"];
#   "8" -- "63" [label="4.0"];
#   "8" -- "87" [label="32.0"];
#   "8" -- "64" [label="38.0"];
#   "8" -- "43" [label="17.0"];
#   "8" -- "49" [label="18.0"];
#   "8" -- "74" [label="22.0"];
#   "8" -- "37" [label="34.0"];
#   "8" -- "9" [label="8.0"];
#   "8" -- "1" [label="9.0"];
#   "8" -- "42" [label="45.0"];
#   "8" -- "88" [label="5.0"];
#   "8" -- "24" [label="40.0"];
#   "8" -- "59" [label="15.0"];
#   "8" -- "52" [label="4.0"];
#   "8" -- "20" [label="9.0"];
#   "8" -- "5" [label="18.0"];
#   "8" -- "14" [label="42.0"];
#   "8" -- "15" [label="10.0"];
#   "8" -- "34" [label="29.0"];
#   "8" -- "18" [label="10.0"];
#   "8" -- "50" [label="14.0"];
#   "8" -- "85" [label="16.0"];
#   "8" -- "16" [label="40.0"];
#   "8" -- "46" [label="9.0"];
#   "58" -- "8" [label="8.0"];
#   "58" -- "88" [label="9.0"];
#   "58" -- "3" [label="34.0"];
#   "58" -- "16" [label="3.0"];
#   "58" -- "85" [label="1.0"];
#   "58" -- "87" [label="37.0"];
#   "58" -- "74" [label="13.0"];
#   "58" -- "57" [label="20.0"];
#   "58" -- "84" [label="43.0"];
#   "58" -- "69" [label="2.0"];
#   "58" -- "6" [label="9.0"];
#   "58" -- "45" [label="12.0"];
#   "58" -- "35" [label="12.0"];
#   "58" -- "86" [label="15.0"];
#   "58" -- "11" [label="32.0"];
#   "58" -- "15" [label="44.0"];
#   "58" -- "80" [label="9.0"];
#   "58" -- "21" [label="9.0"];
#   "58" -- "14" [label="14.0"];
#   "58" -- "28" [label="43.0"];
#   "58" -- "17" [label="20.0"];
#   "58" -- "42" [label="23.0"];
#   "58" -- "20" [label="41.0"];
#   "58" -- "39" [label="4.0"];
#   "58" -- "52" [label="8.0"];
#   "58" -- "83" [label="39.0"];
#   "58" -- "63" [label="46.0"];
#   "58" -- "24" [label="12.0"];
#   "58" -- "78" [label="9.0"];
#   "58" -- "40" [label="3.0"];
#   "58" -- "9" [label="15.0"];
#   "58" -- "59" [label="18.0"];
#   "58" -- "30" [label="9.0"];
#   "58" -- "75" [label="4.0"];
#   "58" -- "37" [label="23.0"];
#   "58" -- "81" [label="9.0"];
#   "58" -- "25" [label="24.0"];
#   "58" -- "50" [label="18.0"];
#   "58" -- "1" [label="19.0"];
#   "58" -- "38" [label="34.0"];
#   "9" -- "42" [label="3.0"];
#   "9" -- "68" [label="44.0"];
#   "9" -- "7" [label="17.0"];
#   "9" -- "75" [label="26.0"];
#   "9" -- "54" [label="6.0"];
#   "9" -- "1" [label="21.0"];
#   "9" -- "79" [label="4.0"];
#   "9" -- "32" [label="46.0"];
#   "9" -- "46" [label="25.0"];
#   "9" -- "35" [label="16.0"];
#   "9" -- "81" [label="11.0"];
#   "9" -- "14" [label="41.0"];
#   "9" -- "25" [label="12.0"];
#   "9" -- "88" [label="16.0"];
#   "9" -- "22" [label="37.0"];
#   "9" -- "18" [label="11.0"];
#   "9" -- "4" [label="23.0"];
#   "9" -- "13" [label="9.0"];
#   "9" -- "77" [label="41.0"];
#   "9" -- "72" [label="45.0"];
#   "9" -- "3" [label="26.0"];
#   "9" -- "17" [label="30.0"];
#   "9" -- "43" [label="24.0"];
#   "9" -- "23" [label="8.0"];
#   "9" -- "86" [label="32.0"];
#   "9" -- "21" [label="10.0"];
#   "9" -- "8" [label="8.0"];
#   "9" -- "63" [label="1.0"];
#   "9" -- "6" [label="16.0"];
#   "9" -- "55" [label="13.0"];
#   "9" -- "58" [label="15.0"];
#   "9" -- "24" [label="21.0"];
#   "9" -- "5" [label="16.0"];
#   "9" -- "83" [label="30.0"];
#   "9" -- "47" [label="43.0"];
#   "9" -- "2" [label="13.0"];
#   "9" -- "48" [label="15.0"];
#   "9" -- "73" [label="8.0"];
#   "9" -- "26" [label="8.0"];
#   "9" -- "20" [label="36.0"];
#   "9" -- "37" [label="20.0"];
#   "9" -- "45" [label="13.0"];
#   "9" -- "19" [label="11.0"];
#   "9" -- "49" [label="32.0"];
#   "9" -- "59" [label="12.0"];
#   "42" -- "9" [label="3.0"];
#   "42" -- "75" [label="57.0"];
#   "42" -- "45" [label="21.0"];
#   "42" -- "10" [label="34.0"];
#   "42" -- "72" [label="26.0"];
#   "42" -- "1" [label="1.0"];
#   "42" -- "62" [label="30.0"];
#   "42" -- "5" [label="24.0"];
#   "42" -- "49" [label="14.0"];
#   "42" -- "68" [label="22.0"];
#   "42" -- "43" [label="17.0"];
#   "42" -- "11" [label="42.0"];
#   "42" -- "56" [label="11.0"];
#   "42" -- "26" [label="41.0"];
#   "42" -- "88" [label="1.0"];
#   "42" -- "37" [label="30.0"];
#   "42" -- "20" [label="8.0"];
#   "42" -- "51" [label="16.0"];
#   "42" -- "36" [label="7.0"];
#   "42" -- "17" [label="28.0"];
#   "42" -- "58" [label="23.0"];
#   "42" -- "40" [label="33.0"];
#   "42" -- "27" [label="18.0"];
#   "42" -- "83" [label="1.0"];
#   "42" -- "2" [label="16.0"];
#   "42" -- "63" [label="29.0"];
#   "42" -- "18" [label="44.0"];
#   "42" -- "85" [label="4.0"];
#   "42" -- "8" [label="45.0"];
#   "42" -- "65" [label="39.0"];
#   "42" -- "50" [label="34.0"];
#   "42" -- "86" [label="23.0"];
#   "42" -- "32" [label="14.0"];
#   "42" -- "60" [label="25.0"];
#   "42" -- "66" [label="1.0"];
#   "42" -- "80" [label="37.0"];
#   "42" -- "19" [label="41.0"];
#   "42" -- "48" [label="30.0"];
#   "42" -- "70" [label="21.0"];
#   "42" -- "59" [label="40.0"];
#   "42" -- "15" [label="9.0"];
#   "42" -- "81" [label="44.0"];
#   "42" -- "54" [label="2.0"];
#   "42" -- "30" [label="12.0"];
#   "42" -- "3" [label="32.0"];
#   "10" -- "18" [label="9.0"];
#   "10" -- "27" [label="6.0"];
#   "10" -- "46" [label="3.0"];
#   "10" -- "64" [label="27.0"];
#   "10" -- "67" [label="6.0"];
#   "10" -- "40" [label="32.0"];
#   "10" -- "42" [label="34.0"];
#   "10" -- "36" [label="5.0"];
#   "10" -- "14" [label="7.0"];
#   "10" -- "26" [label="14.0"];
#   "10" -- "51" [label="26.0"];
#   "10" -- "4" [label="7.0"];
#   "10" -- "85" [label="3.0"];
#   "10" -- "32" [label="1.0"];
#   "10" -- "66" [label="33.0"];
#   "10" -- "13" [label="6.0"];
#   "10" -- "60" [label="9.0"];
#   "10" -- "72" [label="27.0"];
#   "10" -- "7" [label="29.0"];
#   "10" -- "75" [label="25.0"];
#   "10" -- "39" [label="15.0"];
#   "10" -- "34" [label="28.0"];
#   "10" -- "1" [label="20.0"];
#   "10" -- "48" [label="10.0"];
#   "10" -- "2" [label="12.0"];
#   "10" -- "47" [label="8.0"];
#   "10" -- "35" [label="34.0"];
#   "10" -- "23" [label="14.0"];
#   "10" -- "53" [label="44.0"];
#   "10" -- "80" [label="7.0"];
#   "10" -- "65" [label="15.0"];
#   "10" -- "52" [label="20.0"];
#   "10" -- "87" [label="35.0"];
#   "10" -- "78" [label="1.0"];
#   "10" -- "57" [label="43.0"];
#   "10" -- "83" [label="40.0"];
#   "10" -- "86" [label="29.0"];
#   "10" -- "11" [label="25.0"];
#   "10" -- "19" [label="10.0"];
#   "10" -- "62" [label="3.0"];
#   "10" -- "33" [label="40.0"];
#   "10" -- "20" [label="40.0"];
#   "10" -- "54" [label="43.0"];
#   "10" -- "79" [label="10.0"];
#   "10" -- "50" [label="3.0"];
#   "10" -- "44" [label="20.0"];
#   "10" -- "3" [label="28.0"];
#   "10" -- "29" [label="23.0"];
#   "10" -- "69" [label="3.0"];
#   "10" -- "49" [label="21.0"];
#   "10" -- "84" [label="13.0"];
#   "18" -- "10" [label="9.0"];
#   "18" -- "15" [label="14.0"];
#   "18" -- "12" [label="10.0"];
#   "18" -- "48" [label="9.0"];
#   "18" -- "55" [label="6.0"];
#   "18" -- "59" [label="36.0"];
#   "18" -- "24" [label="19.0"];
#   "18" -- "51" [label="20.0"];
#   "18" -- "53" [label="17.0"];
#   "18" -- "87" [label="4.0"];
#   "18" -- "71" [label="35.0"];
#   "18" -- "11" [label="30.0"];
#   "18" -- "1" [label="15.0"];
#   "18" -- "23" [label="27.0"];
#   "18" -- "64" [label="2.0"];
#   "18" -- "9" [label="11.0"];
#   "18" -- "72" [label="32.0"];
#   "18" -- "33" [label="8.0"];
#   "18" -- "78" [label="30.0"];
#   "18" -- "41" [label="2.0"];
#   "18" -- "30" [label="5.0"];
#   "18" -- "75" [label="16.0"];
#   "18" -- "85" [label="26.0"];
#   "18" -- "68" [label="38.0"];
#   "18" -- "83" [label="3.0"];
#   "18" -- "19" [label="8.0"];
#   "18" -- "49" [label="34.0"];
#   "18" -- "70" [label="28.0"];
#   "18" -- "29" [label="9.0"];
#   "18" -- "61" [label="33.0"];
#   "18" -- "76" [label="3.0"];
#   "18" -- "16" [label="15.0"];
#   "18" -- "42" [label="44.0"];
#   "18" -- "37" [label="10.0"];
#   "18" -- "27" [label="9.0"];
#   "18" -- "67" [label="38.0"];
#   "18" -- "38" [label="35.0"];
#   "18" -- "66" [label="29.0"];
#   "18" -- "8" [label="10.0"];
#   "18" -- "46" [label="24.0"];
#   "18" -- "25" [label="34.0"];
#   "18" -- "26" [label="9.0"];
#   "18" -- "22" [label="46.0"];
#   "18" -- "34" [label="16.0"];
#   "18" -- "45" [label="8.0"];
#   "18" -- "35" [label="16.0"];
#   "18" -- "28" [label="7.0"];
#   "11" -- "29" [label="19.0"];
#   "11" -- "35" [label="19.0"];
#   "11" -- "69" [label="39.0"];
#   "11" -- "12" [label="25.0"];
#   "11" -- "78" [label="10.0"];
#   "11" -- "8" [label="9.0"];
#   "11" -- "38" [label="44.0"];
#   "11" -- "48" [label="5.0"];
#   "11" -- "15" [label="31.0"];
#   "11" -- "18" [label="30.0"];
#   "11" -- "81" [label="44.0"];
#   "11" -- "58" [label="32.0"];
#   "11" -- "80" [label="28.0"];
#   "11" -- "42" [label="42.0"];
#   "11" -- "77" [label="4.0"];
#   "11" -- "3" [label="6.0"];
#   "11" -- "79" [label="3.0"];
#   "11" -- "68" [label="41.0"];
#   "11" -- "45" [label="3.0"];
#   "11" -- "6" [label="32.0"];
#   "11" -- "5" [label="8.0"];
#   "11" -- "28" [label="8.0"];
#   "11" -- "62" [label="4.0"];
#   "11" -- "87" [label="13.0"];
#   "11" -- "25" [label="14.0"];
#   "11" -- "27" [label="13.0"];
#   "11" -- "31" [label="6.0"];
#   "11" -- "20" [label="3.0"];
#   "11" -- "88" [label="36.0"];
#   "11" -- "52" [label="15.0"];
#   "11" -- "26" [label="22.0"];
#   "11" -- "47" [label="8.0"];
#   "11" -- "24" [label="25.0"];
#   "11" -- "23" [label="20.0"];
#   "11" -- "1" [label="19.0"];
#   "11" -- "10" [label="25.0"];
#   "11" -- "51" [label="8.0"];
#   "11" -- "67" [label="32.0"];
#   "11" -- "60" [label="23.0"];
#   "11" -- "85" [label="33.0"];
#   "11" -- "65" [label="23.0"];
#   "11" -- "14" [label="11.0"];
#   "11" -- "40" [label="40.0"];
#   "11" -- "64" [label="19.0"];
#   "11" -- "75" [label="26.0"];
#   "11" -- "63" [label="10.0"];
#   "11" -- "54" [label="14.0"];
#   "11" -- "66" [label="17.0"];
#   "11" -- "34" [label="32.0"];
#   "11" -- "22" [label="4.0"];
#   "29" -- "11" [label="19.0"];
#   "29" -- "47" [label="6.0"];
#   "29" -- "79" [label="10.0"];
#   "29" -- "71" [label="9.0"];
#   "29" -- "20" [label="10.0"];
#   "29" -- "60" [label="42.0"];
#   "29" -- "5" [label="46.0"];
#   "29" -- "7" [label="7.0"];
#   "29" -- "4" [label="24.0"];
#   "29" -- "39" [label="18.0"];
#   "29" -- "82" [label="6.0"];
#   "29" -- "44" [label="18.0"];
#   "29" -- "12" [label="18.0"];
#   "29" -- "67" [label="4.0"];
#   "29" -- "15" [label="9.0"];
#   "29" -- "57" [label="30.0"];
#   "29" -- "17" [label="15.0"];
#   "29" -- "56" [label="6.0"];
#   "29" -- "66" [label="19.0"];
#   "29" -- "81" [label="9.0"];
#   "29" -- "14" [label="9.0"];
#   "29" -- "61" [label="2.0"];
#   "29" -- "23" [label="9.0"];
#   "29" -- "30" [label="21.0"];
#   "29" -- "18" [label="9.0"];
#   "29" -- "59" [label="40.0"];
#   "29" -- "27" [label="18.0"];
#   "29" -- "64" [label="17.0"];
#   "29" -- "16" [label="24.0"];
#   "29" -- "68" [label="19.0"];
#   "29" -- "25" [label="42.0"];
#   "29" -- "28" [label="7.0"];
#   "29" -- "49" [label="7.0"];
#   "29" -- "43" [label="2.0"];
#   "29" -- "48" [label="32.0"];
#   "29" -- "24" [label="34.0"];
#   "29" -- "52" [label="12.0"];
#   "29" -- "84" [label="37.0"];
#   "29" -- "50" [label="5.0"];
#   "29" -- "53" [label="10.0"];
#   "29" -- "62" [label="20.0"];
#   "29" -- "10" [label="23.0"];
#   "29" -- "69" [label="29.0"];
#   "12" -- "61" [label="14.0"];
#   "12" -- "18" [label="10.0"];
#   "12" -- "44" [label="3.0"];
#   "12" -- "11" [label="25.0"];
#   "12" -- "73" [label="32.0"];
#   "12" -- "70" [label="11.0"];
#   "12" -- "45" [label="11.0"];
#   "12" -- "2" [label="6.0"];
#   "12" -- "69" [label="2.0"];
#   "12" -- "29" [label="18.0"];
#   "12" -- "1" [label="27.0"];
#   "12" -- "65" [label="12.0"];
#   "12" -- "55" [label="12.0"];
#   "12" -- "54" [label="44.0"];
#   "12" -- "8" [label="16.0"];
#   "12" -- "75" [label="32.0"];
#   "12" -- "50" [label="6.0"];
#   "12" -- "82" [label="37.0"];
#   "12" -- "5" [label="3.0"];
#   "12" -- "67" [label="43.0"];
#   "12" -- "84" [label="29.0"];
#   "12" -- "83" [label="19.0"];
#   "12" -- "74" [label="10.0"];
#   "12" -- "66" [label="43.0"];
#   "12" -- "71" [label="32.0"];
#   "12" -- "7" [label="28.0"];
#   "12" -- "56" [label="13.0"];
#   "12" -- "48" [label="37.0"];
#   "12" -- "35" [label="9.0"];
#   "12" -- "51" [label="16.0"];
#   "12" -- "64" [label="15.0"];
#   "12" -- "80" [label="6.0"];
#   "12" -- "3" [label="34.0"];
#   "12" -- "41" [label="3.0"];
#   "12" -- "30" [label="43.0"];
#   "12" -- "49" [label="39.0"];
#   "12" -- "6" [label="31.0"];
#   "12" -- "77" [label="26.0"];
#   "12" -- "38" [label="46.0"];
#   "12" -- "39" [label="13.0"];
#   "12" -- "57" [label="17.0"];
#   "12" -- "31" [label="1.0"];
#   "12" -- "13" [label="24.0"];
#   "12" -- "78" [label="29.0"];
#   "12" -- "87" [label="5.0"];
#   "12" -- "60" [label="22.0"];
#   "61" -- "12" [label="14.0"];
#   "61" -- "25" [label="10.0"];
#   "61" -- "80" [label="5.0"];
#   "61" -- "6" [label="24.0"];
#   "61" -- "30" [label="41.0"];
#   "61" -- "22" [label="5.0"];
#   "61" -- "48" [label="20.0"];
#   "61" -- "67" [label="25.0"];
#   "61" -- "87" [label="1.0"];
#   "61" -- "4" [label="9.0"];
#   "61" -- "8" [label="1.0"];
#   "61" -- "57" [label="9.0"];
#   "61" -- "27" [label="30.0"];
#   "61" -- "55" [label="2.0"];
#   "61" -- "16" [label="23.0"];
#   "61" -- "62" [label="37.0"];
#   "61" -- "49" [label="4.0"];
#   "61" -- "24" [label="13.0"];
#   "61" -- "41" [label="27.0"];
#   "61" -- "82" [label="9.0"];
#   "61" -- "34" [label="23.0"];
#   "61" -- "29" [label="2.0"];
#   "61" -- "47" [label="9.0"];
#   "61" -- "74" [label="30.0"];
#   "61" -- "15" [label="43.0"];
#   "61" -- "18" [label="33.0"];
#   "61" -- "76" [label="40.0"];
#   "61" -- "20" [label="14.0"];
#   "61" -- "56" [label="29.0"];
#   "61" -- "78" [label="28.0"];
#   "61" -- "45" [label="25.0"];
#   "61" -- "73" [label="29.0"];
#   "61" -- "75" [label="23.0"];
#   "61" -- "86" [label="41.0"];
#   "61" -- "1" [label="8.0"];
#   "61" -- "37" [label="22.0"];
#   "61" -- "81" [label="4.0"];
#   "61" -- "46" [label="16.0"];
#   "61" -- "52" [label="44.0"];
#   "61" -- "2" [label="8.0"];
#   "61" -- "51" [label="36.0"];
#   "61" -- "54" [label="23.0"];
#   "61" -- "43" [label="10.0"];
#   "13" -- "73" [label="6.0"];
#   "13" -- "41" [label="59.0"];
#   "13" -- "7" [label="31.0"];
#   "13" -- "1" [label="32.0"];
#   "13" -- "88" [label="2.0"];
#   "13" -- "50" [label="5.0"];
#   "13" -- "5" [label="18.0"];
#   "13" -- "25" [label="28.0"];
#   "13" -- "37" [label="2.0"];
#   "13" -- "8" [label="33.0"];
#   "13" -- "30" [label="6.0"];
#   "13" -- "27" [label="33.0"];
#   "13" -- "35" [label="9.0"];
#   "13" -- "28" [label="11.0"];
#   "13" -- "75" [label="40.0"];
#   "13" -- "4" [label="23.0"];
#   "13" -- "16" [label="20.0"];
#   "13" -- "10" [label="6.0"];
#   "13" -- "9" [label="9.0"];
#   "13" -- "67" [label="10.0"];
#   "13" -- "57" [label="29.0"];
#   "13" -- "56" [label="35.0"];
#   "13" -- "38" [label="42.0"];
#   "13" -- "2" [label="41.0"];
#   "13" -- "83" [label="15.0"];
#   "13" -- "64" [label="28.0"];
#   "13" -- "84" [label="14.0"];
#   "13" -- "80" [label="2.0"];
#   "13" -- "48" [label="19.0"];
#   "13" -- "70" [label="4.0"];
#   "13" -- "52" [label="26.0"];
#   "13" -- "24" [label="21.0"];
#   "13" -- "54" [label="22.0"];
#   "13" -- "63" [label="7.0"];
#   "13" -- "12" [label="24.0"];
#   "13" -- "59" [label="9.0"];
#   "13" -- "87" [label="43.0"];
#   "13" -- "20" [label="34.0"];
#   "13" -- "46" [label="28.0"];
#   "73" -- "13" [label="6.0"];
#   "73" -- "68" [label="3.0"];
#   "73" -- "76" [label="26.0"];
#   "73" -- "78" [label="9.0"];
#   "73" -- "24" [label="10.0"];
#   "73" -- "12" [label="32.0"];
#   "73" -- "79" [label="23.0"];
#   "73" -- "69" [label="24.0"];
#   "73" -- "86" [label="23.0"];
#   "73" -- "57" [label="5.0"];
#   "73" -- "65" [label="8.0"];
#   "73" -- "47" [label="14.0"];
#   "73" -- "51" [label="24.0"];
#   "73" -- "63" [label="24.0"];
#   "73" -- "8" [label="23.0"];
#   "73" -- "70" [label="3.0"];
#   "73" -- "2" [label="9.0"];
#   "73" -- "82" [label="37.0"];
#   "73" -- "36" [label="45.0"];
#   "73" -- "26" [label="7.0"];
#   "73" -- "6" [label="2.0"];
#   "73" -- "50" [label="8.0"];
#   "73" -- "49" [label="35.0"];
#   "73" -- "67" [label="18.0"];
#   "73" -- "52" [label="1.0"];
#   "73" -- "3" [label="30.0"];
#   "73" -- "28" [label="5.0"];
#   "73" -- "27" [label="33.0"];
#   "73" -- "62" [label="7.0"];
#   "73" -- "64" [label="46.0"];
#   "73" -- "85" [label="39.0"];
#   "73" -- "61" [label="29.0"];
#   "73" -- "72" [label="23.0"];
#   "73" -- "33" [label="2.0"];
#   "73" -- "4" [label="5.0"];
#   "73" -- "75" [label="18.0"];
#   "73" -- "80" [label="33.0"];
#   "73" -- "20" [label="39.0"];
#   "73" -- "83" [label="7.0"];
#   "73" -- "9" [label="8.0"];
#   "73" -- "74" [label="8.0"];
#   "73" -- "16" [label="7.0"];
#   "73" -- "5" [label="31.0"];
#   "73" -- "32" [label="8.0"];
#   "73" -- "84" [label="13.0"];
#   "73" -- "19" [label="16.0"];
#   "73" -- "7" [label="42.0"];
#   "14" -- "3" [label="5.0"];
#   "14" -- "88" [label="3.0"];
#   "14" -- "10" [label="7.0"];
#   "14" -- "63" [label="13.0"];
#   "14" -- "9" [label="41.0"];
#   "14" -- "16" [label="25.0"];
#   "14" -- "57" [label="9.0"];
#   "14" -- "84" [label="8.0"];
#   "14" -- "86" [label="31.0"];
#   "14" -- "60" [label="28.0"];
#   "14" -- "79" [label="16.0"];
#   "14" -- "22" [label="13.0"];
#   "14" -- "24" [label="19.0"];
#   "14" -- "58" [label="14.0"];
#   "14" -- "27" [label="10.0"];
#   "14" -- "1" [label="1.0"];
#   "14" -- "28" [label="31.0"];
#   "14" -- "7" [label="22.0"];
#   "14" -- "68" [label="7.0"];
#   "14" -- "30" [label="4.0"];
#   "14" -- "82" [label="9.0"];
#   "14" -- "32" [label="25.0"];
#   "14" -- "29" [label="9.0"];
#   "14" -- "52" [label="32.0"];
#   "14" -- "44" [label="7.0"];
#   "14" -- "33" [label="2.0"];
#   "14" -- "75" [label="22.0"];
#   "14" -- "76" [label="18.0"];
#   "14" -- "59" [label="39.0"];
#   "14" -- "35" [label="28.0"];
#   "14" -- "20" [label="19.0"];
#   "14" -- "45" [label="22.0"];
#   "14" -- "53" [label="23.0"];
#   "14" -- "11" [label="11.0"];
#   "14" -- "67" [label="27.0"];
#   "14" -- "21" [label="31.0"];
#   "14" -- "8" [label="42.0"];
#   "14" -- "69" [label="24.0"];
#   "14" -- "51" [label="36.0"];
#   "14" -- "47" [label="6.0"];
#   "14" -- "87" [label="45.0"];
#   "15" -- "18" [label="14.0"];
#   "15" -- "16" [label="7.0"];
#   "15" -- "22" [label="11.0"];
#   "15" -- "38" [label="14.0"];
#   "15" -- "48" [label="26.0"];
#   "15" -- "62" [label="9.0"];
#   "15" -- "11" [label="31.0"];
#   "15" -- "47" [label="38.0"];
#   "15" -- "59" [label="14.0"];
#   "15" -- "49" [label="20.0"];
#   "15" -- "6" [label="42.0"];
#   "15" -- "65" [label="12.0"];
#   "15" -- "51" [label="16.0"];
#   "15" -- "85" [label="23.0"];
#   "15" -- "70" [label="6.0"];
#   "15" -- "58" [label="44.0"];
#   "15" -- "40" [label="12.0"];
#   "15" -- "29" [label="9.0"];
#   "15" -- "63" [label="3.0"];
#   "15" -- "20" [label="26.0"];
#   "15" -- "32" [label="1.0"];
#   "15" -- "19" [label="4.0"];
#   "15" -- "2" [label="26.0"];
#   "15" -- "74" [label="8.0"];
#   "15" -- "57" [label="14.0"];
#   "15" -- "75" [label="39.0"];
#   "15" -- "39" [label="46.0"];
#   "15" -- "61" [label="43.0"];
#   "15" -- "83" [label="23.0"];
#   "15" -- "27" [label="12.0"];
#   "15" -- "36" [label="3.0"];
#   "15" -- "4" [label="1.0"];
#   "15" -- "54" [label="30.0"];
#   "15" -- "84" [label="19.0"];
#   "15" -- "5" [label="33.0"];
#   "15" -- "8" [label="10.0"];
#   "15" -- "42" [label="9.0"];
#   "15" -- "60" [label="45.0"];
#   "15" -- "1" [label="30.0"];
#   "15" -- "78" [label="34.0"];
#   "15" -- "66" [label="6.0"];
#   "15" -- "43" [label="9.0"];
#   "16" -- "49" [label="53.0"];
#   "16" -- "25" [label="1.0"];
#   "16" -- "50" [label="28.0"];
#   "16" -- "15" [label="7.0"];
#   "16" -- "17" [label="4.0"];
#   "16" -- "58" [label="3.0"];
#   "16" -- "23" [label="3.0"];
#   "16" -- "37" [label="10.0"];
#   "16" -- "67" [label="41.0"];
#   "16" -- "1" [label="5.0"];
#   "16" -- "14" [label="25.0"];
#   "16" -- "55" [label="3.0"];
#   "16" -- "57" [label="3.0"];
#   "16" -- "80" [label="20.0"];
#   "16" -- "13" [label="20.0"];
#   "16" -- "35" [label="9.0"];
#   "16" -- "61" [label="23.0"];
#   "16" -- "31" [label="7.0"];
#   "16" -- "6" [label="12.0"];
#   "16" -- "24" [label="2.0"];
#   "16" -- "36" [label="39.0"];
#   "16" -- "29" [label="24.0"];
#   "16" -- "18" [label="15.0"];
#   "16" -- "59" [label="46.0"];
#   "16" -- "47" [label="13.0"];
#   "16" -- "64" [label="35.0"];
#   "16" -- "3" [label="24.0"];
#   "16" -- "26" [label="9.0"];
#   "16" -- "60" [label="21.0"];
#   "16" -- "88" [label="37.0"];
#   "16" -- "21" [label="40.0"];
#   "16" -- "53" [label="3.0"];
#   "16" -- "73" [label="7.0"];
#   "16" -- "51" [label="27.0"];
#   "16" -- "8" [label="40.0"];
#   "16" -- "41" [label="45.0"];
#   "49" -- "16" [label="53.0"];
#   "49" -- "34" [label="9.0"];
#   "49" -- "57" [label="5.0"];
#   "49" -- "3" [label="3.0"];
#   "49" -- "59" [label="7.0"];
#   "49" -- "56" [label="19.0"];
#   "49" -- "39" [label="34.0"];
#   "49" -- "60" [label="31.0"];
#   "49" -- "15" [label="20.0"];
#   "49" -- "55" [label="36.0"];
#   "49" -- "42" [label="14.0"];
#   "49" -- "72" [label="46.0"];
#   "49" -- "46" [label="8.0"];
#   "49" -- "70" [label="38.0"];
#   "49" -- "43" [label="3.0"];
#   "49" -- "52" [label="44.0"];
#   "49" -- "21" [label="20.0"];
#   "49" -- "62" [label="32.0"];
#   "49" -- "85" [label="40.0"];
#   "49" -- "61" [label="4.0"];
#   "49" -- "87" [label="9.0"];
#   "49" -- "36" [label="10.0"];
#   "49" -- "50" [label="26.0"];
#   "49" -- "8" [label="18.0"];
#   "49" -- "25" [label="6.0"];
#   "49" -- "18" [label="34.0"];
#   "49" -- "73" [label="35.0"];
#   "49" -- "65" [label="33.0"];
#   "49" -- "30" [label="36.0"];
#   "49" -- "38" [label="28.0"];
#   "49" -- "4" [label="6.0"];
#   "49" -- "78" [label="22.0"];
#   "49" -- "79" [label="37.0"];
#   "49" -- "12" [label="39.0"];
#   "49" -- "29" [label="7.0"];
#   "49" -- "76" [label="39.0"];
#   "49" -- "51" [label="32.0"];
#   "49" -- "35" [label="21.0"];
#   "49" -- "47" [label="3.0"];
#   "49" -- "31" [label="10.0"];
#   "49" -- "77" [label="17.0"];
#   "49" -- "32" [label="27.0"];
#   "49" -- "48" [label="30.0"];
#   "49" -- "83" [label="38.0"];
#   "49" -- "6" [label="27.0"];
#   "49" -- "10" [label="21.0"];
#   "49" -- "9" [label="32.0"];
#   "49" -- "63" [label="46.0"];
#   "49" -- "23" [label="17.0"];
#   "17" -- "30" [label="46.0"];
#   "17" -- "87" [label="2.0"];
#   "17" -- "16" [label="4.0"];
#   "17" -- "69" [label="32.0"];
#   "17" -- "26" [label="9.0"];
#   "17" -- "7" [label="9.0"];
#   "17" -- "53" [label="26.0"];
#   "17" -- "63" [label="5.0"];
#   "17" -- "25" [label="6.0"];
#   "17" -- "1" [label="8.0"];
#   "17" -- "32" [label="15.0"];
#   "17" -- "29" [label="15.0"];
#   "17" -- "36" [label="5.0"];
#   "17" -- "64" [label="10.0"];
#   "17" -- "27" [label="32.0"];
#   "17" -- "5" [label="7.0"];
#   "17" -- "66" [label="25.0"];
#   "17" -- "77" [label="26.0"];
#   "17" -- "51" [label="8.0"];
#   "17" -- "9" [label="30.0"];
#   "17" -- "47" [label="10.0"];
#   "17" -- "42" [label="28.0"];
#   "17" -- "58" [label="20.0"];
#   "17" -- "55" [label="41.0"];
#   "17" -- "48" [label="3.0"];
#   "17" -- "71" [label="12.0"];
#   "17" -- "62" [label="10.0"];
#   "17" -- "82" [label="2.0"];
#   "17" -- "24" [label="44.0"];
#   "17" -- "6" [label="31.0"];
#   "17" -- "35" [label="30.0"];
#   "17" -- "65" [label="31.0"];
#   "17" -- "46" [label="29.0"];
#   "17" -- "79" [label="36.0"];
#   "30" -- "17" [label="46.0"];
#   "30" -- "65" [label="5.0"];
#   "30" -- "81" [label="46.0"];
#   "30" -- "61" [label="41.0"];
#   "30" -- "1" [label="2.0"];
#   "30" -- "20" [label="9.0"];
#   "30" -- "8" [label="12.0"];
#   "30" -- "86" [label="1.0"];
#   "30" -- "27" [label="7.0"];
#   "30" -- "60" [label="14.0"];
#   "30" -- "57" [label="36.0"];
#   "30" -- "6" [label="10.0"];
#   "30" -- "37" [label="17.0"];
#   "30" -- "13" [label="6.0"];
#   "30" -- "3" [label="7.0"];
#   "30" -- "84" [label="32.0"];
#   "30" -- "63" [label="11.0"];
#   "30" -- "80" [label="9.0"];
#   "30" -- "78" [label="36.0"];
#   "30" -- "24" [label="42.0"];
#   "30" -- "14" [label="4.0"];
#   "30" -- "18" [label="5.0"];
#   "30" -- "77" [label="20.0"];
#   "30" -- "54" [label="34.0"];
#   "30" -- "56" [label="30.0"];
#   "30" -- "7" [label="4.0"];
#   "30" -- "29" [label="21.0"];
#   "30" -- "43" [label="27.0"];
#   "30" -- "50" [label="1.0"];
#   "30" -- "44" [label="42.0"];
#   "30" -- "49" [label="36.0"];
#   "30" -- "38" [label="41.0"];
#   "30" -- "23" [label="30.0"];
#   "30" -- "75" [label="7.0"];
#   "30" -- "87" [label="31.0"];
#   "30" -- "12" [label="43.0"];
#   "30" -- "71" [label="27.0"];
#   "30" -- "58" [label="9.0"];
#   "30" -- "67" [label="43.0"];
#   "30" -- "4" [label="41.0"];
#   "30" -- "31" [label="31.0"];
#   "30" -- "21" [label="23.0"];
#   "30" -- "42" [label="12.0"];
#   "30" -- "51" [label="10.0"];
#   "19" -- "22" [label="1.0"];
#   "19" -- "52" [label="21.0"];
#   "19" -- "56" [label="7.0"];
#   "19" -- "86" [label="14.0"];
#   "19" -- "74" [label="20.0"];
#   "19" -- "67" [label="29.0"];
#   "19" -- "76" [label="8.0"];
#   "19" -- "62" [label="10.0"];
#   "19" -- "39" [label="2.0"];
#   "19" -- "68" [label="38.0"];
#   "19" -- "66" [label="13.0"];
#   "19" -- "72" [label="6.0"];
#   "19" -- "24" [label="8.0"];
#   "19" -- "38" [label="42.0"];
#   "19" -- "59" [label="38.0"];
#   "19" -- "44" [label="21.0"];
#   "19" -- "33" [label="23.0"];
#   "19" -- "40" [label="13.0"];
#   "19" -- "36" [label="8.0"];
#   "19" -- "15" [label="4.0"];
#   "19" -- "35" [label="35.0"];
#   "19" -- "70" [label="12.0"];
#   "19" -- "41" [label="32.0"];
#   "19" -- "50" [label="33.0"];
#   "19" -- "18" [label="8.0"];
#   "19" -- "48" [label="6.0"];
#   "19" -- "83" [label="19.0"];
#   "19" -- "1" [label="6.0"];
#   "19" -- "65" [label="20.0"];
#   "19" -- "7" [label="43.0"];
#   "19" -- "71" [label="46.0"];
#   "19" -- "84" [label="30.0"];
#   "19" -- "34" [label="37.0"];
#   "19" -- "79" [label="3.0"];
#   "19" -- "43" [label="10.0"];
#   "19" -- "77" [label="33.0"];
#   "19" -- "42" [label="41.0"];
#   "19" -- "10" [label="10.0"];
#   "19" -- "87" [label="15.0"];
#   "19" -- "51" [label="24.0"];
#   "19" -- "45" [label="22.0"];
#   "19" -- "20" [label="21.0"];
#   "19" -- "53" [label="1.0"];
#   "19" -- "9" [label="11.0"];
#   "19" -- "63" [label="1.0"];
#   "19" -- "73" [label="16.0"];
#   "22" -- "19" [label="1.0"];
#   "22" -- "52" [label="6.0"];
#   "22" -- "15" [label="11.0"];
#   "22" -- "61" [label="5.0"];
#   "22" -- "67" [label="6.0"];
#   "22" -- "86" [label="3.0"];
#   "22" -- "57" [label="23.0"];
#   "22" -- "85" [label="4.0"];
#   "22" -- "53" [label="15.0"];
#   "22" -- "9" [label="37.0"];
#   "22" -- "14" [label="13.0"];
#   "22" -- "6" [label="9.0"];
#   "22" -- "24" [label="39.0"];
#   "22" -- "72" [label="34.0"];
#   "22" -- "65" [label="32.0"];
#   "22" -- "78" [label="35.0"];
#   "22" -- "31" [label="8.0"];
#   "22" -- "62" [label="26.0"];
#   "22" -- "70" [label="2.0"];
#   "22" -- "35" [label="20.0"];
#   "22" -- "48" [label="2.0"];
#   "22" -- "26" [label="29.0"];
#   "22" -- "34" [label="43.0"];
#   "22" -- "21" [label="10.0"];
#   "22" -- "45" [label="41.0"];
#   "22" -- "32" [label="33.0"];
#   "22" -- "83" [label="45.0"];
#   "22" -- "20" [label="1.0"];
#   "22" -- "51" [label="4.0"];
#   "22" -- "47" [label="14.0"];
#   "22" -- "56" [label="38.0"];
#   "22" -- "38" [label="41.0"];
#   "22" -- "75" [label="40.0"];
#   "22" -- "1" [label="39.0"];
#   "22" -- "18" [label="46.0"];
#   "22" -- "82" [label="36.0"];
#   "22" -- "41" [label="41.0"];
#   "22" -- "4" [label="3.0"];
#   "22" -- "11" [label="4.0"];
#   "20" -- "38" [label="28.0"];
#   "20" -- "26" [label="20.0"];
#   "20" -- "41" [label="25.0"];
#   "20" -- "65" [label="25.0"];
#   "20" -- "30" [label="9.0"];
#   "20" -- "29" [label="10.0"];
#   "20" -- "81" [label="9.0"];
#   "20" -- "71" [label="18.0"];
#   "20" -- "39" [label="7.0"];
#   "20" -- "54" [label="22.0"];
#   "20" -- "51" [label="5.0"];
#   "20" -- "62" [label="14.0"];
#   "20" -- "6" [label="1.0"];
#   "20" -- "36" [label="5.0"];
#   "20" -- "7" [label="29.0"];
#   "20" -- "21" [label="18.0"];
#   "20" -- "27" [label="12.0"];
#   "20" -- "66" [label="6.0"];
#   "20" -- "2" [label="19.0"];
#   "20" -- "63" [label="5.0"];
#   "20" -- "15" [label="26.0"];
#   "20" -- "57" [label="45.0"];
#   "20" -- "67" [label="4.0"];
#   "20" -- "25" [label="18.0"];
#   "20" -- "42" [label="8.0"];
#   "20" -- "79" [label="17.0"];
#   "20" -- "58" [label="41.0"];
#   "20" -- "3" [label="7.0"];
#   "20" -- "59" [label="7.0"];
#   "20" -- "60" [label="6.0"];
#   "20" -- "35" [label="9.0"];
#   "20" -- "11" [label="3.0"];
#   "20" -- "83" [label="11.0"];
#   "20" -- "70" [label="46.0"];
#   "20" -- "75" [label="27.0"];
#   "20" -- "61" [label="14.0"];
#   "20" -- "37" [label="37.0"];
#   "20" -- "32" [label="33.0"];
#   "20" -- "85" [label="33.0"];
#   "20" -- "50" [label="41.0"];
#   "20" -- "64" [label="2.0"];
#   "20" -- "22" [label="1.0"];
#   "20" -- "14" [label="19.0"];
#   "20" -- "45" [label="23.0"];
#   "20" -- "8" [label="9.0"];
#   "20" -- "73" [label="39.0"];
#   "20" -- "78" [label="22.0"];
#   "20" -- "5" [label="29.0"];
#   "20" -- "56" [label="8.0"];
#   "20" -- "10" [label="40.0"];
#   "20" -- "9" [label="36.0"];
#   "20" -- "19" [label="21.0"];
#   "20" -- "13" [label="34.0"];
#   "38" -- "20" [label="28.0"];
#   "38" -- "53" [label="21.0"];
#   "38" -- "2" [label="22.0"];
#   "38" -- "15" [label="14.0"];
#   "38" -- "81" [label="29.0"];
#   "38" -- "11" [label="44.0"];
#   "38" -- "80" [label="10.0"];
#   "38" -- "71" [label="24.0"];
#   "38" -- "37" [label="33.0"];
#   "38" -- "85" [label="44.0"];
#   "38" -- "44" [label="40.0"];
#   "38" -- "77" [label="19.0"];
#   "38" -- "70" [label="36.0"];
#   "38" -- "24" [label="19.0"];
#   "38" -- "19" [label="42.0"];
#   "38" -- "8" [label="31.0"];
#   "38" -- "87" [label="5.0"];
#   "38" -- "5" [label="2.0"];
#   "38" -- "50" [label="5.0"];
#   "38" -- "60" [label="3.0"];
#   "38" -- "39" [label="1.0"];
#   "38" -- "13" [label="42.0"];
#   "38" -- "51" [label="13.0"];
#   "38" -- "54" [label="3.0"];
#   "38" -- "49" [label="28.0"];
#   "38" -- "69" [label="18.0"];
#   "38" -- "30" [label="41.0"];
#   "38" -- "68" [label="16.0"];
#   "38" -- "18" [label="35.0"];
#   "38" -- "22" [label="41.0"];
# ...
#   "82" -- "63" [label="38.0"];
#   "82" -- "69" [label="28.0"];
#   "82" -- "33" [label="1.0"];
#   "82" -- "60" [label="38.0"];
#   "82" -- "79" [label="9.0"];
#   "82" -- "39" [label="4.0"];
#   "82" -- "44" [label="34.0"];
#   "82" -- "24" [label="10.0"];
#   "82" -- "62" [label="41.0"];
#   "82" -- "31" [label="5.0"];
#   "82" -- "29" [label="6.0"];
#   "82" -- "74" [label="27.0"];
#   "82" -- "81" [label="10.0"];
#   "82" -- "55" [label="8.0"];
#   "82" -- "51" [label="44.0"];
#   "82" -- "12" [label="37.0"];
#   "82" -- "87" [label="32.0"];
#   "82" -- "21" [label="30.0"];
#   "82" -- "8" [label="34.0"];
#   "82" -- "73" [label="37.0"];
#   "82" -- "61" [label="9.0"];
#   "82" -- "47" [label="14.0"];
#   "82" -- "27" [label="44.0"];
#   "82" -- "14" [label="9.0"];
#   "82" -- "25" [label="6.0"];
#   "82" -- "65" [label="10.0"];
#   "82" -- "77" [label="22.0"];
#   "82" -- "66" [label="2.0"];
#   "82" -- "1" [label="6.0"];
#   "82" -- "76" [label="36.0"];
#   "82" -- "17" [label="2.0"];
#   "82" -- "50" [label="7.0"];
#   "82" -- "83" [label="20.0"];
#   "82" -- "68" [label="24.0"];
#   "82" -- "72" [label="3.0"];
#   "82" -- "70" [label="42.0"];
#   "82" -- "23" [label="9.0"];
#   "82" -- "88" [label="36.0"];
#   "82" -- "35" [label="33.0"];
#   "82" -- "54" [label="1.0"];
#   "82" -- "43" [label="20.0"];
#   "82" -- "45" [label="4.0"];
#   "82" -- "41" [label="23.0"];
#   "82" -- "84" [label="30.0"];
#   "82" -- "48" [label="3.0"];
#   "82" -- "80" [label="11.0"];
#   "82" -- "34" [label="35.0"];
#   "82" -- "26" [label="14.0"];
#   "82" -- "5" [label="30.0"];
#   "82" -- "46" [label="39.0"];
#   "82" -- "22" [label="36.0"];
#   "82" -- "36" [label="41.0"];
#   "83" -- "24" [label="17.0"];
#   "83" -- "36" [label="1.0"];
#   "83" -- "51" [label="39.0"];
#   "83" -- "79" [label="16.0"];
#   "83" -- "55" [label="31.0"];
#   "83" -- "77" [label="14.0"];
#   "83" -- "40" [label="9.0"];
#   "83" -- "60" [label="31.0"];
#   "83" -- "39" [label="9.0"];
#   "83" -- "1" [label="17.0"];
#   "83" -- "65" [label="27.0"];
#   "83" -- "45" [label="25.0"];
#   "83" -- "84" [label="23.0"];
#   "83" -- "52" [label="1.0"];
#   "83" -- "12" [label="19.0"];
#   "83" -- "33" [label="4.0"];
#   "83" -- "72" [label="12.0"];
#   "83" -- "56" [label="43.0"];
#   "83" -- "64" [label="22.0"];
#   "83" -- "68" [label="40.0"];
#   "83" -- "4" [label="8.0"];
#   "83" -- "42" [label="1.0"];
#   "83" -- "18" [label="3.0"];
#   "83" -- "19" [label="19.0"];
#   "83" -- "13" [label="15.0"];
#   "83" -- "48" [label="20.0"];
#   "83" -- "7" [label="6.0"];
#   "83" -- "15" [label="23.0"];
#   "83" -- "20" [label="11.0"];
#   "83" -- "70" [label="2.0"];
#   "83" -- "82" [label="20.0"];
#   "83" -- "58" [label="39.0"];
#   "83" -- "44" [label="15.0"];
#   "83" -- "69" [label="31.0"];
#   "83" -- "22" [label="45.0"];
#   "83" -- "85" [label="1.0"];
#   "83" -- "10" [label="40.0"];
#   "83" -- "59" [label="2.0"];
#   "83" -- "78" [label="7.0"];
#   "83" -- "9" [label="30.0"];
#   "83" -- "75" [label="38.0"];
#   "83" -- "25" [label="30.0"];
#   "83" -- "73" [label="7.0"];
#   "83" -- "26" [label="1.0"];
#   "83" -- "88" [label="3.0"];
#   "83" -- "49" [label="38.0"];
#   "83" -- "86" [label="27.0"];
#   "83" -- "5" [label="1.0"];
#   "83" -- "74" [label="46.0"];
#   "83" -- "27" [label="3.0"];
#   "83" -- "62" [label="43.0"];
#   "84" -- "7" [label="42.0"];
#   "84" -- "37" [label="9.0"];
#   "84" -- "69" [label="28.0"];
#   "84" -- "1" [label="1.0"];
#   "84" -- "34" [label="45.0"];
#   "84" -- "58" [label="43.0"];
#   "84" -- "14" [label="8.0"];
#   "84" -- "87" [label="29.0"];
#   "84" -- "8" [label="16.0"];
#   "84" -- "52" [label="17.0"];
#   "84" -- "30" [label="32.0"];
#   "84" -- "27" [label="6.0"];
#   "84" -- "85" [label="28.0"];
#   "84" -- "62" [label="4.0"];
#   "84" -- "12" [label="29.0"];
#   "84" -- "75" [label="34.0"];
#   "84" -- "83" [label="23.0"];
#   "84" -- "77" [label="9.0"];
#   "84" -- "68" [label="32.0"];
#   "84" -- "46" [label="9.0"];
#   "84" -- "25" [label="15.0"];
#   "84" -- "6" [label="6.0"];
#   "84" -- "64" [label="16.0"];
#   "84" -- "65" [label="18.0"];
#   "84" -- "41" [label="4.0"];
#   "84" -- "71" [label="15.0"];
#   "84" -- "13" [label="14.0"];
#   "84" -- "19" [label="30.0"];
#   "84" -- "44" [label="27.0"];
#   "84" -- "76" [label="21.0"];
#   "84" -- "53" [label="7.0"];
#   "84" -- "15" [label="19.0"];
#   "84" -- "82" [label="30.0"];
#   "84" -- "4" [label="20.0"];
#   "84" -- "43" [label="23.0"];
#   "84" -- "55" [label="25.0"];
#   "84" -- "29" [label="37.0"];
#   "84" -- "5" [label="22.0"];
#   "84" -- "10" [label="13.0"];
#   "84" -- "38" [label="31.0"];
#   "84" -- "73" [label="13.0"];
#   "84" -- "81" [label="3.0"];
#   "84" -- "2" [label="11.0"];
#   "84" -- "31" [label="16.0"];
#   "86" -- "59" [label="43.0"];
#   "86" -- "75" [label="15.0"];
#   "86" -- "51" [label="30.0"];
#   "86" -- "69" [label="20.0"];
#   "86" -- "74" [label="22.0"];
#   "86" -- "19" [label="14.0"];
#   "86" -- "22" [label="3.0"];
#   "86" -- "72" [label="3.0"];
#   "86" -- "30" [label="1.0"];
#   "86" -- "73" [label="23.0"];
#   "86" -- "39" [label="12.0"];
#   "86" -- "14" [label="31.0"];
#   "86" -- "85" [label="22.0"];
#   "86" -- "58" [label="15.0"];
#   "86" -- "76" [label="17.0"];
#   "86" -- "67" [label="17.0"];
#   "86" -- "8" [label="6.0"];
#   "86" -- "66" [label="1.0"];
#   "86" -- "37" [label="13.0"];
#   "86" -- "21" [label="3.0"];
#   "86" -- "65" [label="14.0"];
#   "86" -- "50" [label="31.0"];
#   "86" -- "47" [label="16.0"];
#   "86" -- "9" [label="32.0"];
#   "86" -- "57" [label="43.0"];
#   "86" -- "81" [label="9.0"];
#   "86" -- "63" [label="23.0"];
#   "86" -- "31" [label="13.0"];
#   "86" -- "42" [label="23.0"];
#   "86" -- "88" [label="37.0"];
#   "86" -- "26" [label="24.0"];
#   "86" -- "10" [label="29.0"];
#   "86" -- "28" [label="6.0"];
#   "86" -- "71" [label="17.0"];
#   "86" -- "7" [label="4.0"];
#   "86" -- "61" [label="41.0"];
#   "86" -- "40" [label="28.0"];
#   "86" -- "1" [label="10.0"];
#   "86" -- "55" [label="11.0"];
#   "86" -- "83" [label="27.0"];
#   "86" -- "77" [label="2.0"];
#   "86" -- "53" [label="11.0"];
#   "86" -- "3" [label="36.0"];
#   "86" -- "43" [label="31.0"];
#   "86" -- "38" [label="21.0"];
#   "86" -- "41" [label="30.0"];
#   "87" -- "70" [label="16.0"];
#   "87" -- "17" [label="2.0"];
#   "87" -- "58" [label="37.0"];
#   "87" -- "79" [label="39.0"];
#   "87" -- "80" [label="18.0"];
#   "87" -- "18" [label="4.0"];
#   "87" -- "61" [label="1.0"];
#   "87" -- "75" [label="39.0"];
#   "87" -- "32" [label="20.0"];
#   "87" -- "50" [label="20.0"];
#   "87" -- "74" [label="15.0"];
#   "87" -- "84" [label="29.0"];
#   "87" -- "57" [label="15.0"];
#   "87" -- "41" [label="11.0"];
#   "87" -- "63" [label="23.0"];
#   "87" -- "62" [label="38.0"];
#   "87" -- "69" [label="15.0"];
#   "87" -- "82" [label="32.0"];
#   "87" -- "1" [label="3.0"];
#   "87" -- "40" [label="36.0"];
#   "87" -- "23" [label="42.0"];
#   "87" -- "38" [label="5.0"];
#   "87" -- "8" [label="32.0"];
#   "87" -- "49" [label="9.0"];
#   "87" -- "11" [label="13.0"];
#   "87" -- "10" [label="35.0"];
#   "87" -- "64" [label="6.0"];
#   "87" -- "66" [label="14.0"];
#   "87" -- "60" [label="27.0"];
#   "87" -- "30" [label="31.0"];
#   "87" -- "88" [label="43.0"];
#   "87" -- "26" [label="3.0"];
#   "87" -- "19" [label="15.0"];
#   "87" -- "24" [label="33.0"];
#   "87" -- "13" [label="43.0"];
#   "87" -- "12" [label="5.0"];
#   "87" -- "14" [label="45.0"];
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 Source(read_dot_file("hd6dijkstra"))
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:152, in DisplayFormatter.format(self, obj, include, exclude)
#     148 if self.ipython_display_formatter(obj):
#     149     # object handled itself, don't proceed
#     150     return {}, {}
# --> 152 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#     154 if format_dict or md_dict:
#     155     if include:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/jupyter_integration.py:98, in JupyterIntegration._repr_mimebundle_(self, include, exclude, **_)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/jupyter_integration.py:112, in JupyterIntegration._repr_image_svg_xml(self)
#     110 def _repr_image_svg_xml(self) -> str:
#     111     """Return the rendered graph as SVG string."""
# --> 112     return self.pipe(format='svg', encoding=SVG_ENCODING)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/piping.py:149, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     146 if encoding is not None:
#     147     if codecs.lookup(encoding) is codecs.lookup(self.encoding):
#     148         # common case: both stdin and stdout need the same encoding
# --> 149         return self._pipe_lines_string(*args, encoding=encoding, **kwargs)
#     150     try:
#     151         raw = self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/piping.py:212, in pipe_lines_string(engine, format, input_lines, encoding, renderer, formatter, neato_no_op, quiet)
#     206 cmd = dot_command.command(engine, format,
#     207                           renderer=renderer,
#     208                           formatter=formatter,
#     209                           neato_no_op=neato_no_op)
#     210 kwargs = {'input_lines': input_lines, 'encoding': encoding}
# --> 212 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     213 return proc.stdout
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/execute.py:76, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      74     if kwargs.pop('capture_output'):
#      75         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 76     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77 else:
#      78     proc = subprocess.run(cmd, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/graphviz/backend/execute.py:102, in _run_input_lines(cmd, input_lines, kwargs)
#      99 for line in input_lines:
#     100     stdin_write(line)
# --> 102 stdout, stderr = popen.communicate()
#     103 return subprocess.CompletedProcess(popen.args, popen.returncode,
#     104                                    stdout=stdout, stderr=stderr)
#
# File /opt/homebrew/anaconda3/lib/python3.12/subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File /opt/homebrew/anaconda3/lib/python3.12/subprocess.py:2115, in Popen._communicate(self, input, endtime, orig_timeout)
#    2108     self._check_timeout(endtime, orig_timeout,
#    2109                         stdout, stderr,
#    2110                         skip_check_and_raise=True)
#    2111     raise RuntimeError(  # Impossible :)
#    2112         '_check_timeout(..., skip_check_and_raise=True) '
#    2113         'failed to raise TimeoutExpired.')
# -> 2115 ready = selector.select(timeout)
#    2116 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2118 # XXX Rewrite these to use non-blocking I/O on the file
#    2119 # objects; they are no longer using C stdio!
#
# File /opt/homebrew/anaconda3/lib/python3.12/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Converting .dot files to PDFs

# %%
# !dot -Tpdf 7dijkstra.dot -o 7_Output.pdf

# %%
# !dot -Tpdf loopparalleldijkstra.dot -o loopparallel_Output.pdf

# %%
# !dot -Tpdf hd1dijkstra.dot -o hd1_Output.pdf

# %%
# !dot -Tpdf hd2dijkstra.dot -o hd2_Output.pdf
# Out:
# ^C

# %%
# !dot -Tpdf hd3dijkstra.dot -o hd3_Output.pdf

# %%
# !dot -Tpdf hd5dijkstra.dot -o hd5.pdf

# %%
# !dot -Tpdf hd6dijkstra.dot -o hd6.pdf
# Out:
# ^C
